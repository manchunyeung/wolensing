# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
x2 = np.linspace(0, 10, 20)
y2 = 1 - np.sin(x2)

# %%
x1 = np.linspace(-5, 5, 100)
y1 = np.linspace(-5, 5, 100)
x, y = np.meshgrid(x1, y1)
z = x**2 + y**2

# %%
plt.plot(x,y)

# %%
plt.contour(x, y, z)
plt.plot(x2, y2)

# %%
ra, dec = ([np.array([1.20795817e-06, 1.20795824e-06, 1.20795870e-06, 1.20795863e-06,
         1.20795844e-06, 1.20795874e-06, 1.20795933e-06, 1.20795807e-06,
         1.20795853e-06, 1.20795953e-06, 1.20795953e-06, 1.20795853e-06,
         1.20795807e-06, 1.20795933e-06, 1.20795874e-06, 1.20795844e-06,
         1.20795863e-06, 1.20795870e-06, 1.20795824e-06, 1.20795817e-06,
         1.20795870e-06, 1.20795843e-06, 1.20795816e-06, 1.20795790e-06,
         1.20795762e-06, 1.20795816e-06, 1.20795809e-06, 1.20795761e-06,
         1.20795769e-06, 1.20795787e-06, 1.20795755e-06, 1.20795702e-06,
         1.20795827e-06, 1.20795773e-06, 1.20795675e-06, 1.20795675e-06,
         1.20795773e-06, 1.20795827e-06, 1.20795702e-06, 1.20795755e-06,
         1.20795787e-06, 1.20795769e-06, 1.20795761e-06, 1.20795809e-06,
         1.20795816e-06, 1.20795762e-06, 1.20795790e-06, 1.20795816e-06,
         1.20795843e-06, 1.20795870e-06, 1.20795817e-06])],
 [np.array([ 1.08526312e-14,  1.51219131e-13,  6.53869746e-13,  4.82565778e-13,
          2.06279047e-13,  3.90508894e-13,  5.03956189e-13, -2.64553703e-14,
          9.00902473e-14,  1.08997972e-13, -1.08997973e-13, -9.00902481e-14,
          2.64553694e-14, -5.03956190e-13, -3.90508894e-13, -2.06279048e-13,
         -4.82565779e-13, -6.53869747e-13, -1.51219132e-13, -1.08526321e-14,
         -1.60756649e-12, -1.65956144e-12, -1.46937775e-12, -1.65691267e-12,
         -1.61379219e-12, -8.90127026e-15, -1.28152746e-13, -6.68382397e-13,
         -4.89338827e-13, -2.17294057e-13, -4.09009396e-13, -4.92989245e-13,
          3.05560468e-14, -1.06465038e-13, -1.12365467e-13,  1.12365466e-13,
          1.06465037e-13, -3.05560477e-14,  4.92989244e-13,  4.09009395e-13,
          2.17294056e-13,  4.89338826e-13,  6.68382396e-13,  1.28152745e-13,
          8.90126942e-15,  1.61379219e-12,  1.65691267e-12,  1.46937775e-12,
          1.65956144e-12,  1.60756649e-12,  1.08526312e-14])])

# %%
plt.plot(ra[0], dec[0])
# plt.plot(1.2079332096400056e-06, -4.235164736271502e-22)

# %%
from scipy import interpolate
ra_new = np.linspace(ra[0].min(), ra[0].max(), 1000)

# Perform the interpolation
f = interpolate.interp1d(ra[0], dec[0], kind='cubic')
dec_smooth = f(ra_new)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 5
#       2 ra_new = np.linspace(ra[0].min(), ra[0].max(), 1000)
#       4 # Perform the interpolation
# ----> 5 f = interpolate.interp1d(ra[0], dec[0], kind='cubic')
#       6 dec_smooth = f(ra_new)
#
# File ~/.conda/envs/wolensing/lib/python3.10/site-packages/scipy/interpolate/_interpolate.py:630, in interp1d.__init__(***failed resolving arguments***)
#     627         yy = np.ones_like(self._y)
#     628         rewrite_nan = True
# --> 630 self._spline = make_interp_spline(xx, yy, k=order,
#     631                                   check_finite=False)
#     632 if rewrite_nan:
#     633     self._call = self.__class__._call_nan_spline
#
# File ~/.conda/envs/wolensing/lib/python3.10/site-packages/scipy/interpolate/_bsplines.py:1385, in make_interp_spline(x, y, k, t, bc_type, axis, check_finite)
# ...

# %%
ra = ra[0]
dec = dec[0]

plt.plot(ra, dec, '-o', markersize=4, linewidth=1, color='blue', label='Data points')

# %%
plt.scatter(ra, dec)
plt.plot(1.2079332096400056e-06, -4.235164736271502e-22, markersize = 10)
