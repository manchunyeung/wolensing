# %%
import numpy as np

# %%
# %env JAX_ENABLE_X64=True
# Out:
# env: JAX_ENABLE_X64=True

# %%
from lenstronomy.LensModel.lens_model import LensModel
import lensinggw.constants.constants as const
from lensinggw.utils.utils import TimeDelay, magnifications, getMinMaxSaddle

# %%
import sys
import os
path = os.getcwd()
dir = os.path.abspath(os.path.join(path, os.pardir))
sys.path.append(dir)

# %%
from wolensing.plot.plot import plot_contour
import wolensing.amplification_factor.amplification_factor as af
from wolensing.lensmodels.potential import potential

# %% [markdown]
# The macroimage where the microlens is placed around.

# %%
type2 = False

# %%
ym = 0.8
angle = np.radians(float(0))

# %% [markdown]
# Importing constants

# %%
G = const.G  # gravitational constant [m^3 kg^-1 s^-2]
c = const.c  # speed of light [m/s]
M_sun = const.M_sun  # Solar mass [Kg]

# %%
y0, y1 = 0.5, 0 # source position
l0, l1 = 0., 0 # lens position

zS = 1.0 # source redshift
zL = 0.5 # lens redshift

# %%
mL1 = 1e10
mL2 = 20
mtot = mL1 + mL2

# convert to radians
from lensinggw.utils.utils import param_processing
thetaE1 = param_processing(zL, zS, mL1)
thetaE2 = param_processing(zL, zS, mL2)
thetaE = param_processing(zL, zS, mtot)

# %%
thetaE
# Out:
# 8.052888069635299e-07

# %%
Mpc=3.085677581491367e+22
from astropy.cosmology import FlatLambdaCDM
cosmo = FlatLambdaCDM(H0=69.7, Om0=0.306, Tcmb0=2.725)
DL       = cosmo.angular_diameter_distance(zL)
DS       = cosmo.angular_diameter_distance(zS)
DLS      = cosmo.angular_diameter_distance_z1z2(zL, zS)
D        = DLS/(DL*DS)
print(np.float64(D/Mpc))
# Out:
# 1.097926071881248e-26

# %%
from wolensing.utils.utils import Einstein_radius

# %%
Einstein_radius(zL, zS, mtot)
# Out:
# 141457.81166301022

# %%
beta0, beta1 = y0 * thetaE, y1 * thetaE
eta10, eta11 = 0 * l0 * thetaE, 0 * l1 * thetaE
lens_model_list = ['SIS']
kwargs_sis_1 = {'center_x': eta10, 'center_y': eta11, 'theta_E': thetaE1}
kwargs_lens_list = [kwargs_sis_1]

kwargs_sis_1_scaled = {'center_x': eta10 / thetaE, 'center_y': eta11 / thetaE, 'theta_E': thetaE1 / thetaE}
kwargs_lens_list_scaled = [kwargs_sis_1_scaled]

from lensinggw.solver.images import microimages
solver_kwargs = {'SearchWindowMacro': 10 * thetaE1,
                 'SearchWindow': 5 * thetaE2,
                 'OverlapDistMacro': 1e-17,
                 'OnlyMacro': True}
MacroImg_ra, MacroImg_dec, pixel_width = microimages(source_pos_x=beta0,
                                                     source_pos_y=beta1,
                                                     lens_model_list=lens_model_list,
                                                     kwargs_lens=kwargs_lens_list,
                                                     **solver_kwargs)

Td = TimeDelay(MacroImg_ra, MacroImg_dec,
                beta0, beta1,
                zL, zS,
                lens_model_list, kwargs_lens_list)
Mus = magnifications(MacroImg_ra, MacroImg_dec, lens_model_list, kwargs_lens_list)
if type2:
    microtype = np.nonzero(Td)[0][0]
else:
    microtype = np.where(Td==0)[0][0]

# masses = np.linspace(0.5, 3, 6)
masses = np.full(10, 30 / 10)
print('masses: ', masses)
angle = [0, 150, 260]
ym = [1., .4, 4.]

# num_points = len(masses)
# for j in range(0,num_points):
#     theta_E = param_processing(zL, zS, masses[j])# lens model
#     #positioning the microlenses
#     eta20 = MacroImg_ra[microtype] + ym[j]*np.cos(np.radians(angle[j])) * theta_E
#     eta21 = MacroImg_dec[microtype] + ym[j] * np.sin(np.radians(angle[j])) * theta_E
#     lens_model_list.append('POINT_MASS')
#     kwargs_lens_list.append({'center_x': eta20, 'center_y': eta21, 'theta_E': theta_E})

mass_density = 200
from utils.lensing import *
radius = injection_radius(masses, mass_density) #rad
lens_model_list, kwargs_lens_list = field_injection(zL, zS, MacroImg_ra[microtype], MacroImg_dec[microtype], masses, radius, lens_model_list, kwargs_lens_list, seed=2)
    
# Injecting microlens around desired macroimage
# eta20, eta21 = MacroImg_ra[microtype] + np.cos(angle)*ym*thetaE2, MacroImg_dec[microtype] + np.sin(angle)*ym*thetaE2
# lens_model_list = ['SIS', 'POINT_MASS']
# kwargs_sis_1 = {'center_x': eta10, 'center_y': eta11, 'theta_E': thetaE1}
# kwargs_point_mass_2 = {'center_x': eta20, 'center_y': eta21, 'theta_E': thetaE2}
# kwargs_lens_list = [kwargs_sis_1, kwargs_point_mass_2]

from lensinggw.solver.images import microimages
solver_kwargs = {'SearchWindowMacro': 10 * thetaE1,
                 'SearchWindow': 20 * thetaE2,
                 'Pixels': 9*1e3,
                 'Optimization': True ,
                 'Verbose': True,
                 'OverlapDist': 1e-18,
                 'OverlapDistMacro': 1e-17}
solver_kwargs.update({'Improvement' : 0.1})
solver_kwargs.update({'MinDist' : 10**(-7)})

Img_ra, Img_dec, MacroImg_ra, MacroImg_dec, pixel_width = microimages(source_pos_x=beta0,
                                                                      source_pos_y=beta1,
                                                                      lens_model_list=lens_model_list,
                                                                      kwargs_lens=kwargs_lens_list,
                                                                      **solver_kwargs)
# Images_dict = {'Source_ra': beta0,
#                'Source_dec': beta1,
#                'Img_ra': Img_ra,
#                'Img_dec': Img_dec,
#                'MacroImg_ra': MacroImg_ra,
#                'MacroImg_dec': MacroImg_dec,
#                'Microlens_ra': [eta20],
#                'Microlens_dec': [eta21],
#                'thetaE': thetaE}

# time delays, magnifications, Morse indices 
from lensinggw.utils.utils import TimeDelay, magnifications, getMinMaxSaddle
from lensinggw.amplification_factor.amplification_factor import geometricalOpticsMagnification
tds = TimeDelay(Img_ra, Img_dec,
               beta0, beta1,
               zL, zS,
               lens_model_list, kwargs_lens_list)
mus = magnifications(Img_ra, Img_dec, lens_model_list, kwargs_lens_list)
ns = getMinMaxSaddle(Img_ra, Img_dec, lens_model_list, kwargs_lens_list, diff = None)
print('Time delays (seconds): ', tds)
print('magnifications: ', mus)
print('Morse indices: ', ns)
    
lens_model_complete = LensModel(lens_model_list=lens_model_list)
T = lens_model_complete.fermat_potential
T0 = thetaE ** (-2) * T(Img_ra[microtype], Img_dec[microtype], kwargs_lens_list, beta0, beta1)#[0]
if not isinstance(T0, float):
    T0 = T0[0]
Tscale = 4 * (1 + zL) * mtot * M_sun * G / c ** 3
print('T0 = {}'.format(T0))
print('Tscale = {}'.format(Tscale))
# Out:
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:107: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:107: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:108: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:117: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:117: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:146: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:171: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:171: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:178: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:178: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:182: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:182: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:392: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:392: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:397: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:397: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:398: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:403: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:403: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:408: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:408: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:107: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:107: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:108: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:117: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:117: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:146: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:171: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:171: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:178: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:178: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:182: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:182: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:392: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:392: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:397: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:397: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:398: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:403: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:403: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:408: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:408: SyntaxWarning: "is" with a literal. Did you mean "=="?
# ---- Will perform only the macromodel analysis ----
#
# ---- Solver settings ----
#
# The macromodel analysis will be performed with the following settings:
#
# OnlyMacro         --> True
# Scaled            --> False
# SearchWindowMacro --> 8.052888061582412e-06
# PixelsMacro       --> 1000
# PrecisionLimit    --> 1e-20
# OverlapDistMacro  --> 1e-17
# NearSource        --> False
# Optimization      --> False
# Verbose           --> False
#
#
#
#
# MACROIMAGES
#
# ra: [-4.02644403e-07  1.20793321e-06]
# dec: [-4.23516474e-22 -4.23516474e-22]
#
# masses:  [3. 3. 3. 3. 3. 3. 3. 3. 3. 3.]
#
# ---- Solver settings ----
#
# The macromodel analysis will be performed with the following settings:
#
# OnlyMacro                       --> False
# Scaled                          --> False
# SearchWindowMacro               --> 8.052888061582412e-06
# PixelsMacro                     --> 1000
# OverlapDistMacro                --> 1e-17
# NearSource                      --> False
# Optimization                    --> True
# Verbose                         --> True
# OptimizationWindowMacro         --> 2
# OptimizationPixelsMacro         --> 30
# MinDistMacro                    --> None
# ImprovementMacro                --> None
# OptimizationPrecisionLimitMacro --> 1e-20
#
#
# ---- Macromodel analysis ----
#
# Interesting regions of the first grid (no iteration yet):
#
# ra:
# [-4.06670847e-07  1.20390677e-06]
# dec:
# [4.02644403e-09 4.02644403e-09]
# pixel_width:
# 8.052888061582012e-09
#
#
# Iteration # 0
#
# Pixels to iterate over, RAs:
# [-4.066708467072679e-07, 1.2039067656092146e-06]
# Pixels to iterate over, DECs:
# [4.026444030790582e-09, 4.026444030790582e-09]
# Pixels to iterate over, source displacements:
# [5.666135983470095e-09, 4.237143739907385e-09]
#
#
#
# Pixel size of the last iteration: 5.368592041055239e-10
#
#
#
#
# MACROIMAGES
#
# ra: [-4.02644403e-07  1.20793321e-06]
# dec: [-4.23516474e-22 -4.23516474e-22]
#
# Elapsed time: 0.2773008346557617 seconds
#
#
# ---- Solver settings ----
#
# The complete model analysis will be performed with the following settings:
#
# Scaled                          --> False
# OnlyMacro                       --> False
# MacroIndex                      --> [0]
# ImgIndex                        --> None
# SearchWindow                    --> 7.202722048357913e-10
# Pixels                          --> 9000.0
# OverlapDist                     --> 1e-18
# Optimization                    --> True
# Verbose                         --> True
# Improvement                     --> 0.1
# MinDist                         --> 1e-07
# OptimizationWindow              --> 2
# OptimizationPixels              --> 30
# OptimizationPrecisionLimit      --> 1e-20
#
#
# ---- Complete model analysis ----
#
#
# Interesting regions of the first grid (no iteration yet):
#
# ra:
# [-4.02644443e-07]
# dec:
# [4.00151221e-14]
# pixel_width:
# 8.003024497800975e-14
#
#
# Iteration # 0
#
# Pixels to iterate over, RAs:
# [-4.0264444269159936e-07]
# Pixels to iterate over, DECs:
# [4.001512206734956e-14]
# Pixels to iterate over, source displacements:
# [5.5742293999063895e-14]
#
#
#
# Pixel size of the last iteration: 5.335349679317866e-15
#
#
# Iteration # 1
#
# Pixels to iterate over, RAs:
# [-4.0264440267647687e-07]
# Pixels to iterate over, DECs:
# [-4.216553235597931e-22]
# Pixels to iterate over, source displacements:
# [1.2079530513012023e-15]
#
#
#
# Pixel size of the last iteration: 3.5568999273840685e-16
#
#
# Iteration # 2
#
# Pixels to iterate over, RAs:
# [-4.026444039213918e-07]
# Pixels to iterate over, DECs:
# [1.778445676552716e-16]
# Pixels to iterate over, source displacements:
# [1.816113810057787e-16]
#
#
#
# Pixel size of the last iteration: 2.3712634418824935e-17
#
#
# Iteration # 3
#
# Pixels to iterate over, RAs:
# [-4.026444038858228e-07]
# Pixels to iterate over, DECs:
# [-4.287139317970621e-22]
# Pixels to iterate over, source displacements:
# [1.3932176302263347e-18]
#
#
#
# Pixel size of the last iteration: 1.5808281773725414e-18
#
#
# Iteration # 4
#
# Pixels to iterate over, RAs:
# [-4.026444038850324e-07]
# Pixels to iterate over, DECs:
# [7.899924333623689e-19]
# Pixels to iterate over, source displacements:
# [9.664481739145599e-19]
#
#
#
# Pixel size of the last iteration: 1.05402662373957e-19
#
#
# Iteration # 5
#
# Pixels to iterate over, RAs:
# [-4.0264440388445274e-07]
# Pixels to iterate over, DECs:
# [-4.2165532390193455e-22]
# Pixels to iterate over, source displacements:
# [4.141766448789326e-20]
#
#
#
# Pixel size of the last iteration: 7.040961374051372e-21
#
#
# Interesting regions of the first grid (no iteration yet):
#
# ra:
# [1.20786738e-06 1.20794189e-06 1.20790588e-06 1.20792461e-06
#  1.20802600e-06 1.20789884e-06 1.20794854e-06 1.20784930e-06
#  1.20783193e-06 1.20786498e-06 1.20788547e-06 1.20797719e-06]
# dec:
# [-5.86221544e-11 -4.30162567e-11 -3.88146688e-12  1.43654290e-11
#   1.50857012e-11  1.59660339e-11  2.95711755e-11  3.55734439e-11
#   4.23760147e-11  1.20405504e-10  1.41293398e-10  1.44574638e-10]
# pixel_width:
# 8.003024487213063e-14
#
#
# Iteration # 0
#
# Pixels to iterate over, RAs:
# [1.207867384763508e-06, 1.207941892921586e-06, 1.2079058793113443e-06, 1.20792460638867e-06, 1.2080260047090619e-06, 1.207898836649786e-06, 1.2079485354319196e-06, 1.2078492979281422e-06, 1.2078319313649812e-06, 1.2078649838561587e-06, 1.207885471598874e-06, 1.207977186259623e-06]
# Pixels to iterate over, DECs:
# [-5.862215444955875e-11, -4.30162566781166e-11, -3.881466882038607e-12, 1.4365428973801422e-11, 1.5085701178637217e-11, 1.5966033873436528e-11, 2.9571175520334805e-11, 3.5573443893966416e-11, 4.2376014717415554e-11, 1.2040550357462624e-10, 1.412933975148642e-10, 1.4457463755911615e-10]
# Pixels to iterate over, source displacements:
# [5.607890927282222e-13, 2.5502965107885808e-14, 2.446584747834206e-13, 1.7232789981043383e-13, 1.2469447621443576e-12, 1.694495624035055e-13, 3.161241671163496e-12, 8.512057517647379e-13, 1.4466376983508243e-12, 7.963335877878382e-13, 6.994043836286509e-13, 5.588768999677781e-13]
#
#
#
# Pixel size of the last iteration: 5.335349785196984e-15
#
#
# Iteration # 1
#
# Pixels to iterate over, RAs:
# [1.2078673981018822e-06, 1.2079419222660091e-06, 1.2079058392962218e-06, 1.2079246303977435e-06, 1.2080259753646388e-06, 1.2078988446528106e-06, 1.207948559440993e-06, 1.2078492792544185e-06, 1.2078319073559077e-06, 1.2078649971945329e-06, 1.2078854796018985e-06, 1.2079771622505495e-06]
# Pixels to iterate over, DECs:
# [-5.864616352302038e-11, -4.2981576905338674e-11, -3.91614665481653e-12, 1.4400108746579345e-11, 1.5061692105175577e-11, 1.5931354100658604e-11, 2.956850784550573e-11, 3.558144691845363e-11, 4.240535914053534e-11, 1.20434847997746e-10, 1.4133341263730027e-10, 1.4454529313599637e-10]
# Pixels to iterate over, source displacements:
# [5.162487278051434e-14, 9.1179156442278e-16, 9.339197994432804e-15, 9.628064577420675e-15, 9.820496856848212e-14, 6.931448991219428e-15, 3.1611295440243265e-12, 6.85199322276297e-14, 7.787175955645319e-14, 5.809951631647009e-14, 5.0820182145989897e-14, 4.7533495414401914e-14]
#
#
#
# Pixel size of the last iteration: 3.5569009861752526e-16
#
#
# Iteration # 2
#
# Pixels to iterate over, RAs:
# [1.2078673975683472e-06, 1.207941923155234e-06, 1.2079058387626868e-06, 1.2079246305755884e-06, 1.2080259780323136e-06, 1.2078988458977256e-06, 1.207948561041598e-06, 1.207948560685908e-06, 1.2078492776538135e-06, 1.2078319053996127e-06, 1.207864995593928e-06, 1.2078854819138834e-06, 1.2079771638511544e-06]
# Pixels to iterate over, DECs:
# [-5.864883119791298e-11, -4.297926492043176e-11, -3.918102949737769e-12, 1.4397441071686746e-11, 1.5062225640154096e-11, 1.5931887635637123e-11, 2.9563706030699057e-11, 2.9564417410670413e-11, 3.558091338347511e-11, 4.240553698552818e-11, 1.2043680429266724e-10, 1.413318120323647e-10, 1.445476051209033e-10]
# Pixels to iterate over, source displacements:
# [2.897317100597303e-15, 2.693437103033089e-17, 9.404602432147161e-16, 8.706014206255771e-16, 3.155277430563471e-15, 7.232492989370484e-16, 3.16112910845844e-12, 3.1611291135722512e-12, 6.219501452238508e-15, 5.492204652980514e-15, 5.1158289934337975e-15, 1.7440594890390941e-15, 2.5791864491716087e-15]
#
#
#
# Pixel size of the last iteration: 2.3712687358384138e-17
#
#
# Iteration # 3
#
# Pixels to iterate over, RAs:
# [1.2078673974379274e-06, 1.207941923119665e-06, 1.2079058389168193e-06, 1.2079246304688813e-06, 1.2080259780204572e-06, 1.2078988457910185e-06, 1.2079485609586036e-06, 1.2079485609348909e-06, 1.2078492776182445e-06, 1.2078319052454802e-06, 1.2078649957480604e-06, 1.2078854818546017e-06, 1.2079771638630107e-06]
# Pixels to iterate over, DECs:
# [-5.864877191622988e-11, -4.297930048944162e-11, -3.9181622314208716e-12, 1.4397618916736055e-11, 1.506230863451044e-11, 1.5931780928607538e-11, 2.9563812737728645e-11, 2.956386016307513e-11, 3.558075925109904e-11, 4.24055488418648e-11, 1.2043667387296442e-10, 1.4133187131404782e-10, 1.4454775925327936e-10]
# Pixels to iterate over, source displacements:
# [2.211936188832462e-16, 3.413111871646362e-18, 3.446372415082065e-17, 2.6852409253624707e-17, 2.5165613496147034e-16, 5.4888680861390595e-17, 3.16112910773209e-12, 3.161129107753129e-12, 5.191638312642108e-16, 2.3021046397403464e-16, 8.713557646402185e-17, 2.0491290962871803e-16, 2.1583577207308257e-16]
#
#
#
# Pixel size of the last iteration: 1.580775237813338e-18
#
#
# Iteration # 4
#
# Pixels to iterate over, RAs:
# [1.2078673974323943e-06, 1.207941923123617e-06, 1.2079058389207713e-06, 1.2079246304696718e-06, 1.208025978018086e-06, 1.207898845799713e-06, 1.207948560948328e-06, 1.2079485609530705e-06, 1.2079485609672982e-06, 1.2079485609435855e-06, 1.207948560948328e-06, 1.2079485609530705e-06, 1.2079485609562323e-06, 1.2079485609372622e-06, 1.2079485609657174e-06, 1.2079485609720407e-06, 1.207948560959394e-06, 1.2079485609767832e-06, 1.2079485609815258e-06, 1.2079485609435855e-06, 1.2079485609546515e-06, 1.2079485609657174e-06, 1.2079485609688791e-06, 1.2079485609736217e-06, 1.2079485609372622e-06, 1.207948560940424e-06, 1.207948560957813e-06, 1.2079485609625556e-06, 1.2079485609783642e-06, 1.2079485609625556e-06, 1.2079485609688791e-06, 1.207948560979945e-06, 1.207948560940424e-06, 1.2079485609467472e-06, 1.207948560949909e-06, 1.2079485609546515e-06, 1.2079485609720407e-06, 1.2079485609752025e-06, 1.2079485609356814e-06, 1.207948560957813e-06, 1.2079485609641366e-06, 1.2079485609420047e-06, 1.2079485609625556e-06, 1.207948560938843e-06, 1.2079485609514898e-06, 1.2079485609657174e-06, 1.2079485609783642e-06, 1.2079485609451665e-06, 1.2079485609546515e-06, 1.2079485609688791e-06, 1.2079485609372622e-06, 1.2079485609420047e-06, 1.207948560957813e-06, 1.2079485609609748e-06, 1.2079485609546515e-06, 1.2079485609736217e-06, 1.2079485609372622e-06, 1.2079485609657174e-06, 1.2079485609530705e-06, 1.2079485609562323e-06, 1.2079485609752025e-06, 1.207948560979945e-06, 1.207948560948328e-06, 1.2079485609672982e-06, 1.2079485609720407e-06, 1.2079485609356814e-06, 1.207948560940424e-06, 1.2079485609435855e-06, 1.2079485609783642e-06, 1.207948560949909e-06, 1.2079485609546515e-06, 1.2079485609609748e-06, 1.2079485609641366e-06, 1.2079485609435855e-06, 1.2079485609467472e-06, 1.2079485609356814e-06, 1.207948560938843e-06, 1.2079485609546515e-06, 1.207948560959394e-06, 1.2079485609641366e-06, 1.2079485609514898e-06, 1.2079485609752025e-06, 1.2079485609435855e-06, 1.2079485609341004e-06, 1.2079485609372622e-06, 1.207948560918292e-06, 1.2079485609214538e-06, 1.207948560948328e-06, 1.2079485609514898e-06, 1.2079485609356814e-06, 1.2079485609435855e-06, 1.207948560927777e-06, 1.207948560940424e-06, 1.207948560957813e-06, 1.207948560918292e-06, 1.2079485609151302e-06, 1.2079485609214538e-06, 1.2079485609325196e-06, 1.2079485609356814e-06, 1.2079485609420047e-06, 1.2079485609546515e-06, 1.2079485609246153e-06, 1.207948560927777e-06, 1.2079485609467472e-06, 1.207948560957813e-06, 1.2079485609372622e-06, 1.2079485609435855e-06, 1.2079485609514898e-06, 1.207948560918292e-06, 1.2079485609261963e-06, 1.207948560940424e-06, 1.2079485609562323e-06, 1.2079485609214538e-06, 1.2079485609293579e-06, 1.207948560948328e-06, 1.2079485609356814e-06, 1.207948560940424e-06, 1.2079485609451665e-06, 1.2079485609546515e-06, 1.2079485609135495e-06, 1.2079485609514898e-06, 1.2079485609167112e-06, 1.2079485609198728e-06, 1.2079485609356814e-06, 1.207948560940424e-06, 1.207948560948328e-06, 1.2079485609546515e-06, 1.2079485609325196e-06, 1.207948560957813e-06, 1.2079485609151302e-06, 1.2079485609246153e-06, 1.207948560938843e-06, 1.2079485609435855e-06, 1.2079485609467472e-06, 1.2079485609309388e-06, 1.2079485609167112e-06, 1.2079485609246153e-06, 1.207948560948328e-06, 1.2079485609514898e-06, 1.207948560957813e-06, 1.2079485609214538e-06, 1.2079485609293579e-06, 1.2079485609341004e-06, 1.2079485609372622e-06, 1.207948560940424e-06, 1.2079485609435855e-06, 1.2079485609562323e-06, 1.2079485609293579e-06, 1.207948560948328e-06, 1.2079485609530705e-06, 1.2079485609167112e-06, 1.2079485609214538e-06, 1.2079485609356814e-06, 1.2079485609435855e-06, 1.2079485609514898e-06, 1.2079485609119687e-06, 1.2079485609246153e-06, 1.207948560940424e-06, 1.2079485609546515e-06, 1.2079485609293579e-06, 1.2079485609435855e-06, 1.2079485609198728e-06, 1.2079485609467472e-06, 1.207948560949909e-06, 1.2079485609530705e-06, 1.2079485609356814e-06, 1.207948560938843e-06, 1.2079485609246153e-06, 1.20794856 ...
# Pixels to iterate over, DECs:
# [-5.864878219172774e-11, -4.297929337563541e-11, -3.918155117614664e-12, 1.4397611802929847e-11, 1.5062315748316647e-11, 1.5931784880722097e-11, 2.956379139631002e-11, 2.956379139631002e-11, 2.956379455800167e-11, 2.9563796138847494e-11, 2.9563796138847494e-11, 2.9563796138847494e-11, 2.9563796138847494e-11, 2.956379771969332e-11, 2.956379771969332e-11, 2.956379771969332e-11, 2.956379930053914e-11, 2.956379930053914e-11, 2.956379930053914e-11, 2.9563800881384965e-11, 2.9563800881384965e-11, 2.9563800881384965e-11, 2.9563800881384965e-11, 2.9563800881384965e-11, 2.956380246223079e-11, 2.956380246223079e-11, 2.956380246223079e-11, 2.956380246223079e-11, 2.956380404307661e-11, 2.956380562392244e-11, 2.956380562392244e-11, 2.956380720476826e-11, 2.956380878561408e-11, 2.956380878561408e-11, 2.956380878561408e-11, 2.956380878561408e-11, 2.956380878561408e-11, 2.956380878561408e-11, 2.956381036645991e-11, 2.956381036645991e-11, 2.956381036645991e-11, 2.9563813528151554e-11, 2.9563813528151554e-11, 2.956381510899738e-11, 2.956381510899738e-11, 2.956381510899738e-11, 2.956381510899738e-11, 2.9563816689843206e-11, 2.9563816689843206e-11, 2.9563816689843206e-11, 2.9563818270689026e-11, 2.9563818270689026e-11, 2.9563818270689026e-11, 2.9563818270689026e-11, 2.956381985153485e-11, 2.956381985153485e-11, 2.956382143238068e-11, 2.956382143238068e-11, 2.95638230132265e-11, 2.95638230132265e-11, 2.95638230132265e-11, 2.95638230132265e-11, 2.9563824594072324e-11, 2.9563824594072324e-11, 2.9563824594072324e-11, 2.956382617491815e-11, 2.956382617491815e-11, 2.956382617491815e-11, 2.956382617491815e-11, 2.956382775576397e-11, 2.956382775576397e-11, 2.956382775576397e-11, 2.956382775576397e-11, 2.9563829336609795e-11, 2.9563829336609795e-11, 2.956383091745562e-11, 2.956383091745562e-11, 2.956383091745562e-11, 2.956383091745562e-11, 2.956383091745562e-11, 2.956383249830144e-11, 2.956383249830144e-11, 2.956383407914727e-11, 2.9563838821656505e-11, 2.9563838821656505e-11, 2.956384040250233e-11, 2.956384040250233e-11, 2.956384040250233e-11, 2.956384040250233e-11, 2.956384198334815e-11, 2.956384198334815e-11, 2.9563843564193976e-11, 2.9563843564193976e-11, 2.9563843564193976e-11, 2.95638451450398e-11, 2.956384672588562e-11, 2.956384672588562e-11, 2.956384672588562e-11, 2.956384672588562e-11, 2.956384672588562e-11, 2.956384672588562e-11, 2.956384830673145e-11, 2.956384830673145e-11, 2.956384830673145e-11, 2.956384830673145e-11, 2.9563849887577274e-11, 2.9563849887577274e-11, 2.9563849887577274e-11, 2.9563851468423094e-11, 2.9563851468423094e-11, 2.9563851468423094e-11, 2.9563851468423094e-11, 2.956385304926892e-11, 2.956385304926892e-11, 2.956385304926892e-11, 2.9563854630114746e-11, 2.9563854630114746e-11, 2.9563854630114746e-11, 2.9563854630114746e-11, 2.9563856210960565e-11, 2.9563856210960565e-11, 2.956385779180639e-11, 2.956385779180639e-11, 2.956385779180639e-11, 2.956385779180639e-11, 2.956385779180639e-11, 2.956385779180639e-11, 2.956385937265222e-11, 2.956385937265222e-11, 2.956386095349804e-11, 2.956386095349804e-11, 2.956386095349804e-11, 2.956386095349804e-11, 2.956386095349804e-11, 2.956386253434386e-11, 2.956386411518969e-11, 2.956386411518969e-11, 2.956386411518969e-11, 2.956386411518969e-11, 2.956386411518969e-11, 2.956386569603551e-11, 2.956386569603551e-11, 2.956386569603551e-11, 2.956386569603551e-11, 2.956386569603551e-11, 2.9563867276881335e-11, 2.9563867276881335e-11, 2.956386885772716e-11, 2.956386885772716e-11, 2.956386885772716e-11, 2.956387043857298e-11, 2.956387043857298e-11, 2.956387043857298e-11, 2.9563872019418807e-11, 2.9563872019418807e-11, 2.956387360026463e-11, 2.956387360026463e-11, 2.956387360026463e-11, 2.956387360026463e-11, 2.956387518111045e-11, 2.956387518111045e-11, 2.956387676195628e-11, 2.956387676195628e-11, 2.956387676195628e-11, 2.956387676195628e-11, 2.9563878342802104e-11, 2.9563878342802104e-11, 2.9563879923647924e-11, 2.9563879923647924e-11, 2.9563879923647924e-11, 2.956388150449375e-11, 2.9563881504493 ...
# Pixels to iterate over, source displacements:
# [8.500201929768208e-18, 2.124331716873754e-19, 3.74720074295041e-18, 1.0681929633071501e-18, 9.463425482554718e-18, 2.126696785020901e-18, 3.161129107859912e-12, 3.161129107851535e-12, 3.161129107751029e-12, 3.161129107875088e-12, 3.161129107820318e-12, 3.161129107775757e-12, 3.161129107835921e-12, 3.1611291079921906e-12, 3.1611291077832515e-12, 3.1611291077739655e-12, 3.1611291078416227e-12, 3.161129107777402e-12, 3.161129107836936e-12, 3.1611291078741356e-12, 3.161129107779151e-12, 3.161129107768588e-12, 3.1611291077691442e-12, 3.161129107732582e-12, 3.1611291079464682e-12, 3.1611291078266834e-12, 3.1611291077835625e-12, 3.1611291077245447e-12, 3.1611291078204605e-12, 3.1611291077097383e-12, 3.1611291077920997e-12, 3.1611291078200247e-12, 3.1611291078535473e-12, 3.1611291078244688e-12, 3.161129107802282e-12, 3.1611291077718568e-12, 3.1611291077801746e-12, 3.1611291078344757e-12, 3.1611291079005258e-12, 3.1611291077820855e-12, 3.161129107735576e-12, 3.1611291077957134e-12, 3.1611291077176878e-12, 3.161129107773981e-12, 3.1611291077505327e-12, 3.1611291077161146e-12, 3.1611291078468023e-12, 3.161129107748575e-12, 3.1611291077713535e-12, 3.1611291077211362e-12, 3.1611291078117687e-12, 3.1611291078023975e-12, 3.161129107747207e-12, 3.161129107746263e-12, 3.161129107756971e-12, 3.161129107814995e-12, 3.1611291077880987e-12, 3.161129107740096e-12, 3.161129107781324e-12, 3.161129107736036e-12, 3.1611291078183982e-12, 3.1611291078946426e-12, 3.161129107754847e-12, 3.161129107774565e-12, 3.1611291077949375e-12, 3.161129107855397e-12, 3.1611291077286843e-12, 3.1611291077361588e-12, 3.1611291078864932e-12, 3.1611291077401202e-12, 3.1611291077659858e-12, 3.161129107758962e-12, 3.1611291077679123e-12, 3.161129107758992e-12, 3.1611291077439104e-12, 3.1611291077828234e-12, 3.1611291077459565e-12, 3.1611291077554222e-12, 3.161129107753962e-12, 3.16112910776271e-12, 3.1611291077525146e-12, 3.1611291078601434e-12, 3.1611291077349754e-12, 3.1611291077358704e-12, 3.1611291077125454e-12, 3.1611291078891206e-12, 3.161129107844032e-12, 3.1611291077247374e-12, 3.161129107762929e-12, 3.1611291077118135e-12, 3.1611291077355764e-12, 3.1611291078151166e-12, 3.1611291076719517e-12, 3.161129107756701e-12, 3.1611291078895757e-12, 3.1611291079229073e-12, 3.1611291078755658e-12, 3.1611291077489494e-12, 3.1611291077278345e-12, 3.1611291077280784e-12, 3.1611291077943046e-12, 3.1611291078165956e-12, 3.161129107785036e-12, 3.1611291077084482e-12, 3.161129107752103e-12, 3.161129107699435e-12, 3.161129107748008e-12, 3.161129107782388e-12, 3.1611291078403593e-12, 3.1611291078265424e-12, 3.161129107721482e-12, 3.161129107748851e-12, 3.161129107831009e-12, 3.1611291077792073e-12, 3.1611291077323125e-12, 3.161129107692945e-12, 3.1611291077110303e-12, 3.161129107739306e-12, 3.161129107746041e-12, 3.161129107874701e-12, 3.1611291076935675e-12, 3.1611291078204977e-12, 3.1611291077716403e-12, 3.1611291077211197e-12, 3.1611291077418776e-12, 3.1611291077647805e-12, 3.1611291077045026e-12, 3.16112910772947e-12, 3.161129107750892e-12, 3.1611291078931482e-12, 3.1611291077813997e-12, 3.1611291077304998e-12, 3.161129107760752e-12, 3.161129107763535e-12, 3.1611291076905027e-12, 3.1611291078586437e-12, 3.161129107805476e-12, 3.16112910775826e-12, 3.161129107769643e-12, 3.161129107794676e-12, 3.161129107795197e-12, 3.161129107721073e-12, 3.1611291076947206e-12, 3.1611291077268215e-12, 3.161129107763446e-12, 3.1611291077510367e-12, 3.161129107752179e-12, 3.161129107709255e-12, 3.1611291077964416e-12, 3.161129107813567e-12, 3.161129107820709e-12, 3.161129107811397e-12, 3.1611291077240294e-12, 3.1611291078270404e-12, 3.1611291078123022e-12, 3.161129107820195e-12, 3.1611291078038426e-12, 3.161129107711385e-12, 3.1611291078348905e-12, 3.161129107729106e-12, 3.161129107785234e-12, 3.1611291077489918e-12, 3.1611291077965826e-12, 3.1611291078530796e-12, 3.1611291078625466e-12, 3.161129107709564e-12, 3.1611291077397385e-12, 3.1611291077411667e-12, 3.1611291077569066e-12, 3.161129107886625e ...
#
#
#
# Pixel size of the last iteration: 1.0545560193316039e-19
#
#
# Iteration # 5
#
# Pixels to iterate over, RAs:
# [1.2078673974322364e-06, 1.207941923123459e-06, 1.2079058389211402e-06, 1.2079246304697245e-06, 1.2080259780181387e-06, 1.207898845800082e-06, 1.2078492776285728e-06, 1.2078319052511712e-06, 1.2078649957515381e-06, 1.207885481851756e-06, 1.2079771638543689e-06]
# Pixels to iterate over, DECs:
# [-5.864878182288019e-11, -4.2979293217557886e-11, -3.9181556972322515e-12, 1.4397612066392386e-11, 1.5062315484854106e-11, 1.5931784722644573e-11, 3.558075081990954e-11, 4.240555168736611e-11, 1.2043667482146485e-10, 1.4133188227454828e-10, 1.445477709515455e-10]
# Pixels to iterate over, source displacements:
# [8.597557665711916e-19, 3.5559136918220815e-20, 2.6798372920833664e-19, 3.1378018344839485e-20, 1.736212096095227e-18, 3.215023617113797e-19, 1.356719922972467e-18, 1.8495560945202872e-18, 1.1088121929057902e-18, 5.744886730613514e-19, 9.01888543084695e-19]
#
#
#
# Pixel size of the last iteration: 6.988021814847978e-21
#
#
# Iteration # 6
#
# Pixels to iterate over, RAs:
# [1.2078673974322188e-06, 1.207905838921179e-06, 1.208025978018093e-06, 1.2078988458000292e-06, 1.2078492776285974e-06, 1.2078319052511536e-06, 1.2078649957514924e-06, 1.2078854818517876e-06, 1.2079771638543231e-06]
# Pixels to iterate over, DECs:
# [-5.864878178421314e-11, -3.918155651534824e-12, 1.5062315474308545e-11, 1.5931784691007894e-11, 3.558075079530323e-11, 4.2405551641668683e-11, 1.2043667481794967e-10, 1.4133188228509385e-10, 1.4454777091287846e-10]
# Pixels to iterate over, source displacements:
# [5.022107014275562e-20, 1.7381140705735638e-20, 7.142036014517797e-20, 2.0668624370300113e-20, 1.3888530130425072e-19, 1.2169977661253697e-19, 8.696396830185555e-20, 3.5765049317976464e-20, 6.464660255163987e-20]
#
#
#
# Pixel size of the last iteration: 4.235164736271502e-22
#
#
#
#
# IMAGES OF THE COMPLETE MODEL
#
# ra: [-4.02644404e-07  1.20794192e-06  1.20792463e-06  1.20786740e-06
#   1.20790584e-06  1.20802598e-06  1.20789885e-06  1.20784928e-06
#   1.20783191e-06  1.20786500e-06  1.20788548e-06  1.20797716e-06]
# dec: [ 3.11991434e-20 -4.29792933e-11  1.43976121e-11 -5.86487818e-11
#  -3.91815565e-12  1.50623155e-11  1.59317847e-11  3.55807508e-11
#   4.24055516e-11  1.20436675e-10  1.41331882e-10  1.44547771e-10]
#
# Elapsed time: 200.94579434394836 seconds
#
# Time delays (seconds):  [2.95529453e+05 0.00000000e+00 3.78859288e-04 1.24832656e-03
#  5.18047251e-04 1.86337414e-03 6.56573218e-04 2.07080221e-03
#  2.73562461e-03 2.31091480e-03 2.11266993e-03 1.89186103e-03]
# magnifications:  [-1.00000000e+00  2.87685178e+00 -5.02613471e-02 -2.60805027e-03
#  -4.01987083e-02 -8.00505063e-04 -3.69233703e-02 -6.76021268e-04
#  -7.65566450e-04 -1.67269872e-03 -3.08180396e-03 -4.18986385e-03]
# Morse indices:  [0, 0, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5]
# T0 = -0.999999928997187
# Tscale = 295529.46212367347

# %%
# plot only the microimages around the desired macroimage
Img_ra = np.delete(Img_ra, [0])
Img_dec = np.delete(Img_dec, [0])

# %%
Img_ra, Img_dec
# Out:
# (array([1.20794192e-06, 1.20792463e-06, 1.20786740e-06, 1.20790584e-06,
#         1.20802598e-06, 1.20789885e-06, 1.20784928e-06, 1.20783191e-06,
#         1.20786500e-06, 1.20788548e-06, 1.20797716e-06]),
#  array([-4.29792933e-11,  1.43976121e-11, -5.86487818e-11, -3.91815565e-12,
#          1.50623155e-11,  1.59317847e-11,  3.55807508e-11,  4.24055516e-11,
#          1.20436675e-10,  1.41331882e-10,  1.44547771e-10]))

# %%
lens_model_complete = LensModel(lens_model_list=lens_model_list)
T = lens_model_complete.fermat_potential
T0 = thetaE ** (-2) * T(MacroImg_ra[microtype], MacroImg_dec[microtype], kwargs_lens_list, beta0, beta1)#[0]

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
plot_contour(ax, lens_model_list, eta10, eta11, 4*thetaE1, kwargs_lens_list, beta0, beta1, MacroImg_ra, MacroImg_dec,
                    T0 = T0, Tfac = (thetaE)**(-2), micro=False)
# Out:
# [-4.02644403e-07  1.20793321e-06] [-4.23516474e-22 -4.23516474e-22] Img_pos
# <Axes: >

# %%
fig1, ax1 = plt.subplots()
plot_contour(ax1, lens_model_list, MacroImg_ra[microtype], MacroImg_dec[microtype], 10*thetaE2, kwargs_lens_list, beta0, beta1, Img_ra, Img_dec,
                    T0 = T0, Tfac = (thetaE)**(-2), micro=True)
# Out:
# [1.20794192e-06 1.20792463e-06 1.20786740e-06 1.20790584e-06
#  1.20802598e-06 1.20789885e-06 1.20784928e-06 1.20783191e-06
#  1.20786500e-06 1.20788548e-06 1.20797716e-06] [-4.29792933e-11  1.43976121e-11 -5.86487818e-11 -3.91815565e-12
#   1.50623155e-11  1.59317847e-11  3.55807508e-11  4.24055516e-11
#   1.20436675e-10  1.41331882e-10  1.44547771e-10] Img_pos
# <Axes: >

# %%
Tscale = 4 * (1 + zL) * mtot * M_sun * G / c ** 3

# %%
# Define the characteristic WindowSize
mL3 = 10
thetaE3 = param_processing(zL, zS, mL3)

# %%
import time

# %%
kwargs_macro = {'source_pos_x': beta0,
                'source_pos_y': beta1,
                'theta_E': thetaE,
                'mu': np.abs(Mus[microtype]),
               }

kwargs_integrator = {'PixelNum': int(40000),
                     'PixelBlockMax': 2000,
                     'WindowSize': 2.*210*thetaE3,
                     'WindowCenterX': MacroImg_ra[microtype],
                     'WindowCenterY': MacroImg_dec[microtype],
                     'T0': T0,
                     'TimeStep': 1e-5/Tscale, 
                     'TimeMax': T0 + .7/Tscale,
                     'TimeMin': T0 - .5/Tscale,
                     'TimeLength': 1./Tscale,
                     'TExtend': 10/Tscale,
                     'LastImageT': .02/Tscale,
                     'Tbuffer': .1/Tscale,
                     'Tscale': Tscale}


amplification = af.amplification_factor(lens_model_list=lens_model_list, kwargs_lens=kwargs_lens_list, kwargs_macro=kwargs_macro, **kwargs_integrator)
ts, Ft = amplification.integrator(gpu=False)
ws, Fws = amplification.fourier()
amplification.plot_freq()
# Out:
# start
# Integrating...: 100%|██████████| 441/441 [36:14<00:00,  4.93s/it]
# [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 2.41025166e-22
#  2.40453169e-22 2.33088710e-22]
# 49978 1 shi
# total time 10.99999
# <Axes: xlabel='Frequency (Hz)', ylabel='$|F|/\\sqrt{\\mu}$'>

# %%
from wolensing.utils.utils import *
dt = amplification._kwargs_integrator['TimeStep']*amplification._Tscale
ts_extended, F_tilde_extended = F_tilde_extend(amplification._ts, amplification._F_tilde, amplification._kwargs_macro, amplification._kwargs_integrator)
F_tilde_apodized = coswindowback(F_tilde_extended, 50)
ws1, Fw1 = iwFourier(ts_extended*amplification._Tscale, F_tilde_apodized, dt)
from bisect import bisect_left
i = bisect_left(ws, 2*np.pi*freq_end)

ws1, Fws1 = ws1/(2*np.pi), Fw1
# Out:
# total time 10.99999
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 7
#       5 ws1, Fw1 = iwFourier(ts_extended*amplification._Tscale, F_tilde_apodized, dt)
#       6 from bisect import bisect_left
# ----> 7 i = bisect_left(ws, 2*np.pi*freq_end)
#       9 ws1, Fws1 = ws1/(2*np.pi), Fw1
#
# NameError: name 'freq_end' is not defined

# %%
ws1, Fws1 = amplification.fourier(freq_end = 4000)

# %%
plt.semilogx(ws1, np.abs(Fws1))

# %%
plt.semilogx(ws1, np.angle(Fws1))

# %%
plt.plot(ts, Ft)

# %%
amplification.plot_freq(smooth=False)

# %%
amplification.plot_freq(pha=True, smooth=False)

# %% [markdown]
# # Geometrical optics
# To get the geometrical optics around type 1 image, we need the magnifications, time delay and the image positions of the microimages

# %%
tds = TimeDelay(Img_ra, Img_dec,
               beta0, beta1,
               zL, zS,
               lens_model_list, kwargs_lens_list)
mus = magnifications(Img_ra, Img_dec, lens_model_list, kwargs_lens_list)
ns = getMinMaxSaddle(Img_ra, Img_dec, lens_model_list, kwargs_lens_list, diff = None)

# %%
mus

# %%
Img_dec

# %%
geofs, geoFws = amplification.geometrical_optics(mus, tds, Img_ra, Img_dec, upper_lim=4000)

# %%
plt.semilogx(geofs, np.abs(geoFws))

# %%
plt.semilogx(geofs, np.angle(geoFws))

# %% [markdown]
# ##### Full amplification factor concatenated with geometrical optics
# Given the computaional cost of the diffraction integral, we concatenate the result of wave optics at low frequency and geometrical optics at high frequency to obtain a full amplification factor with default upper bound of 3000Hz.

# %%
fullfs, fullFws = amplification.concatenate()
plt.semilogx(fullfs, np.abs(fullFws))

# %%
plt.semilogx(fullfs, np.angle(fullFws))

# %%
fac = np.sqrt(np.abs(Mus[microtype]))

# %%
plt.clf()
plt.rc('text', usetex=True)
plt.rc('font', family='serif')

# %%
from bisect import bisect_left
low_index = bisect_left(geofs, 1)
geofs = geofs[low_index:]
geoFws = geoFws[low_index:]
ws = ws[low_index:]
Fws = Fws[low_index:]

# %%
ww = geofs
plt.semilogx(geofs, (fac*np.exp(-ww*np.pi/188) + (1-np.exp(-ww*np.pi/188))*np.abs(geoFws))/fac, label='Approximation')
plt.semilogx(geofs, np.abs(geoFws)/fac,label=r'$F_{geo}$')
plt.semilogx(ws, np.abs(Fws)/fac, label=r'$F_{wave}$')
plt.semilogx(ws1, np.abs(Fws1)/fac, label=r'$F_{wave}$')
plt.ylabel(r'$|F|/\sqrt{\mu}$')
plt.xlabel(r'$f$')
plt.grid(which='both', alpha=0.5)
plt.legend()
plt.xlim(1, 4000)
# plt.savefig('./approx.png',bbox_inches='tight', dpi=300)

# %%
plt.semilogx(geofs, (1-np.exp(-geofs*np.pi/37.5))*np.angle(geoFws), label='Approximation')
plt.semilogx(geofs, np.angle(geoFws),label=r'$F_{geo}$')
plt.semilogx(ws, np.angle(Fws), label=r'$F_{wave}$')
plt.semilogx(ws1, np.angle(Fws1), label=r'$F_{wave1}$')
plt.ylabel(r'$args(F)$')
plt.xlabel(r'$f$')
plt.grid(which='both', alpha=0.5)
plt.legend()
plt.xlim(1, 4000)
# plt.savefig('./approx_ang.png',bbox_inches='tight', dpi=300)
# Out:
# (1, 4000)
