# %%
import numpy as np

# %%
# %env JAX_ENABLE_X64=True
# Out:
# env: JAX_ENABLE_X64=True

# %%
from lenstronomy.LensModel.lens_model import LensModel
import lensinggw.constants.constants as const
from lensinggw.utils.utils import TimeDelay, magnifications, getMinMaxSaddle

# %%
import sys
import os
path = os.getcwd()
dir = os.path.abspath(os.path.join(path, os.pardir))
sys.path.append(dir)

# %%
from plot.plot import plot_contour
import amplification_factor.amplification_factor as af
from lensmodels.potential import potential
from lensmodels.trip_d import total_triple_d

# %% [markdown]
# The macroimage where the microlens is placed around.

# %%
type2 = False

# %%
ym = 0.8
angle = np.radians(float(0))

# %% [markdown]
# Importing constants

# %%
G = const.G  # gravitational constant [m^3 kg^-1 s^-2]
c = const.c  # speed of light [m/s]
M_sun = const.M_sun  # Solar mass [Kg]

# %%
y0, y1 = 0.5, 0 # source position
l0, l1 = 0., 0 # lens position

zS = 1.0 # source redshift
zL = 0.5 # lens redshift

# %%
mL1 = 1e10
mL2 = 20
mtot = mL1 + mL2

# convert to radians
from lensinggw.utils.utils import param_processing
thetaE1 = param_processing(zL, zS, mL1)
thetaE2 = param_processing(zL, zS, mL2)
thetaE = param_processing(zL, zS, mtot)

# %%
thetaE
# Out:
# 8.052888069635299e-07

# %%
Mpc=3.085677581491367e+22
from astropy.cosmology import FlatLambdaCDM
cosmo = FlatLambdaCDM(H0=69.7, Om0=0.306, Tcmb0=2.725)
DL       = cosmo.angular_diameter_distance(zL)
DS       = cosmo.angular_diameter_distance(zS)
DLS      = cosmo.angular_diameter_distance_z1z2(zL, zS)
D        = DLS/(DL*DS)
print(np.float64(D/Mpc))
# Out:
# 1.097926071881248e-26

# %%
from utils.utils import Einstein_radius

# %%
Einstein_radius(zL, zS, mtot)
# Out:
# 1.097926071881248e-26
# 8.052888069635299e-07

# %%
beta0, beta1 = y0 * thetaE, y1 * thetaE
eta10, eta11 = 0 * l0 * thetaE, 0 * l1 * thetaE
lens_model_list = ['SIS']
kwargs_sis_1 = {'center_x': eta10, 'center_y': eta11, 'theta_E': thetaE1}
kwargs_lens_list = [kwargs_sis_1]

kwargs_sis_1_scaled = {'center_x': eta10 / thetaE, 'center_y': eta11 / thetaE, 'theta_E': thetaE1 / thetaE}
kwargs_lens_list_scaled = [kwargs_sis_1_scaled]

from lensinggw.solver.images import microimages
solver_kwargs = {'SearchWindowMacro': 10 * thetaE1,
                 'SearchWindow': 5 * thetaE2,
                 'OverlapDistMacro': 1e-17,
                 'OnlyMacro': True}
MacroImg_ra, MacroImg_dec, pixel_width = microimages(source_pos_x=beta0,
                                                     source_pos_y=beta1,
                                                     lens_model_list=lens_model_list,
                                                     kwargs_lens=kwargs_lens_list,
                                                     **solver_kwargs)

Td = TimeDelay(MacroImg_ra, MacroImg_dec,
                beta0, beta1,
                zL, zS,
                lens_model_list, kwargs_lens_list)
Mus = magnifications(MacroImg_ra, MacroImg_dec, lens_model_list, kwargs_lens_list)
if type2:
    microtype = np.nonzero(Td)[0][0]
else:
    microtype = np.where(Td==0)[0][0]

# masses = np.linspace(0.5, 3, 6)
masses = np.full(10, 50)
print('masses: ', masses)
angle = [0, 150, 260]
ym = [1., .4, 4.]

# num_points = len(masses)
# for j in range(0,num_points):
#     theta_E = param_processing(zL, zS, masses[j])# lens model
#     #positioning the microlenses
#     eta20 = MacroImg_ra[microtype] + ym[j]*np.cos(np.radians(angle[j])) * theta_E
#     eta21 = MacroImg_dec[microtype] + ym[j] * np.sin(np.radians(angle[j])) * theta_E
#     lens_model_list.append('POINT_MASS')
#     kwargs_lens_list.append({'center_x': eta20, 'center_y': eta21, 'theta_E': theta_E})

mass_density = 200
from utils.lensing import *
radius = injection_radius(masses, mass_density) #rad
lens_model_list, kwargs_lens_list = field_injection(zL, zS, MacroImg_ra[microtype], MacroImg_dec[microtype], masses, radius, lens_model_list, kwargs_lens_list, seed=2)

kwargs_lens_list[3]['center_x'] += .0001e-06
kwargs_lens_list[5]['center_x'] += .0001e-06
kwargs_lens_list[-1]['center_x'] += .0001e-06

print(kwargs_lens_list)

# Injecting microlens around desired macroimage
# eta20, eta21 = MacroImg_ra[microtype] + np.cos(angle)*ym*thetaE2, MacroImg_dec[microtype] + np.sin(angle)*ym*thetaE2
# lens_model_list = ['SIS', 'POINT_MASS']
# kwargs_sis_1 = {'center_x': eta10, 'center_y': eta11, 'theta_E': thetaE1}
# kwargs_point_mass_2 = {'center_x': eta20, 'center_y': eta21, 'theta_E': thetaE2}
# kwargs_lens_list = [kwargs_sis_1, kwargs_point_mass_2]

from lensinggw.solver.images import microimages
solver_kwargs = {'SearchWindowMacro': 10 * thetaE1,
                 'SearchWindow': 40 * thetaE2,
                 'Pixels': 10*1e3,
                 'Optimization': True ,
                 'Verbose': True,
                 'OverlapDist': 1e-18,
                 'OverlapDistMacro': 1e-17}
solver_kwargs.update({'Improvement' : 0.1})
solver_kwargs.update({'MinDist' : 10**(-7)})

Img_ra, Img_dec, MacroImg_ra, MacroImg_dec, pixel_width = microimages(source_pos_x=beta0,
                                                                      source_pos_y=beta1,
                                                                      lens_model_list=lens_model_list,
                                                                      kwargs_lens=kwargs_lens_list,
                                                                      **solver_kwargs)
# Images_dict = {'Source_ra': beta0,
#                'Source_dec': beta1,
#                'Img_ra': Img_ra,
#                'Img_dec': Img_dec,
#                'MacroImg_ra': MacroImg_ra,
#                'MacroImg_dec': MacroImg_dec,
#                'Microlens_ra': [eta20],
#                'Microlens_dec': [eta21],
#                'thetaE': thetaE}

# Img_ra, Img_dec = np.array([1.20796878e-06, 1.20766453e-06, 1.20782147e-06, 1.20789819e-06,
#         1.20831193e-06, 1.20779292e-06, 1.20759056e-06, 1.20765472e-06,
#         1.20773836e-06, 1.20811265e-06]), np.array([-1.75457727e-10, -2.39431399e-10, -1.59957089e-11,  5.87778019e-11,
#          6.14919175e-11,  6.50404693e-11,  1.45257339e-10,  4.91681151e-10,
#          5.76987367e-10,  5.90109028e-10])

# time delays, magnifications, Morse indices 
from lensinggw.utils.utils import TimeDelay, magnifications, getMinMaxSaddle
from lensinggw.amplification_factor.amplification_factor import geometricalOpticsMagnification
tds = TimeDelay(Img_ra, Img_dec,
               beta0, beta1,
               zL, zS,
               lens_model_list, kwargs_lens_list)
mus = magnifications(Img_ra, Img_dec, lens_model_list, kwargs_lens_list)
ns = getMinMaxSaddle(Img_ra, Img_dec, lens_model_list, kwargs_lens_list, diff = None)
print('Time delays (seconds): ', tds)
print('magnifications: ', mus)
print('Morse indices: ', ns)
    
lens_model_complete = LensModel(lens_model_list=lens_model_list)
T = lens_model_complete.fermat_potential
T0 = thetaE ** (-2) * T(Img_ra[microtype], Img_dec[microtype], kwargs_lens_list, beta0, beta1)#[0]
if not isinstance(T0, float):
    T0 = T0[0]
Tscale = 4 * (1 + zL) * mtot * M_sun * G / c ** 3
print('T0 = {}'.format(T0))
print('Tscale = {}'.format(Tscale))
# Out:
# ---- Will perform only the macromodel analysis ----
#
# ---- Solver settings ----
#
# The macromodel analysis will be performed with the following settings:
#
# OnlyMacro         --> True
# Scaled            --> False
# SearchWindowMacro --> 8.052888061582412e-06
# PixelsMacro       --> 1000
# PrecisionLimit    --> 1e-20
# OverlapDistMacro  --> 1e-17
# NearSource        --> False
# Optimization      --> False
# Verbose           --> False
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:107: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:107: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:108: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:117: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:117: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:146: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:171: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:171: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:178: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:178: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:182: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:182: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:392: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:392: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:397: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:397: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:398: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:403: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:403: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:408: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:408: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:107: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:107: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:108: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:117: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:117: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:146: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:171: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:171: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:178: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:178: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:182: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:182: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:392: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:392: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:397: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:397: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:398: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:403: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:403: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:408: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:408: SyntaxWarning: "is" with a literal. Did you mean "=="?
# MACROIMAGES
#
# ra: [-4.02644403e-07  1.20793321e-06]
# dec: [-4.23516474e-22 -4.23516474e-22]
#
# masses:  [50 50 50 50 50 50 50 50 50 50]
# [{'center_x': 0.0, 'center_y': 0.0, 'theta_E': 8.052888061582411e-07}, {'center_x': 1.2075291249727151e-06, 'center_y': 1.7187208168305127e-10, 'theta_E': 5.694251756481115e-11}, {'center_x': 1.2083023403930624e-06, 'center_y': 6.066873904061287e-11, 'theta_E': 5.694251756481115e-11}, {'center_x': 1.207942661258282e-06, 'center_y': -2.920879847653598e-11, 'theta_E': 5.694251756481115e-11}, {'center_x': 1.2075996998587334e-06, 'center_y': 1.4352118634992688e-10, 'theta_E': 5.694251756481115e-11}, {'center_x': 1.2079188014775676e-06, 'center_y': 6.255255437758455e-11, 'theta_E': 5.694251756481115e-11}, {'center_x': 1.2076647161901614e-06, 'center_y': 4.859632951138786e-10, 'theta_E': 5.694251756481115e-11}, {'center_x': 1.2081029238311462e-06, 'center_y': 5.793826952113711e-10, 'theta_E': 5.694251756481115e-11}, {'center_x': 1.2076774103292062e-06, 'center_y': -2.3801596797922155e-10, 'theta_E': 5.694251756481115e-11}, {'center_x': 1.2077495025880851e-06, 'center_y': 5.695944127270033e-10, 'theta_E': 5.694251756481115e-11}, {'center_x': 1.2080272675231435e-06, 'center_y': 5.5991876601784975e-11, 'theta_E': 5.694251756481115e-11}]
#
# ---- Solver settings ----
#
# The macromodel analysis will be performed with the following settings:
#
# OnlyMacro                       --> False
# Scaled                          --> False
# SearchWindowMacro               --> 8.052888061582412e-06
# PixelsMacro                     --> 1000
# OverlapDistMacro                --> 1e-17
# NearSource                      --> False
# Optimization                    --> True
# Verbose                         --> True
# OptimizationWindowMacro         --> 2
# OptimizationPixelsMacro         --> 30
# MinDistMacro                    --> None
# ImprovementMacro                --> None
# OptimizationPrecisionLimitMacro --> 1e-20
#
#
# ---- Macromodel analysis ----
#
# Interesting regions of the first grid (no iteration yet):
#
# ra:
# [-4.06670847e-07  1.20390677e-06]
# dec:
# [4.02644403e-09 4.02644403e-09]
# pixel_width:
# 8.052888061582012e-09
#
#
# Iteration # 0
#
# Pixels to iterate over, RAs:
# [-4.066708467072679e-07, 1.2039067656092146e-06]
# Pixels to iterate over, DECs:
# [4.026444030790582e-09, 4.026444030790582e-09]
# Pixels to iterate over, source displacements:
# [5.666135983470095e-09, 4.237143739907385e-09]
#
#
#
# Pixel size of the last iteration: 5.368592041055239e-10
#
#
#
#
# MACROIMAGES
#
# ra: [-4.02644403e-07  1.20793321e-06]
# dec: [-4.23516474e-22 -4.23516474e-22]
#
# Elapsed time: 0.08958053588867188 seconds
#
#
# ---- Solver settings ----
#
# The complete model analysis will be performed with the following settings:
#
# Scaled                          --> False
# OnlyMacro                       --> False
# MacroIndex                      --> [0]
# ImgIndex                        --> None
# SearchWindow                    --> 1.4405444096715827e-09
# Pixels                          --> 10000.0
# OverlapDist                     --> 1e-18
# Optimization                    --> True
# Verbose                         --> True
# Improvement                     --> 0.1
# MinDist                         --> 1e-07
# OptimizationWindow              --> 2
# OptimizationPixels              --> 30
# OptimizationPrecisionLimit      --> 1e-20
#
#
# ---- Complete model analysis ----
#
#
# Interesting regions of the first grid (no iteration yet):
#
# ra:
# [-4.02644475e-07]
# dec:
# [7.20272201e-14]
# pixel_width:
# 1.4405444097100547e-13
#
#
# Iteration # 0
#
# Pixels to iterate over, RAs:
# [-4.0264447470369733e-07]
# Pixels to iterate over, DECs:
# [7.20272200600217e-14]
# Pixels to iterate over, source displacements:
# [8.877256333978716e-14]
#
#
#
# Pixel size of the last iteration: 9.603629380420511e-15
#
#
# Iteration # 1
#
# Pixels to iterate over, RAs:
# [-4.0264442188373563e-07]
# Pixels to iterate over, DECs:
# [-4.254810275819636e-22]
# Pixels to iterate over, source displacements:
# [9.259851691579923e-16]
#
#
#
# Pixel size of the last iteration: 6.402419763412205e-16
#
#
# Iteration # 2
#
# Pixels to iterate over, RAs:
# [-4.0264442284409857e-07]
# Pixels to iterate over, DECs:
# [3.201205538663233e-16]
# Pixels to iterate over, source displacements:
# [3.1964671071418465e-16]
#
#
#
# Pixel size of the last iteration: 4.2682784305532245e-17
#
#
# Iteration # 3
#
# Pixels to iterate over, RAs:
# [-4.0264442282275715e-07]
# Pixels to iterate over, DECs:
# [-4.343042869232886e-22]
# Pixels to iterate over, source displacements:
# [1.3245570258906373e-17]
#
#
#
# Pixel size of the last iteration: 2.8455013071824152e-18
#
#
# Iteration # 4
#
# Pixels to iterate over, RAs:
# [-4.0264442280995234e-07]
# Pixels to iterate over, DECs:
# [1.4223251725641495e-18]
# Pixels to iterate over, source displacements:
# [9.356896439932415e-19]
#
#
#
# Pixel size of the last iteration: 1.8968244062575988e-19
#
#
# Iteration # 5
#
# Pixels to iterate over, RAs:
# [-4.026444228096678e-07]
# Pixels to iterate over, DECs:
# [2.2759755647188744e-18]
# Pixels to iterate over, source displacements:
# [7.232881070000073e-20]
#
#
#
# Pixel size of the last iteration: 1.2652554649611111e-20
#
#
# Interesting regions of the first grid (no iteration yet):
#
# ra:
# [1.20766462e-06 1.20794841e-06 1.20794293e-06 1.20796843e-06
#  1.20831214e-06 1.20806437e-06 1.20786572e-06 1.20759072e-06
#  1.20794452e-06 1.20751970e-06 1.20765482e-06 1.20773838e-06
#  1.20811277e-06]
# dec:
# [-2.39778617e-10 -1.98579047e-10  8.57123924e-12  6.02867835e-11
#   6.14392191e-11  6.56167979e-11  8.18949497e-11  1.45278904e-10
#   1.64582199e-10  1.73225465e-10  4.91873889e-10  5.77154118e-10
#   5.89974963e-10]
# pixel_width:
# 1.440544408121868e-13
#
#
# Iteration # 0
#
# Pixels to iterate over, RAs:
# [1.2076646201348223e-06, 1.2079484073835277e-06, 1.2079429333147709e-06, 1.207968430950822e-06, 1.2083121448469698e-06, 1.2080643712085062e-06, 1.2078657201344125e-06, 1.2075907202066063e-06, 1.2079445179136215e-06, 1.2075197013672094e-06, 1.2076548244328365e-06, 1.2077383760085976e-06, 1.2081127735006712e-06]
# Pixels to iterate over, DECs:
# [-2.397786169902585e-10, -1.9857904687365119e-10, 8.571239237122386e-12, 6.028678354433216e-11, 6.14392190720695e-11, 6.561679786011709e-11, 8.189494968940592e-11, 1.452789037149556e-10, 1.645821988045548e-10, 1.7322546526258424e-10, 4.918738886819384e-10, 5.77154117734496e-10, 5.899749629805732e-10]
# Pixels to iterate over, source displacements:
# [9.32998085331407e-13, 4.761622155712016e-14, 1.1067455124129437e-13, 2.0994704654372246e-13, 2.240567887694266e-12, 1.4994637035391907e-13, 8.444872919908488e-14, 2.477701285013146e-12, 4.3332607082080827e-14, 3.0267641895685807e-12, 1.7267342505181742e-12, 3.8013659468773295e-13, 2.7718582895037153e-14]
#
#
#
# Pixel size of the last iteration: 9.603629274541393e-15
#
#
# Iteration # 1
#
# Pixels to iterate over, RAs:
# [1.2076645865221195e-06, 1.207948373770825e-06, 1.2079429381165856e-06, 1.2079685029780423e-06, 1.208312111234267e-06, 1.2080643471994327e-06, 1.2078657537471153e-06, 1.2075907634229385e-06, 1.2079445611299538e-06, 1.2075197733944297e-06, 1.2076547908201337e-06, 1.207738400017671e-06, 1.208112778302486e-06]
# Pixels to iterate over, DECs:
# [-2.398122296931147e-10, -1.985070196532451e-10, 8.537626534266209e-12, 6.027237810025095e-11, 6.150164266308811e-11, 6.568882508052318e-11, 8.187094061593723e-11, 1.4532212004719927e-10, 1.6463501876618594e-10, 1.7318224893034058e-10, 4.918114650909198e-10, 5.771493159198023e-10, 5.899701611658795e-10]
# Pixels to iterate over, source displacements:
# [1.203251340402801e-13, 3.6799059175136455e-15, 7.635216262059778e-15, 4.660913436803998e-15, 1.4167075835159033e-13, 1.2682420922281213e-14, 3.354766902678442e-15, 1.992857084996723e-13, 1.4265640166290685e-15, 1.594810362783493e-13, 4.8523847352710294e-14, 6.889576181146321e-14, 8.144071611482861e-14]
#
#
#
# Pixel size of the last iteration: 6.402419234016613e-16
#
#
# Iteration # 2
#
# Pixels to iterate over, RAs:
# [1.207664591323934e-06, 1.2079483696092523e-06, 1.2079429384367067e-06, 1.2079685013774374e-06, 1.208312112834872e-06, 1.2080643500805215e-06, 1.2078657521465104e-06, 1.2075907611820917e-06, 1.2079445633708006e-06, 1.2075197724340667e-06, 1.2076547905000127e-06, 1.2077383964963404e-06, 1.2081127735006714e-06]
# Pixels to iterate over, DECs:
# [-2.398163912658003e-10, -1.9850605929031765e-10, 8.535385687435483e-12, 6.027269822122676e-11, 6.149748109040249e-11, 6.568402326588591e-11, 8.186805952715487e-11, 1.453262816198849e-10, 1.6463469864521012e-10, 1.7318641050302622e-10, 4.91809224244089e-10, 5.771496360407781e-10, 5.899730422546619e-10]
# Pixels to iterate over, source displacements:
# [5.50155081926968e-15, 1.7132469769604242e-16, 8.510283748050944e-16, 1.9916974800167554e-16, 9.94623100854554e-15, 9.402458249738546e-16, 3.9386316923224613e-16, 1.0848881659786653e-14, 2.3492006449818573e-16, 6.6512013874080715e-15, 7.129880266522617e-15, 4.595625102183658e-15, 4.39976321431663e-15]
#
#
#
# Pixel size of the last iteration: 4.268283724509145e-17
#
#
# Iteration # 3
#
# Pixels to iterate over, RAs:
# [1.2076645913025927e-06, 1.2079483694171797e-06, 1.207942938714145e-06, 1.2079685013987788e-06, 1.2083121128988962e-06, 1.208064349845766e-06, 1.207865751911755e-06, 1.2075907610753846e-06, 1.2079445631360452e-06, 1.2075197725834564e-06, 1.2076547906920852e-06, 1.207738396261585e-06, 1.2081127737354268e-06]
# Pixels to iterate over, DECs:
# [-2.398161138276335e-10, -1.9850595258333041e-10, 8.535150932063568e-12, 6.027259151423953e-11, 6.14977585285693e-11, 6.56838311933089e-11, 8.186782477178295e-11, 1.4532651637525683e-10, 1.6463437852424842e-10, 1.7318651721001345e-10, 4.918094589994609e-10, 5.771495720165858e-10, 5.89973191644444e-10]
# Pixels to iterate over, source displacements:
# [4.665837147175015e-16, 7.056780832190545e-18, 4.3653368903753325e-17, 2.5326223284761888e-17, 3.835585220730388e-16, 6.207107148752142e-17, 1.2534675318580825e-17, 8.204686189325509e-16, 1.6210096975615052e-17, 7.983626660423724e-16, 3.063184338688364e-16, 4.076967142829891e-16, 2.297190796822216e-16]
#
#
#
# Pixel size of the last iteration: 2.8453954280640084e-18
#
#
# Iteration # 4
#
# Pixels to iterate over, RAs:
# [1.2076645912812512e-06, 1.2079483694129115e-06, 1.2079429387041855e-06, 1.2079685014058926e-06, 1.208312112900319e-06, 1.208064349864262e-06, 1.2078657519188688e-06, 1.2075907610568888e-06, 1.2079445631516956e-06, 1.207519772567806e-06, 1.207654790699199e-06, 1.2077383962430892e-06, 1.208112773739695e-06]
# Pixels to iterate over, DECs:
# [-2.398161038683048e-10, -1.985059625426591e-10, 8.535163736914741e-12, 6.027259009147829e-11, 6.149776848789798e-11, 6.568381838845772e-11, 8.186783188558916e-11, 1.4532652348906303e-10, 1.6463439986566704e-10, 1.7318653001486462e-10, 4.918094490401322e-10, 5.77149584821437e-10, 5.899731759940704e-10]
# Pixels to iterate over, source displacements:
# [1.500771710052157e-17, 1.122191310065846e-18, 1.9407186313337854e-18, 4.265319863809241e-18, 4.761466820591756e-17, 2.637838430705361e-18, 9.453915459893785e-19, 2.3932960799958485e-17, 6.5489092429342235e-19, 4.989148230586615e-17, 1.910423420322409e-17, 2.2173236814996828e-17, 1.8464779429657582e-17]
#
#
#
# Pixel size of the last iteration: 1.8973538018496328e-19
#
#
# Iteration # 5
#
# Pixels to iterate over, RAs:
# [1.2076645912811564e-06, 1.2079483694116785e-06, 1.2079429387052289e-06, 1.2079685014073154e-06, 1.208312112900793e-06, 1.208064349864167e-06, 1.2078657519189637e-06, 1.2075907610564144e-06, 1.2079445631506523e-06, 1.2075197725673317e-06, 1.2076547906985352e-06, 1.2077383962441325e-06, 1.2081127737390311e-06]
# Pixels to iterate over, DECs:
# [-2.3981610472192346e-10, -1.9850596301689167e-10, 8.535164021454283e-12, 6.027258904816663e-11, 6.149776972090267e-11, 6.568381962146241e-11, 8.186783292890082e-11, 1.453265232045235e-10, 1.6463439939143447e-10, 1.731865312478693e-10, 4.918094485658996e-10, 5.771495854853625e-10, 5.89973177037382e-10]
# Pixels to iterate over, source displacements:
# [1.797879661510685e-18, 5.71125378771724e-20, 2.462587967996628e-19, 2.961730087907193e-19, 3.2686638277142028e-18, 2.3156357729889857e-19, 9.590941275554746e-20, 1.9363221676031678e-18, 5.864013981142019e-20, 3.4009147935542053e-18, 2.3449357710163824e-18, 7.089804743069575e-19, 9.751678274188427e-19]
#
#
#
# Pixel size of the last iteration: 1.2705494208814505e-20
#
#
# Iteration # 6
#
# Pixels to iterate over, RAs:
# [1.2076645912811121e-06, 1.20831211290085e-06, 1.2075907610563702e-06, 1.2075197725674013e-06, 1.2076547906986048e-06, 1.2077383962441768e-06, 1.2081127737389742e-06]
# Pixels to iterate over, DECs:
# [-2.398161046397048e-10, 6.149776979047231e-11, 1.4532652319819898e-10, 1.7318653131743893e-10, 4.91809448508979e-10, 5.77149585491687e-10, 5.899731770057594e-10]
# Pixels to iterate over, source displacements:
# [4.6461530175473765e-20, 2.3231395981868148e-19, 1.2933532178400318e-19, 2.3343421155502e-19, 1.2675324705641182e-19, 9.576331089960117e-20, 8.057428374848444e-20]
#
#
#
# Pixel size of the last iteration: 8.470329472543003e-22
#
#
# Iteration # 7
#
# Pixels to iterate over, RAs:
# [1.2075197725673975e-06]
# Pixels to iterate over, DECs:
# [1.7318653131278025e-10]
# Pixels to iterate over, source displacements:
# [1.3060614037393742e-20]
#
#
#
# Pixel size of the last iteration: 0.0
#
#
#
# Minumum pixel size reached. The iteration will be stopped.
#
#
#
# IMAGES OF THE COMPLETE MODEL
#
# ra: [-4.02644423e-07  1.20794837e-06  1.20794294e-06  1.20796850e-06
#   1.20806435e-06  1.20786575e-06  1.20794456e-06  1.20766459e-06
#   1.20831211e-06  1.20759076e-06  1.20765479e-06  1.20773840e-06
#   1.20811277e-06]
# dec: [ 2.33288030e-18 -1.98505963e-10  8.53516395e-12  6.02725891e-11
#   6.56838196e-11  8.18678329e-11  1.64634399e-10 -2.39816105e-10
#   6.14977698e-11  1.45326523e-10  4.91809449e-10  5.77149585e-10
#   5.89973177e-10]
#
# Elapsed time: 293.061466217041 seconds
#
# Time delays (seconds):  [2.95529337e+05 0.00000000e+00 4.81111859e-03 5.18161879e-03
#  6.63113577e-03 4.89049178e-03 4.05019621e-03 1.95417550e-02
#  3.17317488e-02 3.28482623e-02 3.76625583e-02 3.45305338e-02
#  3.13415058e-02]
# magnifications:  [-1.00000007e+00  2.41027075e+00 -1.92522842e-01 -2.08623320e-01
#  -1.36696878e-01 -5.60163620e-01  2.26189351e+00 -2.59284285e-03
#  -8.58953334e-04 -6.26173744e-04 -1.67895102e-03 -3.14041092e-03
#  -4.16286731e-03]
# Morse indices:  [0, 0, 0.5, 0.5, 0.5, 0.5, 0, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5]
# T0 = -0.999998908959732
# Tscale = 295529.46212367347

# %%
# plot only the microimages around the desired macroimage
Img_ra = np.delete(Img_ra, [0])
Img_dec = np.delete(Img_dec, [0])

# %%
# Img_ra, Img_dec = np.array([1.20796878e-06, 1.20766453e-06, 1.20782147e-06, 1.20789819e-06,
#         1.20831193e-06, 1.20779292e-06, 1.20759056e-06, 1.20765472e-06,
#         1.20773836e-06, 1.20811265e-06]), np.array([-1.75457727e-10, -2.39431399e-10, -1.59957089e-11,  5.87778019e-11,
#          6.14919175e-11,  6.50404693e-11,  1.45257339e-10,  4.91681151e-10,
#          5.76987367e-10,  5.90109028e-10])

# %%
lens_model_complete = LensModel(lens_model_list=lens_model_list)
T = lens_model_complete.fermat_potential
T0 = thetaE ** (-2) * T(MacroImg_ra[microtype], MacroImg_dec[microtype], kwargs_lens_list, beta0, beta1)#[0]

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
plot_contour(ax, lens_model_list, eta10, eta11, 4*thetaE1, kwargs_lens_list, beta0, beta1, MacroImg_ra, MacroImg_dec,
                    T0 = T0, Tfac = (thetaE)**(-2), micro=False)
# Out:
# [-4.02644403e-07  1.20793321e-06] [-4.23516474e-22 -4.23516474e-22] Img_pos
# <Axes: >

# %%
fig1, ax1 = plt.subplots()
plot_contour(ax1, lens_model_list, MacroImg_ra[microtype], MacroImg_dec[microtype], 40*thetaE2, kwargs_lens_list, beta0, beta1, Img_ra, Img_dec,
                    T0 = T0, Tfac = (thetaE)**(-2), micro=True, contour=50)
# Out:
# [1.20794837e-06 1.20794294e-06 1.20796850e-06 1.20806435e-06
#  1.20786575e-06 1.20794456e-06 1.20766459e-06 1.20831211e-06
#  1.20759076e-06 1.20765479e-06 1.20773840e-06 1.20811277e-06] [-1.98505963e-10  8.53516395e-12  6.02725891e-11  6.56838196e-11
#   8.18678329e-11  1.64634399e-10 -2.39816105e-10  6.14977698e-11
#   1.45326523e-10  4.91809449e-10  5.77149585e-10  5.89973177e-10] Img_pos
# <Axes: >

# %%
from lenstronomy.LensModel.lens_model_extensions import LensModelExtensions
# lens_model_list = ['POINT_MASS']
lens_model_complete = LensModel(lens_model_list=lens_model_list)
lensmodelext = LensModelExtensions(lens_model_complete)
ra_crit_list, dec_crit_list = lensmodelext.critical_curve_tiling(kwargs_lens_list, compute_window=20*thetaE2, start_scale = thetaE2/500, center_x=MacroImg_ra[1], center_y=MacroImg_dec[1])
ra_caustic_list, dec_caustic_list = lens_model_complete.ray_shooting(ra_crit_list, dec_crit_list, kwargs_lens_list)
macro_srcx, macro_srcy = lens_model_complete.ray_shooting(MacroImg_ra, MacroImg_dec, kwargs_lens_list)
# lens_srcx, lens_srcy = lens_model_complete.ray_shooting(eta20, eta21, kwargs_lens_list)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 5
#       3 lens_model_complete = LensModel(lens_model_list=lens_model_list)
#       4 lensmodelext = LensModelExtensions(lens_model_complete)
# ----> 5 ra_crit_list, dec_crit_list = lensmodelext.critical_curve_tiling(kwargs_lens_list, compute_window=20*thetaE2, start_scale = thetaE2/500, center_x=MacroImg_ra[1], center_y=MacroImg_dec[1])
#       6 ra_caustic_list, dec_caustic_list = lens_model_complete.ray_shooting(ra_crit_list, dec_crit_list, kwargs_lens_list)
#       7 macro_srcx, macro_srcy = lens_model_complete.ray_shooting(MacroImg_ra, MacroImg_dec, kwargs_lens_list)
#
# File ~/.conda/envs/wolensing/lib/python3.10/site-packages/lenstronomy/LensModel/lens_model_extensions.py:382, in LensModelExtensions.critical_curve_tiling(self, kwargs_lens, compute_window, start_scale, max_order, center_x, center_y)
#     380 ra_crit_list += ra_crit  # list addition
#     381 dec_crit_list += dec_crit  # list addition
# --> 382 ra_crit, dec_crit = self._tiling_crit(
#     383     edge1,
#     384     edge2,
#     385     edge_90_2,
#     386     max_order=max_order,
#     387     kwargs_lens=kwargs_lens,
#     388 )
#     389 ra_crit_list += ra_crit  # list addition
#     390 dec_crit_list += dec_crit  # list addition
#
# KeyboardInterrupt:

# %%
from lenstronomy.LensModel.lens_model_extensions import LensModelExtensions
# lens_model_list = ['POINT_MASS']
# lens_model_complete = LensModel(lens_model_list=lens_model_list)
# lensmodelext = LensModelExtensions(lens_model_complete)
ra_crit_list1, dec_crit_list1 = lensmodelext.critical_curve_tiling(kwargs_lens_list, compute_window=40*thetaE2, start_scale = thetaE2/100, center_x=MacroImg_ra[1], center_y=MacroImg_dec[1])
ra_caustic_list1, dec_caustic_list1 = lens_model_complete.ray_shooting(ra_crit_list1, dec_crit_list1, kwargs_lens_list)
macro_srcx, macro_srcy = lens_model_complete.ray_shooting(MacroImg_ra, MacroImg_dec, kwargs_lens_list)
# lens_srcx, lens_srcy = lens_model_complete.ray_shooting(eta20, eta21, kwargs_lens_list)
plt.scatter(ra_caustic_list1, dec_caustic_list1, s=1)
macro_srcx, macro_srcy = lens_model_complete.ray_shooting(MacroImg_ra, MacroImg_dec, kwargs_lens_list)
plt.scatter(macro_srcx, macro_srcy)
# plt.scatter(lens_srcx, lens_srcy)

# %%
tds = TimeDelay(Img_ra, Img_dec,
               beta0, beta1,
               zL, zS,
               lens_model_list, kwargs_lens_list)
mus = magnifications(Img_ra, Img_dec, lens_model_list, kwargs_lens_list)
ns = getMinMaxSaddle(Img_ra, Img_dec, lens_model_list, kwargs_lens_list, diff = None)

# %%
tds, mus, ns

# %%
total_triple_d(lens_model_list, Img_ra, Img_dec, kwargs_lens_list)

# %%
Tscale = 4 * (1 + zL) * mtot * M_sun * G / c ** 3

# %%
# Define the characteristic WindowSize
mL3 = 10
thetaE3 = param_processing(zL, zS, mL3)

# %%
import time

# %%
kwargs_macro = {'source_pos_x': beta0,
                'source_pos_y': beta1,
                'theta_E': thetaE,
                'mu': np.abs(Mus[microtype]),
               }

kwargs_integrator = {'PixelNum': int(40000),
                     'PixelBlockMax': 2000,
                     'WindowSize': 2.*210*thetaE3,
                     'WindowCenterX': MacroImg_ra[microtype],
                     'WindowCenterY': MacroImg_dec[microtype],
                     'T0': T0,
                     'TimeStep': 1e-5/Tscale, 
                     'TimeMax': T0 + .7/Tscale,
                     'TimeMin': T0 - .5/Tscale,
                     'TimeLength': 1./Tscale,
                     'TExtend': 10/Tscale,
                     'LastImageT': .02/Tscale,
                     'Tbuffer': .1/Tscale,
                     'Tscale': Tscale}


amplification = af.amplification_factor(lens_model_list=lens_model_list, kwargs_lens=kwargs_lens_list, kwargs_macro=kwargs_macro, **kwargs_integrator)
ts, Ft = amplification.integrator(gpu=False)
ws, Fws = amplification.fourier()
amplification.plot_freq()

# %%
ws, Fws = amplification.fourier(freq_end = 5000)

# %%
ws, Fws = amplification.fourier(freq_end=6000)

# %%
plt.plot(ts, Ft)

# %%
amplification.plot_freq(smooth=False)

# %%
amplification.plot_freq(pha=True, smooth=False)

# %% [markdown]
# # Geometrical optics
# To get the geometrical optics around type 1 image, we need the magnifications, time delay and the image positions of the microimages

# %%
tds = TimeDelay(Img_ra, Img_dec,
               beta0, beta1,
               zL, zS,
               lens_model_list, kwargs_lens_list)
mus = magnifications(Img_ra, Img_dec, lens_model_list, kwargs_lens_list)
ns = getMinMaxSaddle(Img_ra, Img_dec, lens_model_list, kwargs_lens_list, diff = None)

# %%
tds, mus, ns

# %%
amplification._fs = np.linspace(0, 2000, 500)

# %%
Img_dec

# %%
geofs, geoFws = amplification.geometrical_optics(mus, tds, Img_ra, Img_dec, upper_lim=4000)

# %%
Fmag = 0
for i in range(len(mus)):
    Fmag += np.sqrt(np.abs(mus[i]))* np.exp(1j*np.pi*(2.*geofs*tds[i] - ns[i]))
# return Fmag

# %%
np.savetxt('iden5_ts.txt', ts)
np.savetxt('iden5_Ft.txt', Ft)

# %%
plt.semilogx(geofs, np.abs(geoFws))

# %%
plt.semilogx(geofs, np.angle(geoFws))

# %% [markdown]
# ##### Full amplification factor concatenated with geometrical optics
# Given the computaional cost of the diffraction integral, we concatenate the result of wave optics at low frequency and geometrical optics at high frequency to obtain a full amplification factor with default upper bound of 3000Hz.

# %%
fullfs, fullFws = amplification.concatenate()
plt.semilogx(fullfs, np.abs(fullFws))

# %%
plt.semilogx(fullfs, np.angle(fullFws))

# %%
fac = np.sqrt(np.abs(Mus[microtype]))

# %%
plt.clf()
plt.rc('text', usetex=True)
plt.rc('font', family='serif')

# %%
from bisect import bisect_left
low_index = bisect_left(geofs, 1)
geofs = geofs[low_index:]
geoFws = geoFws[low_index:]
ws = ws[low_index:]
Fws = Fws[low_index:]

# %%
ww = geofs
plt.semilogx(geofs, (fac*np.exp(-ww*np.pi/188) + (1-np.exp(-ww*np.pi/188))*np.abs(geoFws))/fac, label='Approximation')
plt.semilogx(geofs, np.abs(geoFws)/fac,label=r'$F_{geo}$')
plt.semilogx(ws, np.abs(Fws)/fac,label=r'$F_{wave}$')
plt.ylabel(r'$|F|/\sqrt{\mu}$')
plt.xlabel(r'$f$')
plt.grid(which='both', alpha=0.5)
plt.legend()
plt.xlim(10, 2000)
plt.ylim(0.3, 1.7)

# plt.savefig('./approx.png',bbox_inches='tight', dpi=300)

# %%
ww = geofs
# plt.semilogx(geofs, (fac*np.exp(-ww*np.pi/188) + (1-np.exp(-ww*np.pi/188))*np.abs(geoFws))/fac, label='Approximation')
plt.semilogx(geofs, np.abs(geoFws)/fac,label=r'$F_{geo}$')
# plt.semilogx(ws, np.abs(Fws)/fac,label=r'$F_{geo}$')
plt.semilogx(conv_y, conv/fac,label=r'$F_{wave}$')
plt.ylabel(r'$|F|/\sqrt{\mu}$')
plt.xlabel(r'$f$')
plt.grid(which='both', alpha=0.5)
plt.legend()
plt.xlim(1000, 4000)
plt.ylim(0.6, 1.5)
# plt.savefig('./approx.png',bbox_inches='tight', dpi=300)

# %%
window_size = 200
conv = np.convolve(np.abs(Fws), np.ones(window_size)/window_size, mode='valid')
conv_y = ws[window_size - 1:]
plt.semilogx(conv_y, conv)

# %%
interp = np.interp(geofs, ws, Fws)

# %%
geofs

# %%
plt.semilogx(geofs, ((np.abs(interp)-np.abs(geoFws))/np.abs(interp)) , label=r'$F_{wave}$')

# %%
plt.semilogx(geofs, (1-np.exp(-geofs*np.pi/37.5))*np.angle(geoFws), label='Approximation')
plt.semilogx(geofs, np.angle(geoFws),label=r'$F_{geo}$')
plt.semilogx(ws, np.angle(Fws), label=r'$F_{wave}$')
plt.ylabel(r'$args(F)$')
plt.xlabel(r'$f$')
plt.grid(which='both', alpha=0.5)
plt.legend()
plt.xlim(1, 2000)
# plt.savefig('./approx_ang.png',bbox_inches='tight', dpi=300)
