# %%
import numpy as np

# %%
# %env JAX_ENABLE_X64=True
# Out:
# env: JAX_ENABLE_X64=True

# %%
from lenstronomy.LensModel.lens_model import LensModel
import lensinggw.constants.constants as const
from lensinggw.utils.utils import TimeDelay, magnifications, getMinMaxSaddle

# %%
import sys
import os
path = os.getcwd()
dir = os.path.abspath(os.path.join(path, os.pardir))
sys.path.append(dir)

# %%
from plot.plot import plot_contour
import amplification_factor.amplification_factor as af
from lensmodels.potential import potential

# %% [markdown]
# The macroimage where the microlens is placed around.

# %%
type2 = False

# %%
ym = 0.8
angle = np.radians(float(0))

# %% [markdown]
# Importing constants

# %%
G = const.G  # gravitational constant [m^3 kg^-1 s^-2]
c = const.c  # speed of light [m/s]
M_sun = const.M_sun  # Solar mass [Kg]

# %%
y0, y1 = 0.5, 0 # source position
l0, l1 = 0., 0 # lens position

zS = 1.0 # source redshift
zL = 0.5 # lens redshift

# %%
mL1 = 1e10
mL2 = 20
mtot = mL1 + mL2

# convert to radians
from lensinggw.utils.utils import param_processing
thetaE1 = param_processing(zL, zS, mL1)
thetaE2 = param_processing(zL, zS, mL2)
thetaE = param_processing(zL, zS, mtot)

# %%
thetaE
# Out:
# 8.052888069635299e-07

# %%
Mpc=3.085677581491367e+22
from astropy.cosmology import FlatLambdaCDM
cosmo = FlatLambdaCDM(H0=69.7, Om0=0.306, Tcmb0=2.725)
DL       = cosmo.angular_diameter_distance(zL)
DS       = cosmo.angular_diameter_distance(zS)
DLS      = cosmo.angular_diameter_distance_z1z2(zL, zS)
D        = DLS/(DL*DS)
print(np.float64(D/Mpc))
# Out:
# 1.097926071881248e-26

# %%
from utils.utils import Einstein_radius

# %%
Einstein_radius(zL, zS, mtot)
# Out:
# 1.097926071881248e-26
# 8.052888069635299e-07

# %%
beta0, beta1 = y0 * thetaE, y1 * thetaE
eta10, eta11 = 0 * l0 * thetaE, 0 * l1 * thetaE
lens_model_list = ['SIS']
kwargs_sis_1 = {'center_x': eta10, 'center_y': eta11, 'theta_E': thetaE1}
kwargs_lens_list = [kwargs_sis_1]

kwargs_sis_1_scaled = {'center_x': eta10 / thetaE, 'center_y': eta11 / thetaE, 'theta_E': thetaE1 / thetaE}
kwargs_lens_list_scaled = [kwargs_sis_1_scaled]

from lensinggw.solver.images import microimages
solver_kwargs = {'SearchWindowMacro': 10 * thetaE1,
                 'SearchWindow': 5 * thetaE2,
                 'OverlapDistMacro': 1e-17,
                 'OnlyMacro': True}
MacroImg_ra, MacroImg_dec, pixel_width = microimages(source_pos_x=beta0,
                                                     source_pos_y=beta1,
                                                     lens_model_list=lens_model_list,
                                                     kwargs_lens=kwargs_lens_list,
                                                     **solver_kwargs)

Td = TimeDelay(MacroImg_ra, MacroImg_dec,
                beta0, beta1,
                zL, zS,
                lens_model_list, kwargs_lens_list)
Mus = magnifications(MacroImg_ra, MacroImg_dec, lens_model_list, kwargs_lens_list)
if type2:
    microtype = np.nonzero(Td)[0][0]
else:
    microtype = np.where(Td==0)[0][0]

# masses = np.linspace(0.5, 3, 6)
np.random.seed(1)
masses = np.random.rand(10)
masses = (masses / np.sum(masses)) * 500
print('masses: ', masses)
angle = [0, 150, 260]
ym = [1., .4, 4.]

# num_points = len(masses)
# for j in range(0,num_points):
#     theta_E = param_processing(zL, zS, masses[j])# lens model
#     #positioning the microlenses
#     eta20 = MacroImg_ra[microtype] + ym[j]*np.cos(np.radians(angle[j])) * theta_E
#     eta21 = MacroImg_dec[microtype] + ym[j] * np.sin(np.radians(angle[j])) * theta_E
#     lens_model_list.append('POINT_MASS')
#     kwargs_lens_list.append({'center_x': eta20, 'center_y': eta21, 'theta_E': theta_E})

mass_density = 200
from utils.lensing import *
radius = injection_radius(masses, mass_density) #rad
lens_model_list, kwargs_lens_list = field_injection(zL, zS, MacroImg_ra[microtype], MacroImg_dec[microtype], masses, radius, lens_model_list, kwargs_lens_list, seed=8)
    
# Injecting microlens around desired macroimage
# eta20, eta21 = MacroImg_ra[microtype] + np.cos(angle)*ym*thetaE2, MacroImg_dec[microtype] + np.sin(angle)*ym*thetaE2
# lens_model_list = ['SIS', 'POINT_MASS']
# kwargs_sis_1 = {'center_x': eta10, 'center_y': eta11, 'theta_E': thetaE1}
# kwargs_point_mass_2 = {'center_x': eta20, 'center_y': eta21, 'theta_E': thetaE2}
# kwargs_lens_list = [kwargs_sis_1, kwargs_point_mass_2]

from lensinggw.solver.images import microimages
solver_kwargs = {'SearchWindowMacro': 10 * thetaE1,
                 'SearchWindow': 40 * thetaE2,
                 'Pixels': 10*1e3,
                 'Optimization': True,
                 'Verbose': True,
                 'OverlapDist': 1e-18,
                 'OverlapDistMacro': 1e-17}
solver_kwargs.update({'Improvement' : 0.9})
solver_kwargs.update({'MinDist' : 10**(-7)})

Img_ra, Img_dec, MacroImg_ra, MacroImg_dec, pixel_width = microimages(source_pos_x=beta0,
                                                                      source_pos_y=beta1,
                                                                      lens_model_list=lens_model_list,
                                                                      kwargs_lens=kwargs_lens_list,
                                                                      **solver_kwargs)
# Images_dict = {'Source_ra': beta0,
#                'Source_dec': beta1,
#                'Img_ra': Img_ra,
#                'Img_dec': Img_dec,
#                'MacroImg_ra': MacroImg_ra,
#                'MacroImg_dec': MacroImg_dec,
#                'Microlens_ra': [eta20],
#                'Microlens_dec': [eta21],
#                'thetaE': thetaE}

# time delays, magnifications, Morse indices 
from lensinggw.utils.utils import TimeDelay, magnifications, getMinMaxSaddle
from lensinggw.amplification_factor.amplification_factor import geometricalOpticsMagnification
tds = TimeDelay(Img_ra, Img_dec,
               beta0, beta1,
               zL, zS,
               lens_model_list, kwargs_lens_list)
mus = magnifications(Img_ra, Img_dec, lens_model_list, kwargs_lens_list)
ns = getMinMaxSaddle(Img_ra, Img_dec, lens_model_list, kwargs_lens_list, diff = None)
print('Time delays (seconds): ', tds)
print('magnifications: ', mus)
print('Morse indices: ', ns)
    
lens_model_complete = LensModel(lens_model_list=lens_model_list)
T = lens_model_complete.fermat_potential
T0 = thetaE ** (-2) * T(Img_ra[microtype], Img_dec[microtype], kwargs_lens_list, beta0, beta1)#[0]
if not isinstance(T0, float):
    T0 = T0[0]
Tscale = 4 * (1 + zL) * mtot * M_sun * G / c ** 3
print('T0 = {}'.format(T0))
print('Tscale = {}'.format(Tscale))
# Out:
# ---- Will perform only the macromodel analysis ----
#
# ---- Solver settings ----
#
# The macromodel analysis will be performed with the following settings:
#
# OnlyMacro         --> True
# Scaled            --> False
# SearchWindowMacro --> 8.052888061582412e-06
# PixelsMacro       --> 1000
# PrecisionLimit    --> 1e-20
# OverlapDistMacro  --> 1e-17
# NearSource        --> False
# Optimization      --> False
# Verbose           --> False
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:107: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:107: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:108: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:117: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:117: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:146: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:171: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:171: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:178: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:178: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:182: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:182: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:392: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:392: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:397: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:397: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:398: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:403: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:403: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:408: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:408: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:107: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:107: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:108: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:117: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:117: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:146: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:171: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:171: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:178: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:178: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:182: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:182: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:392: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:392: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:397: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:397: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:398: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:403: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:403: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:408: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:408: SyntaxWarning: "is" with a literal. Did you mean "=="?
# MACROIMAGES
#
# ra: [-4.02644403e-07  1.20793321e-06]
# dec: [-4.23516474e-22 -4.23516474e-22]
#
# masses:  [6.62719579e+01 1.14471932e+02 1.81761226e-02 4.80458376e+01
#  2.33220312e+01 1.46741884e+01 2.95999462e+01 5.49155337e+01
#  6.30531652e+01 8.56272319e+01]
#
# ---- Solver settings ----
#
# The macromodel analysis will be performed with the following settings:
#
# OnlyMacro                       --> False
# Scaled                          --> False
# SearchWindowMacro               --> 8.052888061582412e-06
# PixelsMacro                     --> 1000
# OverlapDistMacro                --> 1e-17
# NearSource                      --> False
# Optimization                    --> True
# Verbose                         --> True
# OptimizationWindowMacro         --> 2
# OptimizationPixelsMacro         --> 30
# MinDistMacro                    --> None
# ImprovementMacro                --> None
# OptimizationPrecisionLimitMacro --> 1e-20
#
#
# ---- Macromodel analysis ----
#
# Interesting regions of the first grid (no iteration yet):
#
# ra:
# [-4.06670847e-07  1.20390677e-06]
# dec:
# [4.02644403e-09 4.02644403e-09]
# pixel_width:
# 8.052888061582012e-09
#
#
# Iteration # 0
#
# Pixels to iterate over, RAs:
# [-4.066708467072679e-07, 1.2039067656092146e-06]
# Pixels to iterate over, DECs:
# [4.026444030790582e-09, 4.026444030790582e-09]
# Pixels to iterate over, source displacements:
# [5.666135983470095e-09, 4.237143739907385e-09]
#
#
#
# Pixel size of the last iteration: 5.368592041055239e-10
#
#
#
#
# MACROIMAGES
#
# ra: [-4.02644403e-07  1.20793321e-06]
# dec: [-4.23516474e-22 -4.23516474e-22]
#
# Elapsed time: 0.1262204647064209 seconds
#
#
# ---- Solver settings ----
#
# The complete model analysis will be performed with the following settings:
#
# Scaled                          --> False
# OnlyMacro                       --> False
# MacroIndex                      --> [0]
# ImgIndex                        --> None
# SearchWindow                    --> 1.4405444096715827e-09
# Pixels                          --> 10000.0
# OverlapDist                     --> 1e-18
# Optimization                    --> True
# Verbose                         --> True
# Improvement                     --> 0.9
# MinDist                         --> 1e-07
# OptimizationWindow              --> 2
# OptimizationPixels              --> 30
# OptimizationPrecisionLimit      --> 1e-20
#
#
# ---- Complete model analysis ----
#
#
# Interesting regions of the first grid (no iteration yet):
#
# ra:
# [-4.02644475e-07]
# dec:
# [7.20272201e-14]
# pixel_width:
# 1.4405444097100547e-13
#
#
# Iteration # 0
#
# Pixels to iterate over, RAs:
# [-4.0264447470369733e-07]
# Pixels to iterate over, DECs:
# [7.20272200600217e-14]
# Pixels to iterate over, source displacements:
# [8.877468730734367e-14]
#
#
#
# Pixel size of the last iteration: 9.603629380420511e-15
#
#
# Iteration # 1
#
# Pixels to iterate over, RAs:
# [-4.0264442188373563e-07]
# Pixels to iterate over, DECs:
# [-4.254810275819636e-22]
# Pixels to iterate over, source displacements:
# [9.254894822214714e-16]
#
#
#
# Pixel size of the last iteration: 6.402419763412205e-16
#
#
# Iteration # 2
#
# Pixels to iterate over, RAs:
# [-4.0264442284409857e-07]
# Pixels to iterate over, DECs:
# [3.201205538663233e-16]
# Pixels to iterate over, source displacements:
# [3.21949332625196e-16]
#
#
#
# Pixel size of the last iteration: 4.2682784305532245e-17
#
#
# Iteration # 3
#
# Pixels to iterate over, RAs:
# [-4.0264442282275715e-07]
# Pixels to iterate over, DECs:
# [-4.343042869232886e-22]
# Pixels to iterate over, source displacements:
# [1.3532200216804744e-17]
#
#
#
# Pixel size of the last iteration: 2.8455013071824152e-18
#
#
# Iteration # 4
#
# Pixels to iterate over, RAs:
# [-4.0264442280995234e-07]
# Pixels to iterate over, DECs:
# [1.4223251725641495e-18]
# Pixels to iterate over, source displacements:
# [1.5394208204862381e-18]
#
#
#
# Pixel size of the last iteration: 1.8968244062575988e-19
#
#
# Iteration # 5
#
# Pixels to iterate over, RAs:
# [-4.026444228092884e-07]
# Pixels to iterate over, DECs:
# [-4.254810270581107e-22]
# Pixels to iterate over, source displacements:
# [9.137521710020035e-20]
#
#
#
# Pixel size of the last iteration: 1.2652554649611111e-20
#
#
# Interesting regions of the first grid (no iteration yet):
#
# ra:
# [1.20829961e-06 1.20822312e-06 1.20743212e-06 1.20833058e-06
#  1.20767931e-06 1.20775350e-06 1.20823666e-06 1.20796555e-06
#  1.20773780e-06 1.20736398e-06 1.20798529e-06]
# dec:
# [-3.94060923e-10 -2.82850895e-10 -9.73087749e-11 -7.71411531e-11
#  -3.08996776e-11  2.03837034e-11  2.11039756e-11  7.31076288e-11
#   8.17508952e-11  3.97662284e-10  4.47793230e-10]
# pixel_width:
# 1.440544408121868e-13
#
#
# Iteration # 0
#
# Pixels to iterate over, RAs:
# [1.2082996121106056e-06, 1.208223119202452e-06, 1.2074321162671014e-06, 1.2083305838154134e-06, 1.207679313687801e-06, 1.2077535017248992e-06, 1.2082366603199029e-06, 1.2079655498620028e-06, 1.2077377997908337e-06, 1.207363978516524e-06, 1.2079852853204152e-06]
# Pixels to iterate over, DECs:
# [-3.94060923266085e-10, -2.8285089483943883e-10, -9.730877487373891e-11, -7.714115313833675e-11, -3.089967758787897e-11, 2.038370339642937e-11, 2.1103975601265164e-11, 7.31076287904093e-11, 8.175089524843874e-11, 3.976622842894169e-10, 4.47793229745988e-10]
# Pixels to iterate over, source displacements:
# [3.292304342135469e-10, 1.2390146414965997e-12, 4.9396802150930355e-12, 6.278053409729637e-13, 5.149838926439356e-13, 6.213504277647868e-13, 7.0531677928350454e-12, 4.686609589189253e-14, 1.9729131057626667e-13, 2.670780925740113e-12, 6.482858290579497e-13]
#
#
#
# Pixel size of the last iteration: 9.603629274541393e-15
#
#
# Iteration # 1
#
# Pixels to iterate over, RAs:
# [1.2082994728579795e-06, 1.2082231144006372e-06, 1.2074321402761749e-06, 1.2083305886172282e-06, 1.2076792800750983e-06, 1.2077535641484902e-06, 1.2082366843289764e-06, 1.2077378141962777e-06, 1.2073639545074504e-06, 1.2079853285367475e-06]
# Pixels to iterate over, DECs:
# [-3.939888960456789e-10, -2.8277886761903274e-10, -9.723674765333282e-11, -7.717476584119292e-11, -3.093329029073515e-11, 2.035009069357319e-11, 2.104155201024655e-11, 8.175569706313248e-11, 3.976382752159482e-10, 4.477308061549694e-10]
# Pixels to iterate over, source displacements:
# [2.7189977309202855e-10, 1.1155422610229846e-13, 1.2196119442991878e-13, 9.995052437186964e-14, 4.69144277777445e-14, 4.228660775834023e-14, 3.826205646719534e-13, 9.148577509903906e-14, 3.092777047055139e-13, 3.806426174316845e-14]
#
#
#
# Pixel size of the last iteration: 6.402419234016613e-16
#
#
# Iteration # 2
#
# Pixels to iterate over, RAs:
# [1.2082994635744713e-06, 1.2082231192024517e-06, 1.2074321418767798e-06, 1.2083305844556556e-06, 1.2076792759135257e-06, 1.2077535689503047e-06, 1.2082366820881295e-06, 1.2077378093944632e-06, 1.2073639548275715e-06, 1.2079853256556587e-06]
# Pixels to iterate over, DECs:
# [-3.9398921616665473e-10, -2.8278238894976675e-10, -9.723770801626028e-11, -7.717828717192692e-11, -3.093297016975933e-11, 2.0351051056500645e-11, 2.1038670921464188e-11, 8.175985863581811e-11, 3.9764179654668223e-10, 4.4772792506618704e-10]
# Pixels to iterate over, source displacements:
# [2.043252235627477e-10, 2.3031871015537672e-15, 3.1424488396993957e-15, 4.762287302082261e-15, 2.0571421963702373e-15, 1.5131097676324725e-15, 3.538694436357123e-14, 3.1513003080983357e-15, 1.057144126531692e-14, 9.805078482408325e-16]
#
#
#
# Pixel size of the last iteration: 4.268283724509145e-17
#
#
# Iteration # 3
#
# Pixels to iterate over, RAs:
# [1.2082994629555708e-06, 1.2082231190957446e-06, 1.2074321418127555e-06, 1.2083305842209002e-06, 1.207679275764136e-06, 1.2077535689289633e-06, 1.2082366817680087e-06, 1.207737809330439e-06, 1.2073639548915958e-06, 1.2079853255489516e-06]
# Pixels to iterate over, DECs:
# [-3.9398932287364196e-10, -2.827823249255744e-10, -9.723772935765773e-11, -7.717835119611926e-11, -3.0933119559541454e-11, 2.0351243129077667e-11, 2.1038820311246315e-11, 8.176009339119003e-11, 3.9764190325366946e-10, 4.477278610419947e-10]
# Pixels to iterate over, source displacements:
# [1.9441307133545255e-10, 1.336942671030517e-16, 1.3608274402960302e-15, 3.7588452809568246e-16, 1.8227080597914663e-16, 1.1214504986247138e-16, 2.0898880112920738e-15, 2.312920453546166e-16, 6.456358885671427e-16, 1.2052362432901098e-16]
#
#
#
# Pixel size of the last iteration: 2.8453954280640084e-18
#
#
# Iteration # 4
#
# Pixels to iterate over, RAs:
# [1.2082994629143108e-06, 1.2082231190971674e-06, 1.2074321418312513e-06, 1.2083305841995588e-06, 1.2076792757598677e-06, 1.2077535689218495e-06, 1.2082366817694315e-06, 1.2077378093261707e-06, 1.2073639548987096e-06, 1.207985325558911e-06]
# Pixels to iterate over, DECs:
# [-3.939893242964032e-10, -2.8278233203938063e-10, -9.723772224385152e-11, -7.71783526188805e-11, -3.0933101063645315e-11, 2.035125593392884e-11, 2.1038798969827693e-11, 8.176007774081637e-11, 3.9764189898538576e-10, 4.477278681558009e-10]
# Pixels to iterate over, source displacements:
# [1.937038233932101e-10, 2.3896142085862053e-18, 9.494914681582178e-17, 1.7222499382538705e-17, 2.00540725414211e-18, 6.0504474521991434e-18, 1.1426099817530181e-16, 1.0323457774222514e-17, 7.570070950566268e-17, 1.266728037709171e-17]
#
#
#
# Pixel size of the last iteration: 1.8973538018496328e-19
#
#
# Iteration # 5
#
# Pixels to iterate over, RAs:
# [1.2082994629115602e-06, 1.2082231190970726e-06, 1.2074321418322947e-06, 1.2083305842002226e-06, 1.2076792757599626e-06, 1.2077535689211856e-06, 1.208236681768578e-06, 1.2077378093268346e-06, 1.207363954897856e-06, 1.2079853255593854e-06]
# Pixels to iterate over, DECs:
# [-3.939893249603288e-10, -2.827823321342271e-10, -9.723772328716318e-11, -7.71783532828061e-11, -3.093310115849183e-11, 2.0351255649389297e-11, 2.1038799823446322e-11, 8.176007745627683e-11, 3.9764189908023225e-10, 4.477278693888056e-10]
# Pixels to iterate over, source displacements:
# [1.936562945423218e-10, 4.1530196108703215e-19, 4.651245271724397e-18, 1.4241597324201044e-18, 7.426928671639936e-19, 3.9079883352317396e-19, 1.0100133489178078e-17, 1.1403672441459876e-18, 1.8027760647592375e-18, 3.825782883325904e-19]
#
#
#
# Pixel size of the last iteration: 1.2705494208814505e-20
#
#
# Iteration # 6
#
# Pixels to iterate over, RAs:
# [1.2082994629113768e-06, 1.2082231190970916e-06, 1.207432141832225e-06, 1.2083305842002923e-06, 1.2076792757600323e-06, 1.2077535689212172e-06, 1.2082366817686222e-06, 1.2077378093268536e-06, 1.207363954897837e-06, 1.2079853255593917e-06]
# Pixels to iterate over, DECs:
# [-3.9398932491605724e-10, -2.8278233214055164e-10, -9.723772329348769e-11, -7.717835325118354e-11, -3.0933101152167315e-11, 2.035125560511771e-11, 2.1038799728578632e-11, 8.176007753849549e-11, 3.9764189907390774e-10, 4.477278694330772e-10]
# Pixels to iterate over, source displacements:
# [1.9365312473213512e-10, 8.35582816065428e-20, 4.1182735419950985e-19, 5.69752243594907e-20, 5.099245527701289e-20, 3.9583671693064006e-20, 6.859526752528949e-19, 6.367861370879597e-20, 1.6126548865192747e-19, 3.7732201704026346e-20]
#
#
#
# Pixel size of the last iteration: 8.470329472543003e-22
#
#
# Iteration # 7
#
# Pixels to iterate over, RAs:
# [1.2082994629113646e-06, 1.2082994629113646e-06, 1.2082994629113646e-06, 1.2082994629113646e-06, 1.2082994629113646e-06, 1.2074321418322263e-06, 1.2082366817686167e-06]
# Pixels to iterate over, DECs:
# [-3.9398932492664515e-10, -3.939893249198689e-10, -3.939893249156337e-10, -3.9398932491139856e-10, -3.939893249097045e-10, -9.723772329984044e-11, 2.103879973239028e-11]
# Pixels to iterate over, source displacements:
# [1.9365291243046494e-10, 1.9365291243040464e-10, 1.9365291243057879e-10, 1.9365291243058328e-10, 1.9365291243063584e-10, 1.3448781092031386e-20, 3.697662088682046e-20]
#
#
#
# Pixel size of the last iteration: 0.0
#
#
#
# Minumum pixel size reached. The iteration will be stopped.
#
#
#
# IMAGES OF THE COMPLETE MODEL
#
# ra: [-4.02644423e-07  1.20822312e-06  1.20833058e-06  1.20767928e-06
#   1.20775357e-06  1.20773781e-06  1.20736395e-06  1.20798533e-06]
# dec: [ 6.91247472e-20 -2.82782332e-10 -7.71783533e-11 -3.09331012e-11
#   2.03512556e-11  8.17600775e-11  3.97641899e-10  4.47727869e-10]
#
# Elapsed time: 147.91899275779724 seconds
#
# Time delays (seconds):  [2.95529327e+05 1.62035458e-02 3.01844210e-02 9.36317793e-03
#  4.09444969e-03 3.82398797e-03 7.20409062e-02 0.00000000e+00]
# magnifications:  [-1.00000007e+00 -2.85814659e-03 -3.25969956e-03 -9.65914366e-03
#  -1.58101777e-02 -4.83168804e-03 -1.36781041e-04 -1.34731522e-02]
# Morse indices:  [0, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5]
# T0 = -0.999998818939441
# Tscale = 295529.46212367347

# %%
masses
# Out:
# array([6.62719579e+01, 1.14471932e+02, 1.81761226e-02, 4.80458376e+01,
#        2.33220312e+01, 1.46741884e+01, 2.95999462e+01, 5.49155337e+01,
#        6.30531652e+01, 8.56272319e+01])

# %%
# plot only the microimages around the desired macroimage
Img_ra = np.delete(Img_ra, [0])
Img_dec = np.delete(Img_dec, [0])

# %%
# from lenstronomy.LensModel.Solver.lens_equation_solver import LensEquationSolver
# from lenstronomy.LensModel.lens_model import LensModel
# lensmodel = LensModel(lens_model_list=lens_model_list)
# solver = LensEquationSolver(
#     lensModel = lensmodel
# )
# Img_ra, Img_dec = solver.image_position_stochastic(
#     source_x = beta0,
#     source_y = beta1,
#     kwargs_lens = kwargs_lens_list,
#     # min_distance = 1e-13,
#     # solver='lenstronomy'
#     search_window = 20*thetaE2,
#     # verbose=True,
#     precision_limit=10**(-17),
#     x_center = MacroImg_ra[microtype],
#     y_center= MacroImg_dec[microtype]
# )

# %%
Img_ra, Img_dec
# Out:
# (array([1.20822312e-06, 1.20833058e-06, 1.20767928e-06, 1.20775357e-06,
#         1.20773781e-06, 1.20736395e-06, 1.20798533e-06]),
#  array([-2.82782332e-10, -7.71783533e-11, -3.09331012e-11,  2.03512556e-11,
#          8.17600775e-11,  3.97641899e-10,  4.47727869e-10]))

# %%
lens_model_complete = LensModel(lens_model_list=lens_model_list)
T = lens_model_complete.fermat_potential
T0 = thetaE ** (-2) * T(MacroImg_ra[microtype], MacroImg_dec[microtype], kwargs_lens_list, beta0, beta1)#[0]

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
plot_contour(ax, lens_model_list, eta10, eta11, 4*thetaE1, kwargs_lens_list, beta0, beta1, MacroImg_ra, MacroImg_dec,
                    T0 = T0, Tfac = (thetaE)**(-2), micro=False)
# Out:
# [-4.02644403e-07  1.20793321e-06] [-4.23516474e-22 -4.23516474e-22] Img_pos
# <Axes: >

# %%
fig1, ax1 = plt.subplots()
plot_contour(ax1, lens_model_list, MacroImg_ra[microtype], MacroImg_dec[microtype], 40*thetaE2, kwargs_lens_list, beta0, beta1, Img_ra, Img_dec,
                    T0 = T0, Tfac = (thetaE)**(-2), micro=True, contour=100)
# Out:
# [1.20822312e-06 1.20833058e-06 1.20767928e-06 1.20775357e-06
#  1.20773781e-06 1.20736395e-06 1.20798533e-06] [-2.82782332e-10 -7.71783533e-11 -3.09331012e-11  2.03512556e-11
#   8.17600775e-11  3.97641899e-10  4.47727869e-10] Img_pos
# <Axes: >

# %%
from lenstronomy.LensModel.lens_model_extensions import LensModelExtensions
# lens_model_list = ['POINT_MASS']
lens_model_complete = LensModel(lens_model_list=lens_model_list)
lensmodelext = LensModelExtensions(lens_model_complete)
ra_crit_list, dec_crit_list = lensmodelext.critical_curve_tiling(kwargs_lens_list, compute_window=40*thetaE2, start_scale = thetaE2/50, center_x=MacroImg_ra[1], center_y=MacroImg_dec[1])
ra_caustic_list, dec_caustic_list = lens_model_complete.ray_shooting(ra_crit_list, dec_crit_list, kwargs_lens_list)
macro_srcx, macro_srcy = lens_model_complete.ray_shooting(MacroImg_ra, MacroImg_dec, kwargs_lens_list)
# lens_srcx, lens_srcy = lens_model_complete.ray_shooting(eta20, eta21, kwargs_lens_list)

# %%
plt.scatter(ra_caustic_list, dec_caustic_list, s=1)
plt.scatter(macro_srcx, macro_srcy)

# %%
Tscale = 4 * (1 + zL) * mtot * M_sun * G / c ** 3

# %%
# Define the characteristic WindowSize
mL3 = 10
thetaE3 = param_processing(zL, zS, mL3)

# %%
import time

# %%
kwargs_macro = {'source_pos_x': beta0,
                'source_pos_y': beta1,
                'theta_E': thetaE,
                'mu': np.abs(Mus[microtype]),
               }

kwargs_integrator = {'PixelNum': int(40000),
                     'PixelBlockMax': 2000,
                     'WindowSize': 2.*210*thetaE3,
                     'WindowCenterX': MacroImg_ra[microtype],
                     'WindowCenterY': MacroImg_dec[microtype],
                     'T0': T0,
                     'TimeStep': 1e-5/Tscale, 
                     'TimeMax': T0 + .7/Tscale,
                     'TimeMin': T0 - .5/Tscale,
                     'TimeLength': 1./Tscale,
                     'TExtend': 10/Tscale,
                     'LastImageT': .02/Tscale,
                     'Tbuffer': .1/Tscale,
                     'Tscale': Tscale}


amplification = af.amplification_factor(lens_model_list=lens_model_list, kwargs_lens=kwargs_lens_list, kwargs_macro=kwargs_macro, **kwargs_integrator)
ts, Ft = amplification.integrator(gpu=False)
ws, Fws = amplification.fourier()
amplification.plot_freq()
# Out:
# start
# Integrating...:  12%|█▏        | 54/441 [01:45<12:39,  1.96s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 24
#       7 kwargs_integrator = {'PixelNum': int(40000),
#       8                      'PixelBlockMax': 2000,
#       9                      'WindowSize': 2.*210*thetaE3,
#    (...)
#      19                      'Tbuffer': .1/Tscale,
#      20                      'Tscale': Tscale}
#      23 amplification = af.amplification_factor(lens_model_list=lens_model_list, kwargs_lens=kwargs_lens_list, kwargs_macro=kwargs_macro, **kwargs_integrator)
# ---> 24 ts, Ft = amplification.integrator(gpu=False)
#      25 ws, Fws = amplification.fourier()
#      26 amplification.plot_freq()
#
# File ~/microlensing/wolensing_simon/wolensing/amplification_factor/amplification_factor.py:107, in amplification_factor.integrator(self, gpu)
#     104     bincount = histogram_routine_gpu(self._lens_model_list, Numblocks, np.array([[None, None]]), Nblock, Nresidue, x1corn, x2corn, Lblock, binnum,
#     105                     binmin, binmax, thetaE, self._kwargs_lens, y0, y1, dx)
#     106 else:
# --> 107     bincount = histogram_routine_cpu(self._lens_model_complete, Numblocks, np.array([[None, None]]), Nblock, Nresidue, x1corn, x2corn, Lblock, binnum,
#     108                     binmin, binmax, thetaE, self._kwargs_lens, y0, y1, dx)
#     111 print(bincount)
#     112 # trimming the array
#
# File ~/microlensing/wolensing_simon/wolensing/utils/histogram.py:116, in histogram_routine_cpu(lens_model_complete, Numblocks, macroimindx, Nblock, Nresidue, x1corn, x2corn, Lblock, binnum, binmin, binmax, Scale, kwargs_lens, y0, y1, dx)
#     114 x2blockcorn = x2corn + j * Lblock
#     115 X1, X2 = gridfromcorn(x1blockcorn, x2blockcorn, dx, Nblock1, Nblock2)
# --> 116 Ts = Scale ** (-2) * T(X1, X2, kwargs_lens, y0, y1)
#     117 bincount += histogram1d(Ts, binnum, (binmin, binmax)) * dx ** 2
#     118 pbar.update(1)
#
# File ~/.conda/envs/wolensing/lib/python3.10/site-packages/lenstronomy/LensModel/lens_model.py:201, in LensModel.fermat_potential(self, x_image, y_image, kwargs_lens, x_source, y_source)
#     186 """Fermat potential (negative sign means earlier arrival time) for Multi-plane
#     187 lensing, it computes the effective Fermat potential (derived from the arrival
#     188 time and subtracted off the time-delay distance for the given cosmology). The
#    (...)
#     198     1 in Suyu et al. 2013) as a list
#     199 """
#     200 if hasattr(self.lens_model, "fermat_potential"):
# --> 201     return self.lens_model.fermat_potential(
#     202         x_image, y_image, kwargs_lens, x_source, y_source
#     203     )
#     204 elif hasattr(self.lens_model, "arrival_time") and hasattr(self, "_lensCosmo"):
#     205     dt = self.lens_model.arrival_time(x_image, y_image, kwargs_lens)
#
# File ~/.conda/envs/wolensing/lib/python3.10/site-packages/lenstronomy/LensModel/single_plane.py:44, in SinglePlane.fermat_potential(self, x_image, y_image, kwargs_lens, x_source, y_source, k)
#      28 def fermat_potential(
#      29     self, x_image, y_image, kwargs_lens, x_source=None, y_source=None, k=None
#      30 ):
#      31     """Fermat potential (negative sign means earlier arrival time)
#      32
#      33     :param x_image: image position
#    (...)
#      41         1 in Suyu et al. 2013) as a list
#      42     """
# ---> 44     potential = self.potential(x_image, y_image, kwargs_lens, k=k)
#      45     if x_source is None or y_source is None:
#      46         x_source, y_source = self.ray_shooting(x_image, y_image, kwargs_lens, k=k)
#
# File ~/.conda/envs/wolensing/lib/python3.10/site-packages/lenstronomy/LensModel/single_plane.py:70, in SinglePlane.potential(self, x, y, kwargs, k)
#      68 for i, func in enumerate(self.func_list):
#      69     if bool_list[i] is True:
# ---> 70         potential += func.function(x, y, **kwargs[i])
#      71 return potential
#
# File ~/.conda/envs/wolensing/lib/python3.10/site-packages/lenstronomy/LensModel/Profiles/point_mass.py:40, in PointMass.function(self, x, y, theta_E, center_x, center_y)
#      38     r[a > self.r_min] = a[a > self.r_min]  # in the SIS regime
#      39     r[a <= self.r_min] = self.r_min
# ---> 40 phi = theta_E**2 * np.log(r)
#      41 return phi
#
# KeyboardInterrupt:

# %%
ws1, Fws1 = amplification.fourier(freq_end = 4000)

# %%
plt.plot(ts, Ft)

# %%
amplification.plot_freq(smooth=False)

# %%
amplification.plot_freq(pha=True, smooth=False)

# %% [markdown]
# # Geometrical optics
# To get the geometrical optics around type 1 image, we need the magnifications, time delay and the image positions of the microimages

# %%
tds = TimeDelay(Img_ra, Img_dec,
               beta0, beta1,
               zL, zS,
               lens_model_list, kwargs_lens_list)
mus = magnifications(Img_ra, Img_dec, lens_model_list, kwargs_lens_list)
ns = getMinMaxSaddle(Img_ra, Img_dec, lens_model_list, kwargs_lens_list, diff = None)

# %%
# mus = mus[1:]
# tds = tds[1:]

# %%
Img_dec

# %%
geofs, geoFws = amplification.geometrical_optics(mus, tds, Img_ra, Img_dec, upper_lim=4000)

# %%
plt.semilogx(geofs, np.abs(geoFws))

# %%
plt.semilogx(geofs, np.angle(geoFws))

# %% [markdown]
# # Full amplification factor concatenated with geometrical optics
# Given the computaional cost of the diffraction integral, we concatenate the result of wave optics at low frequency and geometrical optics at high frequency to obtain a full amplification factor with default upper bound of 3000Hz.

# %%
fullfs, fullFws = amplification.concatenate()
plt.semilogx(fullfs, np.abs(fullFws))

# %%
plt.semilogx(fullfs, np.angle(fullFws))

# %%
fac = np.sqrt(np.abs(Mus[microtype]))

# %%
plt.clf()
plt.rc('text', usetex=True)
plt.rc('font', family='serif')

# %%
from bisect import bisect_left
low_index = bisect_left(geofs, 1)
geofs = geofs[low_index:]
geoFws = geoFws[low_index:]
ws = ws[low_index:]
Fws = Fws[low_index:]

# %%
ww = geofs
plt.semilogx(geofs, (fac*np.exp(-ww*np.pi/1.8) + (1-np.exp(-ww*np.pi/1.8))*np.abs(geoFws))/fac, label='Approximation')
plt.semilogx(geofs, np.abs(geoFws)/fac,label=r'$F_{geo}$')
plt.semilogx(ws, np.abs(Fws)/fac, label=r'$F_{wave}$')
# plt.semilogx(ws1, np.abs(Fws1)/fac, label=r'$F_{wave}$')
plt.ylabel(r'$|F|/\sqrt{\mu}$')
plt.xlabel(r'$f$')
plt.grid(which='both', alpha=0.5)
plt.legend()
plt.xlim(1, 4000)
# plt.savefig('./approx.png',bbox_inches='tight', dpi=300)

# %%
plt.semilogx(geofs, (1-np.exp(-ww*np.pi/37.5))*np.angle(geoFws), label='Approximation')
plt.semilogx(geofs, np.angle(geoFws),label=r'$F_{geo}$')
plt.semilogx(ws, np.angle(Fws), label=r'$F_{wave}$')
plt.ylabel(r'$args(F)$')
plt.xlabel(r'$f$')
plt.grid(which='both', alpha=0.5)
plt.legend()
plt.xlim(1, 4000)
# plt.savefig('./approx_ang.png',bbox_inches='tight', dpi=300)

# %%
Abs = (fac*np.exp(-ww*np.pi/1000) + (1-np.exp(-ww*np.pi/1000))*np.abs(geoFws))/fac
Pha = (1-np.exp(-ww*np.pi/1000))*np.angle(geoFws)
complete_approx = Abs * np.exp(1j * Pha)

# %%
from bisect import bisect_left
i = bisect_left(ws, 60)

# %%
i

# %%
plt.semilogx(ww,(1-np.exp(-ww*np.pi/1000)))

# %%
plt.semilogx(ww, np.exp(-ww*np.pi/20))

# %%
import pycbc.psd as psd
from pycbc.filter.matchedfilter import overlap, match

hp, hc = get_fd_waveform(approximant = 'IMRPhenomXPHM',
                         mass1 = 30,
                         mass2 = 30,
                         delta_f = .04,
                         f_lower = 10,
                         f_final = 2000)
dfnoise = 0.04
noiselen = int(2001/dfnoise)+1
noise2 = psd.analytical.aLIGOaLIGODesignSensitivityT1800044(noiselen, dfnoise, 1)
noisef = np.linspace(1, 1 + dfnoise*(noiselen-1), num = noiselen)

# %%
np.savetxt('gf.txt', geofs)
np.savetxt('complete.txt', complete_approx)
np.savetxt('ws.txt', ws)
np.savetxt('Fws.txt', Fws)

# %%
np.savetxt('gwoF.txt', geoFws)

# %%
mus, tds, ns

# %%
Img_ra

# %%
from wolensing.utils.utils import *
Morse_indices(amplification._lens_model_list, Img_ra, Img_dec, amplification._kwargs_lens)

# %%
plt.plot(geofs, -0.000435*geofs + np.pi - 23/geofs)
