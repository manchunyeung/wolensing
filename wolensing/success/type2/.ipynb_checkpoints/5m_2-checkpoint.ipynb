# %%
import numpy as np

# %%
# %env JAX_ENABLE_X64=True
# Out:
# env: JAX_ENABLE_X64=True

# %%
from lenstronomy.LensModel.lens_model import LensModel
import lensinggw.constants.constants as const
from lensinggw.utils.utils import TimeDelay, magnifications, getMinMaxSaddle

# %%
import sys
sys.path.append('/home/manchun.yeung/microlensing/wolensing_simon/wolensing/')

# %%
from plot.plot import plot_contour
import amplification_factor.amplification_factor as af
from lensmodels.potential import potential
import numpy as np

# %% [markdown]
# The macroimage where the microlens is placed around.

# %%
type2 = True

# %%
ym = 0.8
angle = np.radians(float(0))

# %% [markdown]
# Importing constants

# %%
G = const.G  # gravitational constant [m^3 kg^-1 s^-2]
c = const.c  # speed of light [m/s]
M_sun = const.M_sun  # Solar mass [Kg]

# %%
y0, y1 = 0.5, 0 # source position
l0, l1 = 0., 0 # lens position

zS = 1.0 # source redshift
zL = 0.5 # lens redshift

# %%
mL1 = 1e10
mL2 = 20
mtot = mL1 + mL2

# convert to radians
from lensinggw.utils.utils import param_processing
thetaE1 = param_processing(zL, zS, mL1)
thetaE2 = param_processing(zL, zS, mL2)
thetaE = param_processing(zL, zS, mtot)

# %%
Mpc=3.085677581491367e+22
from astropy.cosmology import FlatLambdaCDM
cosmo = FlatLambdaCDM(H0=69.7, Om0=0.306, Tcmb0=2.725)
DL       = cosmo.angular_diameter_distance(zL)
DS       = cosmo.angular_diameter_distance(zS)
DLS      = cosmo.angular_diameter_distance_z1z2(zL, zS)
D        = DLS/(DL*DS)
print(np.float64(D/Mpc))
# Out:
# 1.097926071881248e-26

# %%
from utils.utils import Einstein_radius

# %%
beta0, beta1 = y0 * thetaE, y1 * thetaE
eta10, eta11 = 0 * l0 * thetaE, 0 * l1 * thetaE
lens_model_list = ['SIS']
kwargs_sis_1 = {'center_x': eta10, 'center_y': eta11, 'theta_E': thetaE1}
kwargs_lens_list = [kwargs_sis_1]

kwargs_sis_1_scaled = {'center_x': eta10 / thetaE, 'center_y': eta11 / thetaE, 'theta_E': thetaE1 / thetaE}
kwargs_lens_list_scaled = [kwargs_sis_1_scaled]

from lensinggw.solver.images import microimages
solver_kwargs = {'SearchWindowMacro': 10 * thetaE1,
                 'SearchWindow': 5 * thetaE2,
                 'OverlapDistMacro': 1e-17,
                 'OnlyMacro': True}
MacroImg_ra, MacroImg_dec, pixel_width = microimages(source_pos_x=beta0,
                                                     source_pos_y=beta1,
                                                     lens_model_list=lens_model_list,
                                                     kwargs_lens=kwargs_lens_list,
                                                     **solver_kwargs)

Td = TimeDelay(MacroImg_ra, MacroImg_dec,
                beta0, beta1,
                zL, zS,
                lens_model_list, kwargs_lens_list)
Mus = magnifications(MacroImg_ra, MacroImg_dec, lens_model_list, kwargs_lens_list)
if type2:
    microtype = np.nonzero(Td)[0][0]
else:
    microtype = np.where(Td==0)[0][0]

masses = [60, 40, 20, 30, 3, 5]
angle = [0, 150, 260]
ym = [1., .4, 4.]

mass_density = 100
from utils.lensing import *
radius = injection_radius(masses, mass_density) #rad
lens_model_list, kwargs_lens_list = field_injection(zL, zS, MacroImg_ra[microtype], MacroImg_dec[microtype], masses, radius, lens_model_list, kwargs_lens_list, seed=1)

from lensinggw.solver.images import microimages
solver_kwargs = {'SearchWindowMacro': 10 * thetaE1,
                 'SearchWindow': 20 * thetaE2,
                 'Pixels': 5*1e3,
                 # 'ÍmgIndex': 1,
                 'Optimization': True,
                 'Verbose': True,
                 'OverlapDist': 1e-18,
                 'OverlapDistMacro': 1e-17}
solver_kwargs.update({'Improvement' : 0.1})
solver_kwargs.update({'MinDist' : 10**(-7)})

Img_ra, Img_dec, MacroImg_ra, MacroImg_dec, pixel_width = microimages(source_pos_x=beta0,
                                                                      source_pos_y=beta1,
                                                                      lens_model_list=lens_model_list,
                                                                      kwargs_lens=kwargs_lens_list,
                                                                      **solver_kwargs)

# time delays, magnifications, Morse indices 
from lensinggw.utils.utils import TimeDelay, magnifications, getMinMaxSaddle
from lensinggw.amplification_factor.amplification_factor import geometricalOpticsMagnification
tds = TimeDelay(Img_ra, Img_dec,
               beta0, beta1,
               zL, zS,
               lens_model_list, kwargs_lens_list)
mus = magnifications(Img_ra, Img_dec, lens_model_list, kwargs_lens_list)
ns = getMinMaxSaddle(Img_ra, Img_dec, lens_model_list, kwargs_lens_list, diff = None)
print('Time delays (seconds): ', tds)
print('magnifications: ', mus)
print('Morse indices: ', ns)
    
lens_model_complete = LensModel(lens_model_list=lens_model_list)
T = lens_model_complete.fermat_potential
T0 = thetaE ** (-2) * T(Img_ra[microtype], Img_dec[microtype], kwargs_lens_list, beta0, beta1)#[0]
if not isinstance(T0, float):
    T0 = T0[0]
Tscale = 4 * (1 + zL) * mtot * M_sun * G / c ** 3
print('T0 = {}'.format(T0))
print('Tscale = {}'.format(Tscale))
# Out:
# ---- Will perform only the macromodel analysis ----
#
# ---- Solver settings ----
#
# The macromodel analysis will be performed with the following settings:
#
# OnlyMacro         --> True
# Scaled            --> False
# SearchWindowMacro --> 8.052888061582412e-06
# PixelsMacro       --> 1000
# PrecisionLimit    --> 1e-20
# OverlapDistMacro  --> 1e-17
# NearSource        --> False
# Optimization      --> False
# Verbose           --> False
#
#
#
#
# MACROIMAGES
#
# ra: [-4.02644403e-07  1.20793321e-06]
# dec: [-4.23516474e-22 -4.23516474e-22]
#
#
# ---- Solver settings ----
#
# The macromodel analysis will be performed with the following settings:
#
# OnlyMacro         --> False
# Scaled            --> False
# SearchWindowMacro --> 8.052888061582412e-06
# PixelsMacro       --> 1000
# PrecisionLimit    --> 1e-20
# OverlapDistMacro  --> 1e-17
# NearSource        --> False
# Optimization      --> False
# Verbose           --> True
#
#
# ---- Macromodel analysis ----
#
# Interesting regions of the first grid (no iteration yet):
#
# ra:
# [-4.06670847e-07  1.20390677e-06]
# dec:
# [4.02644403e-09 4.02644403e-09]
# pixel_width:
# 8.052888061582012e-09
#
#
# Iteration # 0
#
# Pixels to iterate over, RAs:
# [-4.066708467072679e-07, 1.2039067656092146e-06]
# Pixels to iterate over, DECs:
# [4.026444030790582e-09, 4.026444030790582e-09]
# Pixels to iterate over, source displacements:
# [5.666135983470095e-09, 4.237143739907385e-09]
#
#
#
# Pixel size of the last iteration: 5.368592041055239e-10
#
#
#
#
# MACROIMAGES
#
# ra: [-4.02644403e-07  1.20793321e-06]
# dec: [-4.23516474e-22 -4.23516474e-22]
#
# Elapsed time: 0.07108187675476074 seconds
#
#
# ---- Solver settings ----
#
# The complete model analysis will be performed with the following settings:
#
# Scaled         --> False
# OnlyMacro      --> False
# MacroIndex     --> [0]
# ImgIndex       --> None
# SearchWindow   --> 7.202722048357913e-10
# Pixels         --> 5000.0
# OverlapDist    --> 1e-18
# PrecisionLimit --> 1e-20
# Optimization   --> False
# Verbose        --> True
# Improvement    --> 0.1
# MinDist        --> 1e-07
#
#
# ---- Complete model analysis ----
#
#
# Interesting regions of the first grid (no iteration yet):
#
# ra:
# [-4.02682793e-07 -4.02415140e-07 -4.02617248e-07 -4.02765624e-07
#  -4.02501573e-07 -4.02321649e-07 -4.02744016e-07]
# dec:
# [-1.78411425e-10  2.16081661e-13  6.12231374e-12  4.05513251e-11
#   1.87054692e-10  2.10535565e-10  2.80834133e-10]
# pixel_width:
# 1.4405444097100547e-13
#
#
# Iteration # 0
#
# Pixels to iterate over, RAs:
# [-4.026827931849946e-07, -4.0241514003367763e-07, -4.0261724841435455e-07, -4.027656244885507e-07, -4.0250157269825796e-07, -4.0232164870148994e-07, -4.0274401632240565e-07]
# Pixels to iterate over, DECs:
# [-1.7841142513824902e-10, 2.1608166102725316e-13, 6.122313740680744e-12, 4.0551325131831536e-11, 1.8705469159543153e-10, 2.1053556547307831e-10, 2.808341326650516e-10]
# Pixels to iterate over, source displacements:
# [5.525643272708683e-13, 9.98799840221645e-13, 5.191284573125458e-14, 3.0575182435645033e-13, 1.850803412845699e-11, 3.040402891664025e-11, 2.4738106426922498e-12]
#
#
#
# Pixel size of the last iteration: 9.60362943336007e-15
#
#
# Iteration # 1
#
# Pixels to iterate over, RAs:
# [-4.0268277877955054e-07, -4.0241516404275114e-07, -4.0261721480165167e-07, -4.02765571668589e-07, -4.0250163512184904e-07, -4.0232161508878705e-07, -4.0274399231333215e-07]
# Pixels to iterate over, DECs:
# [-1.7844503784114224e-10, 2.2088347572628667e-13, 6.098304667185577e-12, 4.059454146412284e-11, 1.8704028615133443e-10, 2.1059798906416574e-10, 2.807909163327603e-10]
# Pixels to iterate over, source displacements:
# [1.278001986443984e-14, 1.8970987973136058e-13, 4.37521242660655e-15, 1.0808627573529325e-14, 1.4142164744908257e-12, 6.83580491238211e-14, 1.0177780773555883e-13]
#
#
#
# Pixel size of the last iteration: 6.402419763412205e-16
#
#
# Iteration # 2
#
# Pixels to iterate over, RAs:
# [-4.026827797399135e-07, -4.024151682043239e-07, -4.026172125608048e-07, -4.0276557262895196e-07, -4.0250163736269593e-07, -4.02321615408908e-07, -4.027439932736951e-07]
# Pixels to iterate over, DECs:
# [-1.7844471772016113e-10, 2.250450484807427e-13, 6.095423578355569e-12, 4.059678231099062e-11, 1.8704444772408888e-10, 2.1059766894318463e-10, 2.8079251693766583e-10]
# Pixels to iterate over, source displacements:
# [3.226920871980637e-15, 1.2244953008906503e-14, 3.1399426137215134e-16, 1.2998858462324487e-15, 7.5637727668435e-14, 1.4049754755356114e-13, 1.4093476922151965e-14]
#
#
#
# Pixel size of the last iteration: 4.2682784305532245e-17
#
#
# Iteration # 3
#
# Pixels to iterate over, RAs:
# [-4.0268277954784087e-07, -4.024151679268857e-07, -4.0261721266751176e-07, -4.027655723515138e-07, -4.025016376401341e-07, -4.0232161513146984e-07, -4.0274399355113326e-07]
# Pixels to iterate over, DECs:
# [-1.7844469637876192e-10, 2.248102930894176e-13, 6.095188822964244e-12, 4.0596889017986675e-11, 1.870444690654881e-10, 2.105978183329791e-10, 2.807924529134682e-10]
# Pixels to iterate over, source displacements:
# [2.570167211105884e-16, 4.466501827309743e-16, 1.581748493155098e-17, 1.557858829212432e-17, 8.067773113829394e-15, 9.395387165612602e-15, 6.648455262368262e-16]
#
#
#
# Pixel size of the last iteration: 2.8455542467416186e-18
#
#
# Iteration # 4
#
# Pixels to iterate over, RAs:
# [-4.026827795321905e-07, -4.02415167925463e-07, -4.0261721267462557e-07, -4.0276557235578203e-07, -4.025016376187927e-07, -4.023216151357381e-07, -4.027439935383284e-07]
# Pixels to iterate over, DECs:
# [-1.7844468926496453e-10, 2.2482309792470925e-13, 6.095176018128952e-12, 4.05968875952272e-11, 1.8704448756136128e-10, 2.1059783967437125e-10, 2.8079245433622767e-10]
# Pixels to iterate over, source displacements:
# [1.4617554254542133e-17, 1.815730188060777e-17, 1.4581819677435105e-18, 6.839104682359163e-18, 2.156697017738747e-16, 1.0223468301055712e-16, 4.479538682512221e-17]
#
#
#
# Pixel size of the last iteration: 1.8968244062575988e-19
#
#
# Iteration # 5
#
# Pixels to iterate over, RAs:
# [-4.026827795322854e-07, -4.024151679249887e-07, -4.026172126749101e-07, -4.0276557235435923e-07, -4.0250163761945665e-07, -4.023216151356432e-07, -4.0274399353823353e-07]
# Pixels to iterate over, DECs:
# [-1.784446901186308e-10, 2.2482319277651747e-13, 6.09517725120246e-12, 4.059688693126454e-11, 1.870444876562131e-10, 2.1059783938981582e-10, 2.807924534825614e-10]
# Pixels to iterate over, source displacements:
# [1.6106185501885922e-18, 2.0690146833965824e-18, 1.104905928800006e-19, 1.4254810767945687e-19, 2.6028015166622563e-17, 4.001694268625119e-17, 3.909041730641113e-18]
#
#
#
# Pixel size of the last iteration: 1.2652554649611111e-20
#
#
# Iteration # 6
#
# Pixels to iterate over, RAs:
# [-4.0268277953235494e-07, -4.024151679249318e-07, -4.027655723543782e-07, -4.025016376195262e-07, -4.023216151356116e-07, -4.027439935383031e-07]
# Pixels to iterate over, DECs:
# [-1.7844469020082651e-10, 2.2482316116277737e-13, 4.059688696287828e-11, 1.8704448761195387e-10, 2.1059783947201154e-10, 2.8079245347623865e-10]
# Pixels to iterate over, source displacements:
# [5.761395776866701e-20, 2.0170576878003646e-19, 2.848595685834469e-20, 2.029548422443676e-18, 1.9336757363684977e-18, 3.59600627485127e-19]
#
#
#
# Pixel size of the last iteration: 8.470329472543003e-22
#
#
# Iteration # 7
#
# Pixels to iterate over, RAs:
# [-4.024151679249373e-07, -4.0250163761953257e-07, -4.023216151356129e-07, -4.027439935383086e-07]
# Pixels to iterate over, DECs:
# [2.2482316074102555e-13, 1.870444876081581e-10, 2.105978394766508e-10, 2.8079245347159935e-10]
# Pixels to iterate over, source displacements:
# [1.2093705354770815e-20, 1.2754009642279262e-19, 1.8089360174766253e-19, 2.1088654527543703e-20]
#
#
#
# Pixel size of the last iteration: 5.293955920339377e-23
#
#
# Interesting regions of the first grid (no iteration yet):
#
# ra:
# [1.20793328e-06]
# dec:
# [-7.20272209e-14]
# pixel_width:
# 1.4405444102394502e-13
#
#
# Iteration # 0
#
# Pixels to iterate over, RAs:
# [1.207933281667226e-06]
# Pixels to iterate over, DECs:
# [-7.202722090705465e-14]
# Pixels to iterate over, source displacements:
# [6.99170210364947e-14]
#
#
#
# Pixel size of the last iteration: 9.603629274541393e-15
#
#
# Iteration # 1
#
# Pixels to iterate over, RAs:
# [1.207933219243635e-06]
# Pixels to iterate over, DECs:
# [-3.9508214007063984e-22]
# Pixels to iterate over, source displacements:
# [3.2419305702702855e-15]
#
#
#
# Pixel size of the last iteration: 6.402419234016613e-16
#
#
# Iteration # 2
#
# Pixels to iterate over, RAs:
# [1.2079332157223044e-06]
# Pixels to iterate over, DECs:
# [-3.2012137090018566e-16]
# Pixels to iterate over, source displacements:
# [2.990323896864879e-16]
#
#
#
# Pixel size of the last iteration: 4.268283724509145e-17
#
#
# Iteration # 3
#
# Pixels to iterate over, RAs:
# [1.2079332159997426e-06]
# Pixels to iterate over, DECs:
# [-4.091993550167599e-22]
# Pixels to iterate over, source displacements:
# [1.967070966331353e-18]
#
#
#
# Pixel size of the last iteration: 2.8453954280640084e-18
#
#
# Iteration # 4
#
# Pixels to iterate over, RAs:
# [1.2079332160011654e-06]
# Pixels to iterate over, DECs:
# [-1.4231704408580687e-18]
# Pixels to iterate over, source displacements:
# [6.328744706460118e-19]
#
#
#
# Pixel size of the last iteration: 1.8973538018496328e-19
#
#
# Iteration # 5
#
# Pixels to iterate over, RAs:
# [1.2079332160016395e-06]
# Pixels to iterate over, DECs:
# [-3.7985878390126534e-19]
# Pixels to iterate over, source displacements:
# [6.695377916884574e-20]
#
#
#
# Pixel size of the last iteration: 1.2705494208814505e-20
#
#
#
#
# IMAGES OF THE COMPLETE MODEL
#
# ra: [-4.02617213e-07 -4.02682780e-07 -4.02765572e-07 -4.02415168e-07
#  -4.02501638e-07 -4.02321615e-07 -4.02743994e-07  1.20793322e-06]
# dec: [ 6.09517727e-12 -1.78444690e-10  4.05968870e-11  2.24823161e-13
#   1.87044488e-10  2.10597839e-10  2.80792453e-10 -4.24130373e-19]
#
# Elapsed time: 21.867983102798462 seconds
#
# Time delays (seconds):  [295529.50429329 295529.49863919 295529.50909055 295529.51569694
#  295529.49934729 295529.51491205 295529.48937564      0.        ]
# magnifications:  [-7.47273639e-01 -4.21000069e-03 -5.11072164e-02 -8.49018969e-04
#  -1.18033575e-05 -5.25851821e-06 -3.72816554e-04  2.99999999e+00]
# Morse indices:  [0, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0]
# T0 = 3.5494642880797663e-07
# Tscale = 295529.46212367347

# %%
# plot only the microimages around the desired macroimage
Img_ra = np.delete(Img_ra, [-1])
Img_dec = np.delete(Img_dec, [-1])

# %%
filename = __file__
np.savetxt(f'./data/{filename}_pos.txt', np.array([Img_ra, Img_dec]))
np.savetxt(f'./data/{filename}_kwargs.txt', kwargs_lens_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 filename = __file__
#       2 np.savetxt(f'./data/{filename}_pos.txt', np.array([Img_ra, Img_dec]))
#       3 np.savetxt(f'./data/{filename}_kwargs.txt', kwargs_lens_list)
#
# NameError: name '__file__' is not defined

# %%
lens_model_complete = LensModel(lens_model_list=lens_model_list)
T = lens_model_complete.fermat_potential
T0 = thetaE ** (-2) * T(MacroImg_ra[microtype], MacroImg_dec[microtype], kwargs_lens_list, beta0, beta1)#[0]

# %%
import matplotlib.pyplot as plt

fig1, ax1 = plt.subplots()
plot_contour(ax1, lens_model_list, MacroImg_ra[microtype], MacroImg_dec[microtype], 40*thetaE2, kwargs_lens_list, beta0, beta1, Img_ra, Img_dec,
                    T0 = T0, Tfac = (thetaE)**(-2), micro=True)
# plt.savefig(f'./data/{filename}_tdpic.png')
# Out:
# [-4.02617213e-07 -4.02682780e-07 -4.02765572e-07 -4.02415168e-07
#  -4.02501638e-07 -4.02321615e-07 -4.02743994e-07] [ 6.09517727e-12 -1.78444690e-10  4.05968870e-11  2.24823161e-13
#   1.87044488e-10  2.10597839e-10  2.80792453e-10] Img_pos
# <Axes: >

# %%
Tscale = 4 * (1 + zL) * mtot * M_sun * G / c ** 3

# %%
# Define the characteristic WindowSize
mL3 = 10
thetaE3 = param_processing(zL, zS, mL3)

# %%
import time

# %%
kwargs_macro = {'source_pos_x': beta0,
                'source_pos_y': beta1,
                'theta_E': thetaE,
                'mu': np.abs(Mus[microtype]),
               }

kwargs_integrator = {'PixelNum': int(300000),
                     'PixelBlockMax': 2000,
                     'WindowSize': 10.*210*thetaE3,
                     'WindowCenterX': MacroImg_ra[microtype],
                     'WindowCenterY': MacroImg_dec[microtype],
                     'T0': T0,
                     'TimeStep': 1e-6/Tscale, 
                     'TimeMax': T0 + 7/Tscale,
                     'TimeMin': T0 - 5/Tscale,
                     'TExtend': 12/Tscale,
                     'LastImageT': 4e-7/Tscale,
                     'Tbuffer': 0./Tscale,
                     'Tscale': Tscale}

amplification = af.amplification_factor(lens_model_list=lens_model_list, kwargs_lens=kwargs_lens_list, kwargs_macro=kwargs_macro, **kwargs_integrator)
ts, Ft = amplification.integrator(gpu=False)
ws, Fws = amplification.fourier()
# Out:
# start
# Integrating...: 100%|██████████| 441/441 [09:53<00:00,  1.35s/it]
# [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 2.39523674e-22
#  2.43027155e-22 2.38951677e-22]
# 49976 1 shi
# total time 10.99999
# <Axes: xlabel='Frequency (Hz)', ylabel='$|F|/\\sqrt{\\mu}$'>

# %% [markdown]
# # Geometrical optics
# To get the geometrical optics around type 1 image, we need the magnifications, time delay and the image positions of the microimages

# %%
tds = TimeDelay(Img_ra, Img_dec,
               beta0, beta1,
               zL, zS,
               lens_model_list, kwargs_lens_list)
mus = magnifications(Img_ra, Img_dec, lens_model_list, kwargs_lens_list)
ns = getMinMaxSaddle(Img_ra, Img_dec, lens_model_list, kwargs_lens_list, diff = None)

# %%
geofs, geoFws = amplification.geometrical_optics(mus, tds, Img_ra, Img_dec, upper_lim=2000)

# %% [markdown]
# # Full amplification factor concatenated with geometrical optics
# Given the computaional cost of the diffraction integral, we concatenate the result of wave optics at low frequency and geometrical optics at high frequency to obtain a full amplification factor with default upper bound of 3000Hz.

# %%
fac = np.sqrt(np.abs(Mus[microtype]))

# %%
plt.clf()
plt.rc('text', usetex=True)
plt.rc('font', family='serif')

# %%
from bisect import bisect_left
low_index = bisect_left(geofs, 1)
geofs = geofs[low_index:]
geoFws = geoFws[low_index:]
ws = ws[low_index:]
Fws = Fws[low_index:]

# %%
ww = geofs
plt.semilogx(geofs, (fac*np.exp(-ww*np.pi/188) + (1-np.exp(-ww*np.pi/188))*np.abs(geoFws))/fac, label='Approximation')
plt.semilogx(geofs, np.abs(geoFws)/fac,label=r'$F_{geo}$')
plt.semilogx(ws, np.abs(Fws)/fac, label=r'$F_{wave}$')
plt.ylabel(r'$|F|/\sqrt{\mu}$')
plt.xlabel(r'$f$')
plt.grid(which='both', alpha=0.5)
plt.legend()
plt.xlim(1, 2000)
plt.savefig(f'./{filename}_abs.png',bbox_inches='tight', dpi=300)
# Out:
# (1, 2000)

# %%
plt.semilogx(geofs, (1-np.exp(-ww*np.pi/37.5))*np.angle(geoFws), label='Approximation')
plt.semilogx(geofs, np.angle(geoFws),label=r'$F_{geo}$')
plt.semilogx(ws, np.angle(Fws), label=r'$F_{wave}$')
plt.ylabel(r'$args(F)$')
plt.xlabel(r'$f$')
plt.grid(which='both', alpha=0.5)
plt.legend()
plt.xlim(1, 2000)
plt.savefig(f'./{filename}_pha.png',bbox_inches='tight', dpi=300)
# Out:
# (1, 2000)
