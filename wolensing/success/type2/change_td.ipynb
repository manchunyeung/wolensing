# %%
import numpy as np

# %%
# %env JAX_ENABLE_X64=True
# Out:
# env: JAX_ENABLE_X64=True

# %%
from lenstronomy.LensModel.lens_model import LensModel
import lensinggw.constants.constants as const
from lensinggw.utils.utils import TimeDelay, magnifications, getMinMaxSaddle

# %%
import sys
sys.path.append('/home/manchun.yeung/microlensing/wolensing_simon/wolensing/')

# %%
from plot.plot import plot_contour
import amplification_factor.amplification_factor as af
from lensmodels.potential import potential
import numpy as np

# %% [markdown]
# The macroimage where the microlens is placed around.

# %%
type2 = True

# %%
ym = 0.8
angle = np.radians(float(0))

# %% [markdown]
# Importing constants

# %%
G = const.G  # gravitational constant [m^3 kg^-1 s^-2]
c = const.c  # speed of light [m/s]
M_sun = const.M_sun  # Solar mass [Kg]

# %%
y0, y1 = 0.5, 0 # source position
l0, l1 = 0., 0 # lens position

zS = 1.0 # source redshift
zL = 0.5 # lens redshift

# %%
mL1 = 1e10
mL2 = 20
mtot = mL1 + mL2

# convert to radians
from lensinggw.utils.utils import param_processing
thetaE1 = param_processing(zL, zS, mL1)
thetaE2 = param_processing(zL, zS, mL2)
thetaE = param_processing(zL, zS, mtot)

# %%
Mpc=3.085677581491367e+22
from astropy.cosmology import FlatLambdaCDM
cosmo = FlatLambdaCDM(H0=69.7, Om0=0.306, Tcmb0=2.725)
DL       = cosmo.angular_diameter_distance(zL)
DS       = cosmo.angular_diameter_distance(zS)
DLS      = cosmo.angular_diameter_distance_z1z2(zL, zS)
D        = DLS/(DL*DS)
print(np.float64(D/Mpc))
# Out:
# 1.097926071881248e-26

# %%
from utils.utils import Einstein_radius

# %%
beta0, beta1 = y0 * thetaE, y1 * thetaE
eta10, eta11 = 0 * l0 * thetaE, 0 * l1 * thetaE
lens_model_list = ['SIS']
kwargs_sis_1 = {'center_x': eta10, 'center_y': eta11, 'theta_E': thetaE1}
kwargs_lens_list = [kwargs_sis_1]

kwargs_sis_1_scaled = {'center_x': eta10 / thetaE, 'center_y': eta11 / thetaE, 'theta_E': thetaE1 / thetaE}
kwargs_lens_list_scaled = [kwargs_sis_1_scaled]

from lensinggw.solver.images import microimages
solver_kwargs = {'SearchWindowMacro': 10 * thetaE1,
                 'SearchWindow': 5 * thetaE2,
                 'OverlapDistMacro': 1e-17,
                 'OnlyMacro': True}
MacroImg_ra, MacroImg_dec, pixel_width = microimages(source_pos_x=beta0,
                                                     source_pos_y=beta1,
                                                     lens_model_list=lens_model_list,
                                                     kwargs_lens=kwargs_lens_list,
                                                     **solver_kwargs)

Td = TimeDelay(MacroImg_ra, MacroImg_dec,
                beta0, beta1,
                zL, zS,
                lens_model_list, kwargs_lens_list)
Mus = magnifications(MacroImg_ra, MacroImg_dec, lens_model_list, kwargs_lens_list)
if type2:
    microtype = np.nonzero(Td)[0][0]
else:
    microtype = np.where(Td==0)[0][0]

masses = [60, 40, 20, 30, 10, 17, 23]
angle = [0, 150, 260]
ym = [1., .4, 4.]

mass_density = 100
from utils.lensing import *
radius = injection_radius(masses, mass_density) #rad
lens_model_list, kwargs_lens_list = field_injection(zL, zS, MacroImg_ra[microtype], MacroImg_dec[microtype], masses, radius, lens_model_list, kwargs_lens_list, seed=5)

import json

with open('./data/7m.py_kwargs.json') as f:
    kwargs_lens_list = json.load(f)

from lensinggw.solver.images import microimages
solver_kwargs = {'SearchWindowMacro': 10 * thetaE1,
                 'SearchWindow': 20 * thetaE2,
                 'Pixels': 10*1e3,
                 # 'ÍmgIndex': 1,
                 'Optimization': True,
                 'Verbose': True,
                 'OverlapDist': 1e-18,
                 'OverlapDistMacro': 1e-17}
solver_kwargs.update({'Improvement' : 0.1})
solver_kwargs.update({'MinDist' : 10**(-7)})

Img_ra, Img_dec, MacroImg_ra, MacroImg_dec, pixel_width = microimages(source_pos_x=beta0,
                                                                      source_pos_y=beta1,
                                                                      lens_model_list=lens_model_list,
                                                                      kwargs_lens=kwargs_lens_list,
                                                                      **solver_kwargs)

# time delays, magnifications, Morse indices 
from lensinggw.utils.utils import TimeDelay, magnifications, getMinMaxSaddle
from lensinggw.amplification_factor.amplification_factor import geometricalOpticsMagnification
tds = TimeDelay(Img_ra, Img_dec,
               beta0, beta1,
               zL, zS,
               lens_model_list, kwargs_lens_list)
mus = magnifications(Img_ra, Img_dec, lens_model_list, kwargs_lens_list)
ns = getMinMaxSaddle(Img_ra, Img_dec, lens_model_list, kwargs_lens_list, diff = None)
print('Time delays (seconds): ', tds)
print('magnifications: ', mus)
print('Morse indices: ', ns)
    
lens_model_complete = LensModel(lens_model_list=lens_model_list)
T = lens_model_complete.fermat_potential
T0 = thetaE ** (-2) * T(Img_ra[microtype], Img_dec[microtype], kwargs_lens_list, beta0, beta1)#[0]
if not isinstance(T0, float):
    T0 = T0[0]
Tscale = 4 * (1 + zL) * mtot * M_sun * G / c ** 3
print('T0 = {}'.format(T0))
print('Tscale = {}'.format(Tscale))
# Out:
# ---- Will perform only the macromodel analysis ----
#
# ---- Solver settings ----
#
# The macromodel analysis will be performed with the following settings:
#
# OnlyMacro         --> True
# Scaled            --> False
# SearchWindowMacro --> 8.052888061582412e-06
# PixelsMacro       --> 1000
# PrecisionLimit    --> 1e-20
# OverlapDistMacro  --> 1e-17
# NearSource        --> False
# Optimization      --> False
# Verbose           --> False
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:107: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:107: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:108: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:117: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:117: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:146: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:171: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:171: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:178: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:178: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:182: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:182: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:392: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:392: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:397: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:397: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:398: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:403: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:403: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:408: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:408: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:107: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:107: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:108: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:117: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:117: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:146: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:171: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:171: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:178: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:178: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:182: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:182: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:392: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:392: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:397: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:397: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:398: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:403: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:403: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:408: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /home/manchun.yeung/.conda/envs/wolensing/lib/python3.10/site-packages/lensinggw-1.0.0-py3.10.egg/lensinggw/solver/images.py:408: SyntaxWarning: "is" with a literal. Did you mean "=="?
# MACROIMAGES
#
# ra: [-4.02644403e-07  1.20793321e-06]
# dec: [-4.23516474e-22 -4.23516474e-22]
#
#
# ---- Solver settings ----
#
# The macromodel analysis will be performed with the following settings:
#
# OnlyMacro                       --> False
# Scaled                          --> False
# SearchWindowMacro               --> 8.052888061582412e-06
# PixelsMacro                     --> 1000
# OverlapDistMacro                --> 1e-17
# NearSource                      --> False
# Optimization                    --> True
# Verbose                         --> True
# OptimizationWindowMacro         --> 2
# OptimizationPixelsMacro         --> 30
# MinDistMacro                    --> None
# ImprovementMacro                --> None
# OptimizationPrecisionLimitMacro --> 1e-20
#
#
# ---- Macromodel analysis ----
#
# Interesting regions of the first grid (no iteration yet):
#
# ra:
# [-4.06670847e-07  1.20390677e-06]
# dec:
# [4.02644403e-09 4.02644403e-09]
# pixel_width:
# 8.052888061582012e-09
#
#
# Iteration # 0
#
# Pixels to iterate over, RAs:
# [-4.066708467072679e-07, 1.2039067656092146e-06]
# Pixels to iterate over, DECs:
# [4.026444030790582e-09, 4.026444030790582e-09]
# Pixels to iterate over, source displacements:
# [5.666135983470095e-09, 4.237143739907385e-09]
#
#
#
# Pixel size of the last iteration: 5.368592041055239e-10
#
#
#
#
# MACROIMAGES
#
# ra: [-4.02644403e-07  1.20793321e-06]
# dec: [-4.23516474e-22 -4.23516474e-22]
#
# Elapsed time: 0.08974051475524902 seconds
#
#
# ---- Solver settings ----
#
# The complete model analysis will be performed with the following settings:
#
# Scaled                          --> False
# OnlyMacro                       --> False
# MacroIndex                      --> [0]
# ImgIndex                        --> None
# SearchWindow                    --> 7.202722048357913e-10
# Pixels                          --> 10000.0
# OverlapDist                     --> 1e-18
# Optimization                    --> True
# Verbose                         --> True
# Improvement                     --> 0.1
# MinDist                         --> 1e-07
# OptimizationWindow              --> 2
# OptimizationPixels              --> 30
# OptimizationPrecisionLimit      --> 1e-20
#
#
# ---- Complete model analysis ----
#
#
# Interesting regions of the first grid (no iteration yet):
#
# ra:
# [-4.02860304e-07 -4.02507083e-07 -4.02630609e-07 -4.02570899e-07
#  -4.02686070e-07 -4.02609505e-07 -4.02585088e-07]
# dec:
# [-1.77367030e-10 -1.24859187e-10 -8.84854404e-11 -2.07798531e-11
#  -8.39117119e-12  1.04547511e-10  3.11481715e-10]
# pixel_width:
# 7.202722051197251e-14
#
#
# Iteration # 0
#
# Pixels to iterate over, RAs:
# [-4.028603042698764e-07, -4.0250708278062495e-07, -4.026306094637543e-07, -4.0257089889797336e-07, -4.0268607042352664e-07, -4.026095054881526e-07, -4.0258508826040866e-07]
# Pixels to iterate over, DECs:
# [-1.7736703044123715e-10, -1.2485918670870798e-10, -8.848544036450047e-11, -2.077985310993612e-11, -8.391171186760522e-12, 1.045475105314916e-10, 3.114817149808144e-10]
# Pixels to iterate over, source displacements:
# [1.9717267095657366e-13, 5.446412931576394e-13, 3.893591068863043e-13, 1.0810342587435751e-13, 2.7271128326273056e-14, 2.607193312589387e-13, 9.88922012106039e-13]
#
#
#
# Pixel size of the last iteration: 4.801814690210256e-15
#
#
# Iteration # 1
#
# Pixels to iterate over, RAs:
# [-4.0286030667078375e-07, -4.025071139924205e-07, -4.026305830537734e-07, -4.025708868934366e-07, -4.02686072824434e-07, -4.0260948387998645e-07, -4.0258511467038954e-07]
# Pixels to iterate over, DECs:
# [-1.7736462953388674e-10, -1.2488559668956238e-10, -8.845903038364608e-11, -2.0748641314380933e-11, -8.369563020606931e-12, 1.045403078094404e-10, 3.114601068146608e-10]
# Pixels to iterate over, source displacements:
# [3.912621109684912e-14, 2.2280023578222447e-14, 1.1813681940298467e-14, 7.502085764362798e-15, 2.5765104058318653e-15, 9.544055515039064e-15, 5.16141944937678e-15]
#
#
#
# Pixel size of the last iteration: 3.2012101464038985e-16
#
#
# Iteration # 2
#
# Pixels to iterate over, RAs:
# [-4.028603065107233e-07, -4.0250711543296495e-07, -4.026305832138339e-07, -4.025708851327712e-07, -4.0268607362473647e-07, -4.026094846802889e-07, -4.0258511483045e-07]
# Pixels to iterate over, DECs:
# [-1.7736510971535576e-10, -1.2488639699201076e-10, -8.845790996021836e-11, -2.0746880648994523e-11, -8.367482234241174e-12, 1.0453982762797138e-10, 3.114599467541711e-10]
# Pixels to iterate over, source displacements:
# [5.524109736113758e-15, 1.5797402937684912e-15, 1.324310317212479e-15, 4.751809607512168e-16, 7.067347322954261e-17, 1.6063696360769813e-15, 3.75284715532151e-15]
#
#
#
# Pixel size of the last iteration: 2.134136568298652e-17
#
#
# Iteration # 3
#
# Pixels to iterate over, RAs:
# [-4.02860306521394e-07, -4.0250711555034265e-07, -4.02630583352553e-07, -4.025708850367349e-07, -4.0268607367808996e-07, -4.02609484605594e-07, -4.025851146917309e-07]
# Pixels to iterate over, DECs:
# [-1.773651844102592e-10, -1.248863649799093e-10, -8.845792063091884e-11, -2.0746998026699893e-11, -8.367471563540685e-12, 1.0453994500567676e-10, 3.1145993608347063e-10]
# Pixels to iterate over, source displacements:
# [5.177192858746314e-16, 3.5846566330123057e-17, 1.2593705649666997e-16, 1.905864736701062e-17, 9.498727243646437e-18, 3.29488550979651e-17, 3.1978029634203604e-16]
#
#
#
# Pixel size of the last iteration: 1.4227506535912076e-18
#
#
# Iteration # 4
#
# Pixels to iterate over, RAs:
# [-4.0286030652637364e-07, -4.0250711555105405e-07, -4.026305833433051e-07, -4.025708850360235e-07, -4.026860736859151e-07, -4.0260948460772815e-07, -4.025851147009788e-07]
# Pixels to iterate over, DECs:
# [-1.773651893899112e-10, -1.2488636284577271e-10, -8.845791280575142e-11, -2.0747004429109596e-11, -8.367473697677254e-12, 1.045399442942979e-10, 3.1145993110381863e-10]
# Pixels to iterate over, source displacements:
# [4.168055632635395e-17, 7.194352657972421e-18, 2.6014786324627107e-18, 1.055514738856009e-18, 2.5220259515319465e-19, 6.6313359728169206e-18, 2.1602643470935658e-17]
#
#
#
# Pixel size of the last iteration: 9.481475053327824e-20
#
#
# Iteration # 5
#
# Pixels to iterate over, RAs:
# [-4.028603065268953e-07, -4.025071155511015e-07, -4.0263058334325766e-07, -4.0257088503635547e-07, -4.0268607368615223e-07, -4.026094846082498e-07, -4.025851147013108e-07]
# Pixels to iterate over, DECs:
# [-1.7736518972188635e-10, -1.2488636232409748e-10, -8.845791256862631e-11, -2.074700428683453e-11, -8.367473745102276e-12, 1.0453994415202283e-10, 3.114599303924433e-10]
# Pixels to iterate over, source displacements:
# [3.2364615670761583e-18, 5.555170689728272e-19, 1.4210084915347824e-19, 5.560817790491202e-20, 2.6068026745390685e-20, 6.626820410227081e-19, 1.3737780935761827e-18]
#
#
#
# Pixel size of the last iteration: 6.299807545203859e-21
#
#
# Iteration # 6
#
# Pixels to iterate over, RAs:
# [-4.028603065268669e-07, -4.0250711555107936e-07, -4.0263058334326084e-07, -4.026094846082846e-07, -4.025851147012697e-07]
# Pixels to iterate over, DECs:
# [-1.7736518976297275e-10, -1.2488636228301108e-10, -8.845791255282385e-11, 1.0453994419310923e-10, 3.1145993041456677e-10]
# Pixels to iterate over, source displacements:
# [2.1112952418916597e-19, 4.350632699941589e-20, 2.5351356928937653e-20, 3.615786870950151e-20, 1.0048259013279779e-19]
#
#
#
# Pixel size of the last iteration: 4.235164736271502e-22
#
#
# Interesting regions of the first grid (no iteration yet):
#
# ra:
# [1.20793325e-06]
# dec:
# [-3.60136107e-14]
# pixel_width:
# 7.202722051197251e-14
#
#
# Iteration # 0
#
# Pixels to iterate over, RAs:
# [1.2079332456536158e-06]
# Pixels to iterate over, DECs:
# [-3.601361066533726e-14]
# Pixels to iterate over, source displacements:
# [3.0428623084869397e-14]
#
#
#
# Pixel size of the last iteration: 4.801814743149815e-15
#
#
# Iteration # 1
#
# Pixels to iterate over, RAs:
# [1.207933219243635e-06]
# Pixels to iterate over, DECs:
# [-4.0935100563717957e-22]
# Pixels to iterate over, source displacements:
# [1.5506776909783187e-15]
#
#
#
# Pixel size of the last iteration: 3.2012106757994905e-16
#
#
# Iteration # 2
#
# Pixels to iterate over, RAs:
# [1.2079332178030906e-06]
# Pixels to iterate over, DECs:
# [-1.6006090078933296e-16]
# Pixels to iterate over, source displacements:
# [1.2226251845398853e-16]
#
#
#
# Pixel size of the last iteration: 2.1341418622545724e-17
#
#
# Iteration # 3
#
# Pixels to iterate over, RAs:
# [1.2079332176857128e-06]
# Pixels to iterate over, DECs:
# [-3.6699935848154054e-22]
# Pixels to iterate over, source displacements:
# [7.249209235736594e-18]
#
#
#
# Pixel size of the last iteration: 1.422803593150411e-18
#
#
# Iteration # 4
#
# Pixels to iterate over, RAs:
# [1.2079332176935379e-06]
# Pixels to iterate over, DECs:
# [-7.117476201100075e-19]
# Pixels to iterate over, source displacements:
# [5.809675290642579e-19]
#
#
#
# Pixel size of the last iteration: 9.486769009248164e-20
#
#
# Iteration # 5
#
# Pixels to iterate over, RAs:
# [1.2079332176929212e-06]
# Pixels to iterate over, DECs:
# [-7.591744065483547e-19]
# Pixels to iterate over, source displacements:
# [3.7017419086140346e-20]
#
#
#
# Pixel size of the last iteration: 6.3527471044072525e-21
#
#
#
#
# IMAGES OF THE COMPLETE MODEL
#
# ra: [-4.02570885e-07 -4.02686074e-07 -4.02860307e-07 -4.02507116e-07
#  -4.02630583e-07 -4.02609485e-07 -4.02585115e-07  1.20793322e-06]
# dec: [-2.07470043e-11 -8.36747373e-12 -1.77365190e-10 -1.24886362e-10
#  -8.84579126e-11  1.04539944e-10  3.11459930e-10 -7.81310201e-19]
#
# Elapsed time: 87.36161971092224 seconds
#
# Time delays (seconds):  [295529.51751277 295529.5153665  295529.5168846  295529.51726563
#  295529.51498603 295529.51383266 295529.49598858      0.        ]
# magnifications:  [-1.08899763e-01 -7.69332824e-01 -2.18494498e-04 -6.07334827e-03
#  -9.55537535e-03 -7.27491724e-03 -1.20389465e-03  2.99999999e+00]
# Morse indices:  [0.5, 0, 0.5, 0.5, 0.5, 0.5, 0.5, 0]
# T0 = 4.5570176117440013e-07
# Tscale = 295529.46212367347

# %%
# Img_ra, Img_dec = np.loadtxt('./data/5m_2.py_pos.txt')
import json

with open('./data/7m.py_kwargs.json') as f:
    kwargs_lens_list = json.load(f)

# %%
Img_ra, Img_dec
# Out:
# (array([-4.02570885e-07, -4.02686074e-07, -4.02860307e-07, -4.02507116e-07,
#         -4.02630583e-07, -4.02609485e-07, -4.02585115e-07,  1.20793322e-06]),
#  array([-2.07470043e-11, -8.36747373e-12, -1.77365190e-10, -1.24886362e-10,
#         -8.84579126e-11,  1.04539944e-10,  3.11459930e-10, -7.81310201e-19]))

# %%
Img_ra[microtype]
# Out:
# -4.02570885036346e-07

# %%
kwargs_lens_list
# Out:
# [{'center_x': 0.0, 'center_y': 0.0, 'theta_E': 8.052888061582411e-07},
#  {'center_x': -4.02587014690857e-07,
#   'center_y': 3.227466072166839e-10,
#   'theta_E': 6.237740270276241e-11},
#  {'center_x': -4.0251530245652306e-07,
#   'center_y': -1.3621631174758854e-10,
#   'theta_E': 5.093093603395741e-11},
#  {'center_x': -4.026125193428416e-07,
#   'center_y': 1.1433884084517411e-10,
#   'theta_E': 3.601361024178957e-11},
#  {'center_x': -4.0259987940379257e-07,
#   'center_y': -2.49853700967668e-11,
#   'theta_E': 4.410748444392738e-11},
#  {'center_x': -4.031101001663641e-07,
#   'center_y': 3.396965556625535e-11,
#   'theta_E': 2.5465468016978704e-11},
#  {'center_x': -4.028574534603707e-07,
#   'center_y': -1.802190790013833e-10,
#   'theta_E': 3.3202908069179736e-11},
#  {'center_x': -4.026344137921295e-07,
#   'center_y': -9.9603778150314e-11,
#   'theta_E': 3.862029441944559e-11}]

# %%
# plot only the microimages around the desired macroimage
Img_ra = np.delete(Img_ra, [-1])
Img_dec = np.delete(Img_dec, [-1])

# %%
# filename = __file__
# np.savetxt(f'./data/{filename}_pos.txt', np.array([Img_ra, Img_dec]))
# np.savetxt(f'./data/{filename}_kwargs.txt', kwargs_lens_list)

# %%
lens_model_complete = LensModel(lens_model_list=lens_model_list)
T = lens_model_complete.fermat_potential
T0 = thetaE ** (-2) * T(MacroImg_ra[microtype], MacroImg_dec[microtype], kwargs_lens_list, beta0, beta1)#[0]

# %%
import matplotlib.pyplot as plt

fig1, ax1 = plt.subplots()
plot_contour(ax1, lens_model_list, MacroImg_ra[microtype], MacroImg_dec[microtype], 20*thetaE2, kwargs_lens_list, beta0, beta1, Img_ra, Img_dec,
                    T0 = T0, Tfac = (thetaE)**(-2), micro=True)
# plt.savefig(f'./data/{filename}_tdpic.png')
# Out:
# [-4.02570885e-07 -4.02686074e-07 -4.02860307e-07 -4.02507116e-07
#  -4.02630583e-07 -4.02609485e-07 -4.02585115e-07] [-2.07470043e-11 -8.36747373e-12 -1.77365190e-10 -1.24886362e-10
#  -8.84579126e-11  1.04539944e-10  3.11459930e-10] Img_pos
# <Axes: >

# %%
Tscale = 4 * (1 + zL) * mtot * M_sun * G / c ** 3

# %%
# Define the characteristic WindowSize
mL3 = 10
thetaE3 = param_processing(zL, zS, mL3)

# %%
import time

# %%
kwargs_macro = {'source_pos_x': beta0,
                'source_pos_y': beta1,
                'theta_E': thetaE,
                'mu': np.abs(Mus[microtype]),
               }

kwargs_integrator = {'PixelNum': int(300000),
                     'PixelBlockMax': 2000,
                     'WindowSize': 10.*210*thetaE3,
                     'WindowCenterX': MacroImg_ra[microtype],
                     'WindowCenterY': MacroImg_dec[microtype],
                     'T0': T0,
                     'TimeStep': 1e-6/Tscale, 
                     'TimeMax': T0 + 7/Tscale,
                     'TimeMin': T0 - 5/Tscale,
                     'TExtend': 12/Tscale,
                     'LastImageT': 4e-7/Tscale,
                     'Tbuffer': 0./Tscale,
                     'Tscale': Tscale}

amplification = af.amplification_factor(lens_model_list=lens_model_list, kwargs_lens=kwargs_lens_list, kwargs_macro=kwargs_macro, **kwargs_integrator)
# ts, Ft = amplification.integrator(gpu=False)
ts = np.loadtxt('./data/7m_ts.txt')
Ft = np.loadtxt('./data/7m_ft.txt')
amplification.importor(ts=ts, F_tilde=Ft, time=True)
ws, Fws = amplification.fourier(type2=type2)
# Out:
# [0.00000000e+00 3.38375795e-12 6.76751590e-12 ... 4.06050852e-05
#  4.06050886e-05 4.06050920e-05] 1e-06
# total time 12.0

# %%
window_size = 100
moving_average = np.convolve(Ft, np.ones(window_size)/window_size, mode='valid')

# %%
plt.plot(ts, Ft)

# %%
amplification.importor(ts=ts, F_tilde=Ft, time=True)
ws, Fws = amplification.fourier(type2=type2)
# Out:
# [0.00000000e+00 3.38375795e-12 6.76751590e-12 ... 4.06050852e-05
#  4.06050886e-05 4.06050920e-05] 8e-07
# total time 9.6

# %%
new_ts = ts[(window_size - 1):]
plt.plot(new_ts, moving_average)

# %%
amplification.plot_freq()
# Out:
# <Axes: xlabel='Frequency (Hz)', ylabel='$|F|/\\sqrt{\\mu}$'>

# %%
plt.semilogx(ws, np.angle(Fws), label=r'$F_{wave}$')

# %% [markdown]
# # Geometrical optics
# To get the geometrical optics around type 1 image, we need the magnifications, time delay and the image positions of the microimages

# %%
tds = TimeDelay(Img_ra, Img_dec,
               beta0, beta1,
               zL, zS,
               lens_model_list, kwargs_lens_list)
mus = magnifications(Img_ra, Img_dec, lens_model_list, kwargs_lens_list)
ns = getMinMaxSaddle(Img_ra, Img_dec, lens_model_list, kwargs_lens_list, diff = None)

# %%
geofs, geoFws = amplification.geometrical_optics(mus, tds, Img_ra, Img_dec, upper_lim=2000)

# %%
from wolensing.utils.utils import *
ns = Morse_indices(amplification._lens_model_list, Img_ra, Img_dec, amplification._kwargs_lens)

# %%
fs = amplification._fs
fs_grid = fs[1]-fs[0]

num_interp = int((3000-fs[0])/fs_grid) 
amplification._geofs = np.linspace(fs[0], 3000, num_interp)

ns = Morse_indices(amplification._lens_model_list, Img_ra, Img_dec, amplification._kwargs_lens)
geoFws1 = compute_geometrical(amplification._geofs, mus[:], tds[:], ns[:])

# %%
mus, ns, tds
# Img_ra, Img_dec
# Out:
# (array([-1.08899763e-01, -7.69332824e-01, -2.18494498e-04, -6.07334827e-03,
#         -9.55537535e-03, -7.27491724e-03, -1.20389465e-03]),
#  array([0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5]),
#  array([0.02152419, 0.01937792, 0.02089602, 0.02127705, 0.01899745,
#         0.01784408, 0.        ]))

# %%
plt.semilogx(amplification._geofs, np.abs(geoFws1))

# %% [markdown]
# # Full amplification factor concatenated with geometrical optics
# Given the computaional cost of the diffraction integral, we concatenate the result of wave optics at low frequency and geometrical optics at high frequency to obtain a full amplification factor with default upper bound of 3000Hz.

# %%
fac = np.sqrt(np.abs(Mus[microtype]))

# %%
plt.clf()
plt.rc('text', usetex=True)
plt.rc('font', family='serif')

# %%
# from bisect import bisect_left
# low_index = bisect_left(geofs, 1)
# geofs = geofs[low_index:]
# geoFws = geoFws[low_index:]
# ws = ws[low_index:]
# Fws = Fws[low_index:]

# %%
ww = geofs
# plt.semilogx(geofs, (fac*np.exp(-ww*np.pi/188) + (1-np.exp(-ww*np.pi/188))*np.abs(geoFws))/fac, label='Approximation')
# plt.semilogx(amplification._geofs, np.abs(geoFws1)/fac,label=r'$F_{geo}$')
plt.semilogx(geofs, np.abs(geoFws)/fac,label=r'$F_{geo}$')
plt.semilogx(ws, np.abs(Fws)/fac, label=r'$F_{wave}$')
# plt.plot(ws, np.abs(Fws)/fac, label=r'$F_{wave}$')
# plt.plot(ws, np.abs(Fws)/fac, label=r'$F_{wave}$')
plt.ylabel(r'$|F|/\sqrt{\mu}$')
plt.xlabel(r'$f$')
plt.grid(which='both', alpha=0.5)
plt.legend()
plt.xlim(1, 1000)
# plt.savefig(f'./{filename}_abs.png',bbox_inches='tight', dpi=300)
# Out:
# (1, 1000)

# %%
ww = geofs
# plt.semilogx(geofs, (fac*np.exp(-ww*np.pi/188) + (1-np.exp(-ww*np.pi/188))*np.abs(geoFws))/fac, label='Approximation')
# plt.semilogx(amplification._geofs, np.abs(geoFws1)/fac,label=r'$F_{geo}$')
# plt.semilogx(amplification._geofs, np.abs(geoFws1)/fac,label=r'$F_{geo}$')

plt.semilogx(ws, np.abs(Fws)/fac, label=r'$F_{wave}$')
plt.ylabel(r'$|F|/\sqrt{\mu}$')
plt.xlabel(r'$f$')
plt.grid(which='both', alpha=0.5)
plt.legend()
plt.xlim(1, 700)
# plt.savefig(f'./{filename}_abs.png',bbox_inches='tight', dpi=300)
# Out:
# (1, 700)

# %%
# plt.semilogx(geofs, (1-np.exp(-ww*np.pi/37.5))*np.angle(geoFws), label='Approximation')
# plt.semilogx(geofs, np.angle(geoFws),label=r'$F_{geo}$')
plt.semilogx(geofs[1:j+1], np.angle(geoFws1))
# plt.semilogx(amplification._geofs, np.abs(geoFws))
plt.semilogx(ws, np.angle(Fws), label=r'$F_{wave}$')
plt.ylabel(r'$args(F)$')
plt.xlabel(r'$f$')
plt.grid(which='both', alpha=0.5)
plt.legend()
plt.xlim(1, 800)
# plt.savefig(f'./{filename}_pha.png',bbox_inches='tight', dpi=300)
# Out:
# (1, 800)

# %%
peak = np.where(amplification._F_tilde == np.amax(amplification._F_tilde))
index = int(peak[0])
tdiff = amplification._ts[index]*amplification._Tscale

# %%
from bisect import bisect_left
i = bisect_left(ws, 700)

# %%
index = np.argmin(np.abs(geofs - 700))
j = index

# %%
over_pha = np.exp(-1 * 2 * np.pi * 1j * (0.01937792) * geofs[1:j+1])
geoFws1 = geoFws[1:j+1] * over_pha
plt.semilogx(geofs[1:j+1], np.angle(geoFws1))
plt.xlim(1, 800)
# Out:
# (1, 800)

# %%
residue = np.divide(np.angle(geoFws)[1:j+1], np.angle(Fws)[1:i])
missing_t = np.log(residue)*(1j/(2*np.pi*geofs[1:j+1]))

# %%
missing_t

# %%
res = np.log(np.angle(geoFws)[:j+1] - np.angle(Fws)[:i])

# %%
plt.plot(geofs[1:j+1], np.angle(missing_t))

# %%
np.angle(missing_t[:200])
