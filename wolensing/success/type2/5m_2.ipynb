# %%
import numpy as np

# %%
# %env JAX_ENABLE_X64=True
# Out:
# env: JAX_ENABLE_X64=True

# %%
from lenstronomy.LensModel.lens_model import LensModel
import lensinggw.constants.constants as const
from lensinggw.utils.utils import TimeDelay, magnifications, getMinMaxSaddle

# %%
import sys
sys.path.append('/home/manchun.yeung/microlensing/wolensing_simon/wolensing/')

# %%
from plot.plot import plot_contour
import amplification_factor.amplification_factor as af
from lensmodels.potential import potential
import numpy as np

# %% [markdown]
# The macroimage where the microlens is placed around.

# %%
type2 = True

# %%
ym = 0.8
angle = np.radians(float(0))

# %% [markdown]
# Importing constants

# %%
G = const.G  # gravitational constant [m^3 kg^-1 s^-2]
c = const.c  # speed of light [m/s]
M_sun = const.M_sun  # Solar mass [Kg]

# %%
y0, y1 = 0.5, 0 # source position
l0, l1 = 0., 0 # lens position

zS = 1.0 # source redshift
zL = 0.5 # lens redshift

# %%
mL1 = 1e10
mL2 = 20
mtot = mL1 + mL2

# convert to radians
from lensinggw.utils.utils import param_processing
thetaE1 = param_processing(zL, zS, mL1)
thetaE2 = param_processing(zL, zS, mL2)
thetaE = param_processing(zL, zS, mtot)

# %%
Mpc=3.085677581491367e+22
from astropy.cosmology import FlatLambdaCDM
cosmo = FlatLambdaCDM(H0=69.7, Om0=0.306, Tcmb0=2.725)
DL       = cosmo.angular_diameter_distance(zL)
DS       = cosmo.angular_diameter_distance(zS)
DLS      = cosmo.angular_diameter_distance_z1z2(zL, zS)
D        = DLS/(DL*DS)
print(np.float64(D/Mpc))
# Out:
# 1.097926071881248e-26

# %%
from utils.utils import Einstein_radius

# %%
beta0, beta1 = y0 * thetaE, y1 * thetaE
eta10, eta11 = 0 * l0 * thetaE, 0 * l1 * thetaE
lens_model_list = ['SIS']
kwargs_sis_1 = {'center_x': eta10, 'center_y': eta11, 'theta_E': thetaE1}
kwargs_lens_list = [kwargs_sis_1]

kwargs_sis_1_scaled = {'center_x': eta10 / thetaE, 'center_y': eta11 / thetaE, 'theta_E': thetaE1 / thetaE}
kwargs_lens_list_scaled = [kwargs_sis_1_scaled]

from lensinggw.solver.images import microimages
solver_kwargs = {'SearchWindowMacro': 10 * thetaE1,
                 'SearchWindow': 5 * thetaE2,
                 'OverlapDistMacro': 1e-17,
                 'OnlyMacro': True}
MacroImg_ra, MacroImg_dec, pixel_width = microimages(source_pos_x=beta0,
                                                     source_pos_y=beta1,
                                                     lens_model_list=lens_model_list,
                                                     kwargs_lens=kwargs_lens_list,
                                                     **solver_kwargs)

Td = TimeDelay(MacroImg_ra, MacroImg_dec,
                beta0, beta1,
                zL, zS,
                lens_model_list, kwargs_lens_list)
Mus = magnifications(MacroImg_ra, MacroImg_dec, lens_model_list, kwargs_lens_list)
if type2:
    microtype = np.nonzero(Td)[0][0]
else:
    microtype = np.where(Td==0)[0][0]

masses = [60, 40, 20, 30, 3, 5]
angle = [0, 150, 260]
ym = [1., .4, 4.]

mass_density = 100
from utils.lensing import *
radius = injection_radius(masses, mass_density) #rad
lens_model_list, kwargs_lens_list = field_injection(zL, zS, MacroImg_ra[microtype], MacroImg_dec[microtype], masses, radius, lens_model_list, kwargs_lens_list, seed=1)

import json

with open('./data/5m_2.py_kwargs.json') as f:
    kwargs_lens_list = json.load(f)

from lensinggw.solver.images import microimages
solver_kwargs = {'SearchWindowMacro': 10 * thetaE1,
                 'SearchWindow': 20 * thetaE2,
                 'Pixels': 10*1e3,
                 # 'ÍmgIndex': 1,
                 'Optimization': True,
                 'Verbose': True,
                 'OverlapDist': 1e-18,
                 'OverlapDistMacro': 1e-17}
solver_kwargs.update({'Improvement' : 0.1})
solver_kwargs.update({'MinDist' : 10**(-7)})

Img_ra, Img_dec, MacroImg_ra, MacroImg_dec, pixel_width = microimages(source_pos_x=beta0,
                                                                      source_pos_y=beta1,
                                                                      lens_model_list=lens_model_list,
                                                                      kwargs_lens=kwargs_lens_list,
                                                                      **solver_kwargs)

# time delays, magnifications, Morse indices 
from lensinggw.utils.utils import TimeDelay, magnifications, getMinMaxSaddle
from lensinggw.amplification_factor.amplification_factor import geometricalOpticsMagnification
tds = TimeDelay(Img_ra, Img_dec,
               beta0, beta1,
               zL, zS,
               lens_model_list, kwargs_lens_list)
mus = magnifications(Img_ra, Img_dec, lens_model_list, kwargs_lens_list)
ns = getMinMaxSaddle(Img_ra, Img_dec, lens_model_list, kwargs_lens_list, diff = None)
print('Time delays (seconds): ', tds)
print('magnifications: ', mus)
print('Morse indices: ', ns)
    
lens_model_complete = LensModel(lens_model_list=lens_model_list)
T = lens_model_complete.fermat_potential
T0 = thetaE ** (-2) * T(Img_ra[microtype], Img_dec[microtype], kwargs_lens_list, beta0, beta1)#[0]
if not isinstance(T0, float):
    T0 = T0[0]
Tscale = 4 * (1 + zL) * mtot * M_sun * G / c ** 3
print('T0 = {}'.format(T0))
print('Tscale = {}'.format(Tscale))
# Out:
# ---- Will perform only the macromodel analysis ----
#
# ---- Solver settings ----
#
# The macromodel analysis will be performed with the following settings:
#
# OnlyMacro         --> True
# Scaled            --> False
# SearchWindowMacro --> 8.052888061582412e-06
# PixelsMacro       --> 1000
# PrecisionLimit    --> 1e-20
# OverlapDistMacro  --> 1e-17
# NearSource        --> False
# Optimization      --> False
# Verbose           --> False
#
#
#
#
# MACROIMAGES
#
# ra: [-4.02644403e-07  1.20793321e-06]
# dec: [-4.23516474e-22 -4.23516474e-22]
#
#
# ---- Solver settings ----
#
# The macromodel analysis will be performed with the following settings:
#
# OnlyMacro                       --> False
# Scaled                          --> False
# SearchWindowMacro               --> 8.052888061582412e-06
# PixelsMacro                     --> 1000
# OverlapDistMacro                --> 1e-17
# NearSource                      --> False
# Optimization                    --> True
# Verbose                         --> True
# OptimizationWindowMacro         --> 2
# OptimizationPixelsMacro         --> 30
# MinDistMacro                    --> None
# ImprovementMacro                --> None
# OptimizationPrecisionLimitMacro --> 1e-20
#
#
# ---- Macromodel analysis ----
#
# Interesting regions of the first grid (no iteration yet):
#
# ra:
# [-4.06670847e-07  1.20390677e-06]
# dec:
# [4.02644403e-09 4.02644403e-09]
# pixel_width:
# 8.052888061582012e-09
#
#
# Iteration # 0
#
# Pixels to iterate over, RAs:
# [-4.066708467072679e-07, 1.2039067656092146e-06]
# Pixels to iterate over, DECs:
# [4.026444030790582e-09, 4.026444030790582e-09]
# Pixels to iterate over, source displacements:
# [5.666135983470095e-09, 4.237143739907385e-09]
#
#
#
# Pixel size of the last iteration: 5.368592041055239e-10
#
#
#
#
# MACROIMAGES
#
# ra: [-4.02644403e-07  1.20793321e-06]
# dec: [-4.23516474e-22 -4.23516474e-22]
#
# Elapsed time: 0.09166169166564941 seconds
#
#
# ---- Solver settings ----
#
# The complete model analysis will be performed with the following settings:
#
# Scaled                          --> False
# OnlyMacro                       --> False
# MacroIndex                      --> [0]
# ImgIndex                        --> None
# SearchWindow                    --> 7.202722048357913e-10
# Pixels                          --> 10000.0
# OverlapDist                     --> 1e-18
# Optimization                    --> True
# Verbose                         --> True
# Improvement                     --> 0.1
# MinDist                         --> 1e-07
# OptimizationWindow              --> 2
# OptimizationPixels              --> 30
# OptimizationPrecisionLimit      --> 1e-20
#
#
# ---- Complete model analysis ----
#
#
# Interesting regions of the first grid (no iteration yet):
#
# ra:
# [-4.02682757e-07 -4.02415176e-07 -4.02617212e-07 -4.02765588e-07
#  -4.02501609e-07 -4.02321613e-07 -4.02743980e-07]
# dec:
# [-1.78447439e-10  2.52095271e-13  6.08630013e-12  4.05873387e-11
#   1.87018678e-10  2.10571579e-10  2.80798119e-10]
# pixel_width:
# 7.202722051197251e-14
#
#
# Iteration # 0
#
# Pixels to iterate over, RAs:
# [-4.0268275717138436e-07, -4.024151760472879e-07, -4.026172124007443e-07, -4.027655884749405e-07, -4.0250160871186816e-07, -4.0232161268787973e-07, -4.0274398030879545e-07]
# Pixels to iterate over, DECs:
# [-1.7844743874849084e-10, 2.5209527126902225e-13, 6.0863001304389235e-12, 4.0587338742073305e-11, 1.870186779851897e-10, 2.1057157908332003e-10, 2.8079811905480977e-10]
# Pixels to iterate over, source displacements:
# [3.4740440696711044e-13, 9.777874016614352e-13, 1.0274451766955355e-14, 8.28430504527721e-14, 1.0788050104447378e-11, 1.1269538390203316e-11, 7.464997838695262e-13]
#
#
#
# Pixel size of the last iteration: 4.801814690210256e-15
#
#
# Iteration # 1
#
# Pixels to iterate over, RAs:
# [-4.026827787795505e-07, -4.024151688445658e-07, -4.0261721480165167e-07, -4.0276557166858907e-07, -4.0250163992366373e-07, -4.023216150887871e-07, -4.027439923133322e-07]
# Pixels to iterate over, DECs:
# [-1.7844503784114044e-10, 2.2568529041463233e-13, 6.093502852490121e-12, 4.0594541464124505e-11, 1.870450879660441e-10, 2.1059798906417443e-10, 2.807909163327586e-10]
# Pixels to iterate over, source displacements:
# [1.2780020615158899e-14, 4.326753003596659e-14, 3.131282580214759e-15, 1.0808627521875194e-14, 6.94513730517981e-13, 6.835804575601832e-14, 1.0177780601828918e-13]
#
#
#
# Pixel size of the last iteration: 3.2012096170083064e-16
#
#
# Iteration # 2
#
# Pixels to iterate over, RAs:
# [-4.0268277957985295e-07, -4.0241516804426337e-07, -4.026172127208653e-07, -4.0276557246889153e-07, -4.025016375227564e-07, -4.023216152488476e-07, -4.027439934337556e-07]
# Pixels to iterate over, DECs:
# [-1.7844455765967141e-10, 2.2488498796626395e-13, 6.095263517876531e-12, 4.059694237146961e-11, 1.8704460778457508e-10, 2.1059782900368476e-10, 2.8079235687716565e-10]
# Pixels to iterate over, source displacements:
# [2.1699209410453292e-15, 4.61231587020015e-15, 1.131116175867258e-16, 5.627526535036739e-16, 4.491441134866472e-14, 4.9595357834404705e-14, 7.371988669070933e-15]
#
#
#
# Pixel size of the last iteration: 2.134136568298652e-17
#
#
# Iteration # 3
#
# Pixels to iterate over, RAs:
# [-4.0268277952649945e-07, -4.0241516792688567e-07, -4.026172126675118e-07, -4.0276557235151383e-07, -4.025016376187927e-07, -4.023216151314699e-07, -4.027439935297919e-07]
# Pixels to iterate over, DECs:
# [-1.784446963787548e-10, 2.2483163447264714e-13, 6.095167481588021e-12, 4.059688901797599e-11, 1.8704449040688914e-10, 2.1059783967438348e-10, 2.8079245291345417e-10]
# Pixels to iterate over, source displacements:
# [1.3116194644051456e-16, 2.984058342592503e-16, 1.4122838869497996e-17, 1.5578433573559676e-17, 8.425444924161194e-16, 1.8086289014414924e-15, 4.4201019076446605e-16]
#
#
#
# Pixel size of the last iteration: 1.4227506535912076e-18
#
#
# Iteration # 4
#
# Pixels to iterate over, RAs:
# [-4.0268277953290186e-07, -4.024151679247515e-07, -4.0261721267533697e-07, -4.0276557235507074e-07, -4.025016376195041e-07, -4.023216151350268e-07, -4.0274399353761705e-07]
# Pixels to iterate over, DECs:
# [-1.784446899763451e-10, 2.2482380930523006e-13, 6.09517672951315e-12, 4.059688688383943e-11, 1.8704448827275256e-10, 2.105978389630046e-10, 2.80792453624833e-10]
# Pixels to iterate over, source displacements:
# [9.155658273327765e-18, 2.315803938115395e-17, 8.638766225199545e-19, 3.1092174580576854e-18, 1.9357601397411803e-16, 3.39668296410802e-16, 3.6665105619606644e-17]
#
#
#
# Pixel size of the last iteration: 9.486769009248164e-20
#
#
# Iteration # 5
#
# Pixels to iterate over, RAs:
# [-4.026827795323802e-07, -4.024151679248938e-07, -4.026172126748153e-07, -4.0276557235435933e-07, -4.025016376195515e-07, -4.0232161513564333e-07, -4.027439935383284e-07]
# Pixels to iterate over, DECs:
# [-1.784446902134702e-10, 2.2482319277994683e-13, 6.09517725118839e-12, 4.059688693126445e-11, 1.8704448756137723e-10, 2.1059783948467984e-10, 2.8079245348255795e-10]
# Pixels to iterate over, source displacements:
# [4.924634565482606e-19, 1.8634452417356585e-18, 1.506346145044752e-20, 1.4236735399983469e-19, 1.4774536810971732e-17, 1.3874768386703597e-17, 1.1918929576357561e-18]
#
#
#
# Pixel size of the last iteration: 6.299807545203859e-21
#
#
# Iteration # 6
#
# Pixels to iterate over, RAs:
# [-4.026827795323517e-07, -4.0241516792493496e-07, -4.0276557235437516e-07, -4.025016376195294e-07, -4.0232161513561485e-07, -4.0274399353830627e-07]
# Pixels to iterate over, DECs:
# [-1.7844469019765893e-10, 2.2482315799512713e-13, 4.059688695972476e-11, 1.8704448760881108e-10, 2.1059783947519306e-10, 2.8079245347307117e-10]
# Pixels to iterate over, source displacements:
# [3.148971349672227e-20, 1.310613457397388e-19, 1.4382721415953104e-20, 8.17341650162741e-19, 1.0876354012126515e-18, 1.2775034609015612e-19]
#
#
#
# Pixel size of the last iteration: 4.235164736271502e-22
#
#
# Iteration # 7
#
# Pixels to iterate over, RAs:
# [-4.0250163761953215e-07, -4.023216151356125e-07]
# Pixels to iterate over, DECs:
# [1.870444876081811e-10, 2.1059783947624304e-10]
# Pixels to iterate over, source displacements:
# [3.317984191225978e-20, 6.050470584237789e-20]
#
#
#
# Pixel size of the last iteration: 5.293955920339377e-23
#
#
# Interesting regions of the first grid (no iteration yet):
#
# ra:
# [1.20793325e-06]
# dec:
# [-3.60136107e-14]
# pixel_width:
# 7.202722051197251e-14
#
#
# Iteration # 0
#
# Pixels to iterate over, RAs:
# [1.2079332456536158e-06]
# Pixels to iterate over, DECs:
# [-3.601361066533726e-14]
# Pixels to iterate over, source displacements:
# [3.198970711403672e-14]
#
#
#
# Pixel size of the last iteration: 4.801814743149815e-15
#
#
# Iteration # 1
#
# Pixels to iterate over, RAs:
# [1.2079332144418203e-06]
# Pixels to iterate over, DECs:
# [-4.0935100563717957e-22]
# Pixels to iterate over, source displacements:
# [1.5598841825493315e-15]
#
#
#
# Pixel size of the last iteration: 3.2012106757994905e-16
#
#
# Iteration # 2
#
# Pixels to iterate over, RAs:
# [1.2079332158823648e-06]
# Pixels to iterate over, DECs:
# [-1.6006090078933296e-16]
# Pixels to iterate over, source displacements:
# [1.306650259841219e-16]
#
#
#
# Pixel size of the last iteration: 2.1341418622545724e-17
#
#
# Iteration # 3
#
# Pixels to iterate over, RAs:
# [1.2079332159997426e-06]
# Pixels to iterate over, DECs:
# [-3.6699935848154054e-22]
# Pixels to iterate over, source displacements:
# [1.9670719869347053e-18]
#
#
#
# Pixel size of the last iteration: 1.422803593150411e-18
#
#
# Iteration # 4
#
# Pixels to iterate over, RAs:
# [1.2079332160018767e-06]
# Pixels to iterate over, DECs:
# [-7.117476201100075e-19]
# Pixels to iterate over, source displacements:
# [1.9638830252370915e-19]
#
#
#
# Pixel size of the last iteration: 9.486769009248164e-20
#
#
# Iteration # 5
#
# Pixels to iterate over, RAs:
# [1.2079332160017344e-06]
# Pixels to iterate over, DECs:
# [-4.746136879182724e-19]
# Pixels to iterate over, source displacements:
# [3.362186202265001e-20]
#
#
#
# Pixel size of the last iteration: 6.3527471044072525e-21
#
#
#
#
# IMAGES OF THE COMPLETE MODEL
#
# ra: [-4.02617213e-07 -4.02682780e-07 -4.02415168e-07 -4.02765572e-07
#  -4.02743994e-07  1.20793322e-06]
# dec: [ 6.09517727e-12 -1.78444690e-10  2.24823161e-13  4.05968870e-11
#   2.80792453e-10 -4.27179843e-19]
#
# Elapsed time: 78.48765897750854 seconds
#
# Time delays (seconds):  [295529.50429329 295529.49863919 295529.51569694 295529.50909055
#  295529.48937564      0.        ]
# magnifications:  [-7.47273639e-01 -4.21000069e-03 -8.49018969e-04 -5.11072164e-02
#  -3.72816554e-04  2.99999999e+00]
# Morse indices:  [0, 0.5, 0.5, 0.5, 0.5, 0]
# T0 = 3.5494642880797663e-07
# Tscale = 295529.46212367347

# %%
# Img_ra, Img_dec = np.loadtxt('./data/5m_2.py_pos.txt')
import json

with open('./data/5m_2.py_kwargs.json') as f:
    kwargs_lens_list = json.load(f)

# %%
Img_ra, Img_dec
# Out:
# (array([-4.02617213e-07, -4.02682780e-07, -4.02415168e-07, -4.02765572e-07,
#         -4.02743994e-07,  1.20793322e-06]),
#  array([ 6.09517727e-12, -1.78444690e-10,  2.24823161e-13,  4.05968870e-11,
#          2.80792453e-10, -4.27179843e-19]))

# %%
Img_ra[microtype]
# Out:
# -4.0263775650896126e-07

# %%
kwargs_lens_list
# Out:
# [{'center_x': 0.0, 'center_y': 0.0, 'theta_E': 8.052888061582411e-07},
#  {'center_x': -4.027351770958389e-07,
#   'center_y': 5.2138758967362375e-11,
#   'theta_E': 6.237740270276241e-11},
#  {'center_x': -4.0268040556898516e-07,
#   'center_y': -1.9084695918261635e-10,
#   'theta_E': 5.093093603395741e-11},
#  {'center_x': -4.0242141013708445e-07,
#   'center_y': 1.6025097800896074e-13,
#   'theta_E': 3.601361024178957e-11},
#  {'center_x': -4.027421923650217e-07,
#   'center_y': 2.8660379167269894e-10,
#   'theta_E': 4.410748444392738e-11},
#  {'center_x': -4.0250206609442013e-07,
#   'center_y': 1.8773997807997698e-10,
#   'theta_E': 1.3948011270325585e-11},
#  {'center_x': -4.0232231116424597e-07,
#   'center_y': 2.1110729994479883e-10,
#   'theta_E': 1.8006805120894784e-11}]

# %%
# plot only the microimages around the desired macroimage
Img_ra = np.delete(Img_ra, [-1])
Img_dec = np.delete(Img_dec, [-1])

# %%
# filename = __file__
# np.savetxt(f'./data/{filename}_pos.txt', np.array([Img_ra, Img_dec]))
# np.savetxt(f'./data/{filename}_kwargs.txt', kwargs_lens_list)

# %%
lens_model_complete = LensModel(lens_model_list=lens_model_list)
T = lens_model_complete.fermat_potential
T0 = thetaE ** (-2) * T(MacroImg_ra[microtype], MacroImg_dec[microtype], kwargs_lens_list, beta0, beta1)#[0]

# %%
import matplotlib.pyplot as plt

fig1, ax1 = plt.subplots()
plot_contour(ax1, lens_model_list, MacroImg_ra[microtype], MacroImg_dec[microtype], 20*thetaE2, kwargs_lens_list, beta0, beta1, Img_ra, Img_dec,
                    T0 = T0, Tfac = (thetaE)**(-2), micro=True)
# plt.savefig(f'./data/{filename}_tdpic.png')
# Out:
# [-4.02617213e-07 -4.02682780e-07 -4.02415168e-07 -4.02765572e-07
#  -4.02743994e-07] [ 6.09517727e-12 -1.78444690e-10  2.24823161e-13  4.05968870e-11
#   2.80792453e-10] Img_pos
# <Axes: >

# %%
Tscale = 4 * (1 + zL) * mtot * M_sun * G / c ** 3

# %%
# Define the characteristic WindowSize
mL3 = 10
thetaE3 = param_processing(zL, zS, mL3)

# %%
import time

# %%
window_size = 100
moving_average = np.convolve(Ft, np.ones(window_size)/window_size, mode='valid')

# %%
kwargs_macro = {'source_pos_x': beta0,
                'source_pos_y': beta1,
                'theta_E': thetaE,
                'mu': np.abs(Mus[microtype]),
               }

kwargs_integrator = {'PixelNum': int(300000),
                     'PixelBlockMax': 2000,
                     'WindowSize': 10.*210*thetaE3,
                     'WindowCenterX': MacroImg_ra[microtype],
                     'WindowCenterY': MacroImg_dec[microtype],
                     'T0': T0,
                     'TimeStep': 8*1e-7/Tscale, 
                     'TimeMax': T0 + 7/Tscale,
                     'TimeMin': T0 - 5/Tscale,
                     'TExtend': 12/Tscale,
                     'LastImageT': 4e-7/Tscale,
                     'Tbuffer': 0./Tscale,
                     'Tscale': Tscale}

amplification = af.amplification_factor(lens_model_list=lens_model_list, kwargs_lens=kwargs_lens_list, kwargs_macro=kwargs_macro, **kwargs_integrator)
# ts, Ft = amplification.integrator(gpu=False)
ts = np.loadtxt('./data/5m_ts.txt')
Ft = np.loadtxt('./data/5m_ft.txt')
amplification.importor(ts=ts, F_tilde=Ft, time=True)
ws, Fws = amplification.fourier(type2=type2)
# Out:
# [0.00000000e+00 2.70700627e-12 5.41401254e-12 ... 4.06050859e-05
#  4.06050886e-05 4.06050913e-05] 8e-07
# total time 12.0

# %%
plt.plot(ts, Ft)

# %%
amplification.importor(ts=ts, F_tilde=Ft, time=True)
ws, Fws = amplification.fourier(type2=type2)
# Out:
# [0.00000000e+00 2.70700627e-12 5.41401254e-12 ... 4.06050859e-05
#  4.06050886e-05 4.06050913e-05] 8e-07
# total time 12.0

# %%
new_ts = ts[(window_size - 1):]
plt.plot(new_ts, moving_average)

# %%
amplification.plot_freq()
# Out:
# <Axes: xlabel='Frequency (Hz)', ylabel='$|F|/\\sqrt{\\mu}$'>

# %%
plt.semilogx(ws, np.angle(Fws), label=r'$F_{wave}$')

# %% [markdown]
# # Geometrical optics
# To get the geometrical optics around type 1 image, we need the magnifications, time delay and the image positions of the microimages

# %%
tds = TimeDelay(Img_ra, Img_dec,
               beta0, beta1,
               zL, zS,
               lens_model_list, kwargs_lens_list)
mus = magnifications(Img_ra, Img_dec, lens_model_list, kwargs_lens_list)
ns = getMinMaxSaddle(Img_ra, Img_dec, lens_model_list, kwargs_lens_list, diff = None)

# %%
geofs, geoFws = amplification.geometrical_optics(mus, tds, Img_ra, Img_dec, upper_lim=2000)

# %%
from wolensing.utils.utils import *
ns = Morse_indices(amplification._lens_model_list, Img_ra, Img_dec, amplification._kwargs_lens)

# %%
fs = amplification._fs
fs_grid = fs[1]-fs[0]

num_interp = int((3000-fs[0])/fs_grid) 
amplification._geofs = np.linspace(fs[0], 3000, num_interp)

ns = Morse_indices(amplification._lens_model_list, Img_ra, Img_dec, amplification._kwargs_lens)
geoFws1 = compute_geometrical(amplification._geofs, mus[:], tds[:], ns[:])

# %%
mus, ns, tds
Img_ra, Img_dec
# Out:
# (array([-4.02617213e-07, -4.02682780e-07, -4.02415168e-07, -4.02765572e-07,
#         -4.02743994e-07]),
#  array([ 6.09517727e-12, -1.78444690e-10,  2.24823161e-13,  4.05968870e-11,
#          2.80792453e-10]))

# %%
plt.semilogx(amplification._geofs, np.abs(geoFws1))

# %% [markdown]
# # Full amplification factor concatenated with geometrical optics
# Given the computaional cost of the diffraction integral, we concatenate the result of wave optics at low frequency and geometrical optics at high frequency to obtain a full amplification factor with default upper bound of 3000Hz.

# %%
fac = np.sqrt(np.abs(Mus[microtype]))

# %%
plt.clf()
plt.rc('text', usetex=True)
plt.rc('font', family='serif')

# %%
from bisect import bisect_left
low_index = bisect_left(geofs, 1)
geofs = geofs[low_index:]
geoFws = geoFws[low_index:]
ws = ws[low_index:]
Fws = Fws[low_index:]

# %%
ww = geofs
# plt.semilogx(geofs, (fac*np.exp(-ww*np.pi/188) + (1-np.exp(-ww*np.pi/188))*np.abs(geoFws))/fac, label='Approximation')
# plt.semilogx(amplification._geofs, np.abs(geoFws1)/fac,label=r'$F_{geo}$')
plt.semilogx(geofs, np.abs(geoFws)/fac,label=r'$F_{geo}$')
plt.semilogx(ws, np.abs(Fws)/fac, label=r'$F_{wave}$')
# plt.plot(ws, np.abs(Fws)/fac, label=r'$F_{wave}$')
# plt.plot(ws, np.abs(Fws)/fac, label=r'$F_{wave}$')
plt.ylabel(r'$|F|/\sqrt{\mu}$')
plt.xlabel(r'$f$')
plt.grid(which='both', alpha=0.5)
plt.legend()
plt.xlim(1, 1000)
# plt.savefig(f'./{filename}_abs.png',bbox_inches='tight', dpi=300)
# Out:
# (1, 1000)

# %%
ww = geofs
# plt.semilogx(geofs, (fac*np.exp(-ww*np.pi/188) + (1-np.exp(-ww*np.pi/188))*np.abs(geoFws))/fac, label='Approximation')
# plt.semilogx(amplification._geofs, np.abs(geoFws1)/fac,label=r'$F_{geo}$')
# plt.semilogx(amplification._geofs, np.abs(geoFws1)/fac,label=r'$F_{geo}$')

plt.semilogx(ws, np.abs(Fws)/fac, label=r'$F_{wave}$')
plt.ylabel(r'$|F|/\sqrt{\mu}$')
plt.xlabel(r'$f$')
plt.grid(which='both', alpha=0.5)
plt.legend()
plt.xlim(1, 700)
# plt.savefig(f'./{filename}_abs.png',bbox_inches='tight', dpi=300)
# Out:
# (1, 700)

# %%
# plt.semilogx(geofs, (1-np.exp(-ww*np.pi/37.5))*np.angle(geoFws), label='Approximation')
plt.semilogx(geofs[1:j+1], np.angle(geoFws1),label=r'$F_{geo}$')
plt.semilogx(ws[(window_size - 1):], np.convolve(np.angle(Fws), np.ones(window_size)/window_size, mode='valid'), label=r'$F_{wave}$')
plt.ylabel(r'$args(F)$')
plt.xlabel(r'$f$')
plt.grid(which='both', alpha=0.5)
plt.legend()
plt.xlim(1, 800)
# plt.savefig(f'./{filename}_pha.png',bbox_inches='tight', dpi=300)
# Out:
# (1, 800)

# %%
plt.semilogx(ws[:i], np.angle(Fws)[:i], label=r'$F_{wave}$')
np.where(np.angle(Fws)[1:i]==0)
# Out:
# (array([], dtype=int64),)

# %%
np.angle(geoFws)
# Out:
# array([-1.57079633, -1.56265375, -1.55451117, ..., -2.90588608,
#        -2.89847646, -2.89106431])

# %%
peak = np.where(amplification._F_tilde == np.amax(amplification._F_tilde))
index = int(peak[0])
tdiff = amplification._ts[index]*amplification._Tscale
# Out:
# /tmp/ipykernel_1366438/2505619520.py:2: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   index = int(peak[0])

# %%
from bisect import bisect_left
i = bisect_left(ws, 700)

# %%
tdiff
# Out:
# 4.999830266643946

# %%
mis = 1/(4*geofs[1:j+1])
over_pha = np.exp(-1 * 2 * np.pi * 1j * (0.01491765) * geofs[1:j+1])
geoFws1 = geoFws[1:j+1] * over_pha
plt.semilogx(geofs[1:j+1], np.angle(geoFws1))
plt.xlim(1, 800)
# Out:
# (1, 800)

# %%
index = np.argmin(np.abs(geofs - 700))
j = index

# %%
residue = np.divide(np.angle(geoFws)[1:j+1], np.angle(Fws)[1:i])
missing_t = np.log(residue)*(1j/(2*np.pi*geofs[1:j+1]))
# Out:
# /tmp/ipykernel_1366438/907421763.py:2: RuntimeWarning: invalid value encountered in log
#   missing_t = np.log(residue)*(1j/(2*np.pi*geofs[1:j+1]))

# %%
missing_t
# Out:
# array([-0.-0.00631265j, -0.-0.04002417j,  0.+0.01097177j, ...,
#        nan       +nanj, nan       +nanj, nan       +nanj])

# %%
res = np.log(np.angle(geoFws)[:j+1] - np.angle(Fws)[:i])
# Out:
# /tmp/ipykernel_1366438/1410020239.py:1: RuntimeWarning: invalid value encountered in log
#   res = np.log(np.angle(geoFws)[:j+1] - np.angle(Fws)[:i])

# %%
plt.plot(geofs[1:j+1], np.angle(missing_t))

# %%
np.angle(missing_t[:200])
# Out:
# array([-1.57079633, -1.57079633,  1.57079633, -1.57079633,  1.57079633,
#        -1.57079633,  1.57079633, -1.57079633, -1.57079633, -1.57079633,
#        -1.57079633, -1.57079633, -1.57079633, -1.57079633, -1.57079633,
#        -1.57079633, -1.57079633, -1.57079633, -1.57079633, -1.57079633,
#        -1.57079633, -1.57079633, -1.57079633, -1.57079633, -1.57079633,
#        -1.57079633, -1.57079633, -1.57079633, -1.57079633, -1.57079633,
#        -1.57079633, -1.57079633, -1.57079633, -1.57079633, -1.57079633,
#        -1.57079633, -1.57079633, -1.57079633, -1.57079633, -1.57079633,
#        -1.57079633, -1.57079633, -1.57079633, -1.57079633, -1.57079633,
#        -1.57079633, -1.57079633, -1.57079633, -1.57079633, -1.57079633,
#        -1.57079633, -1.57079633, -1.57079633, -1.57079633, -1.57079633,
#        -1.57079633, -1.57079633, -1.57079633, -1.57079633, -1.57079633,
#        -1.57079633, -1.57079633, -1.57079633, -1.57079633, -1.57079633,
#        -1.57079633, -1.57079633, -1.57079633, -1.57079633, -1.57079633,
#        -1.57079633, -1.57079633, -1.57079633, -1.57079633, -1.57079633,
#        -1.57079633, -1.57079633, -1.57079633, -1.57079633, -1.57079633,
#        -1.57079633, -1.57079633, -1.57079633, -1.57079633, -1.57079633,
#        -1.57079633, -1.57079633, -1.57079633, -1.57079633, -1.57079633,
#        -1.57079633, -1.57079633, -1.57079633, -1.57079633, -1.57079633,
#        -1.57079633, -1.57079633, -1.57079633, -1.57079633, -1.57079633,
#        -1.57079633, -1.57079633, -1.57079633, -1.57079633, -1.57079633,
#        -1.57079633, -1.57079633, -1.57079633, -1.57079633, -1.57079633,
#        -1.57079633, -1.57079633, -1.57079633, -1.57079633, -1.57079633,
#        -1.57079633, -1.57079633, -1.57079633, -1.57079633, -1.57079633,
#        -1.57079633, -1.57079633, -1.57079633, -1.57079633, -1.57079633,
#        -1.57079633, -1.57079633, -1.57079633, -1.57079633, -1.57079633,
#        -1.57079633, -1.57079633, -1.57079633, -1.57079633, -1.57079633,
#        -1.57079633, -1.57079633, -1.57079633, -1.57079633, -1.57079633,
#        -1.57079633, -1.57079633, -1.57079633, -1.57079633, -1.57079633,
#        -1.57079633, -1.57079633, -1.57079633, -1.57079633, -1.57079633,
#        -1.57079633, -1.57079633, -1.57079633, -1.57079633, -1.57079633,
#        -1.57079633, -1.57079633, -1.57079633, -1.57079633, -1.57079633,
#        -1.57079633, -1.57079633, -1.57079633, -1.57079633, -1.57079633,
#        -1.57079633, -1.57079633, -1.57079633, -1.57079633, -1.57079633,
#        -1.57079633, -1.57079633, -1.57079633, -1.57079633, -1.57079633,
#        -1.57079633, -1.57079633, -1.57079633, -1.57079633, -1.57079633,
#        -1.57079633, -1.57079633, -1.57079633, -1.57079633, -1.57079633,
#        -1.57079633, -1.57079633, -1.57079633, -1.57079633, -1.57079633,
#        -1.57079633, -1.57079633,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan])
